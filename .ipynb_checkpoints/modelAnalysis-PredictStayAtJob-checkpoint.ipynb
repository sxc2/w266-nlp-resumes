# %% [markdown]
# ## Resume EDA
# #### Resumes (300MB)
#
#
#
# ### Methodology
#
#
# #### 1 <a href='#setup'>Initial Setup</a>
#
# #### 2. <a href='#eda'>Exploratory Analysis</a>
# - 2.0 <a href='#eda'>Cleaning Data</a>
# #### 2. <a href='#future'>Future Extensions</a>

# %% [markdown]
# <a id="setup"></a>
# ## Setup
#
# Let's import the serialized data

# %%
# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

# General libraries
import re
import string
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, json
import unicodedata
from collections import Counter

# NLTK library for stop word removal
from nltk.corpus import stopwords

# SK-learn libraries for learning.
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB

# SK-learn libraries for evaluation.
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer


from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

from sklearn.metrics import log_loss

from xml.dom import minidom
from bs4 import BeautifulSoup as BS

# %%
import pickle
import sys

sys.setrecursionlimit(20000)
train_xml_ = pickle.load( open( "data/train_1_xml.p", "rb" ) )

# %%
train_xml_ = pd.DataFrame(train_xml_)

# shuffle the training data to get rid of implicit order biases
train_data_original = train_xml_.sample(frac = 1)
train_data_original = train_data_original.reset_index()

# %%
train_data_original.describe()
# Out:
#               index
# count  44397.000000
# mean   22198.000000
# std    12816.454287
# min        0.000000
# 25%    11099.000000
# 50%    22198.000000
# 75%    33297.000000
# max    44396.000000

# %%
# Lowercase the text
train_data_original['data'] = train_data_original['data'].apply(lambda x: x.lower())

# Attempt to remove css that is encased between {| and |
#train_data_original['data'] = train_data_original['data'].apply(lambda x: re.sub(re.compile('{|.*?|'),'',x))

# Removing line breaks
#train_data_original['data'] = train_data_original['data'].map(lambda x: x.splitlines()).astype(str)

# Remove html tags in <>
#train_data_original['data'] = train_data_original['data'].apply(lambda x: re.sub(re.compile('<.*?>'),'',x))

# Remove content in curly braces {}, which include entities and more css
#train_data_original['data'] = train_data_original['data'].apply(lambda x: re.sub(re.compile('{.*?}'),'',x))

# Remove indicators in HTML
train_data_original['data'] = train_data_original['data'].str.replace('itemprop="worksfor"',' ')
train_data_original['data'] = train_data_original['data'].str.replace('itemtype="http://schema.org/organization"',' ')
train_data_original['data'] = train_data_original['data'].str.replace('itemscope',' ')
train_data_original['data'] = train_data_original['data'].str.replace('present',' ')

train_data_original['plain_data'] = train_data_original['data'].apply(lambda x: re.sub('<[^<]+?>', '', x))

# %%
print(train_data_original['data'][0])
print(train_data_original['plain_data'][0])
# print(train_data_original['data'][1])
# print(train_data_original['data'][2])
# Out:
# <div class="vcard single_form-content" id="resume_body">
# <div class="last basicinfo-content" id="basic_info_row"><div class="data_display" id="basic_info_cell">
# <h1 class="fn " id="resume-contact" itemprop="name">child care worker</h1>
# <div id="contact_info_container">
# <div class="adr" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><p class="locality" id="headline_location" itemprop="addresslocality">arcola, tx</p></div>
# <div class="separator-hyphen">-</div>
# </div>
# </div></div>
# <div class="section-item workexperience-content">
# <div><div class="section_title"><h2>work experience</h2></div></div>
# <div class="items-container" id="work-experience-items">
# <div class="work-experience-section " id="workexperience-eeynhzewuma12slhbgsw1q"><div class="data_display">
# <p class="work_title title">child care worker</p>
# <div class="work_company"    =""  >
# <span class="bold" itemprop="name">the kensington school</span> <div class="separator-hyphen">-</div> <div class="inline-block" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">richmond, tx</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# october 2015
# <p class="work_description">assistant teacher</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eevuljsa2_ygzln7osniyg"><div class="data_display">
# <p class="work_title title">child care worker</p>
# <div class="work_company"><span class="bold">kids r kids learning academy</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">2015 to 2015</p>
# </div></div>
# <div class="work-experience-section last" id="workexperience-eevulldgaeegzln7osniyg"><div class="data_display">
# <p class="work_title title">nanny</p>
# <div class="work_company"><span class="bold">from home</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">2014 to 2015</p>
# </div></div>
# </div>
# </div>
# <div class="section-item education-content">
# <div><div class="section_title"><h2>education</h2></div></div>
# <div class="items-container" id="education-items"><div class="education-section last" id="education-eevulmxrgjwgrgxatb0mla"><div class="data_display" itemprop="alumniof"  ="" itemtype="http://schema.org/educationalorganization">
# <p class="edu_title">high school or equivalent</p>
# <div class="edu_school"><span class="bold" itemprop="name">hcc</span></div>
# </div></div></div>
# </div>
# </div>
#
#
# child care worker
#
# arcola, tx
# -
#
#
#
# work experience
#
#
# child care worker
#
# the kensington school - richmond, tx
#
# -
# october 2015
# assistant teacher
#
#
# child care worker
# kids r kids learning academy
# -
# 2015 to 2015
#
#
# nanny
# from home
# -
# 2014 to 2015
#
#
#
#
# education
#
# high school or equivalent
# hcc

# %% [markdown]
# ### Questions to Explore
#
#
# - How many folks (%) have no previous experience?
# - How many jobs do folks have on average?
# - What is the average length of resume?

# %%
comment_length = train_data_original['data'].str.len()

plt.figure(figsize=(8,6))
plt.title("Resume Field String Length Histogram")
plt.ylabel('Number of Occurrences', fontsize = 12)
plt.xlabel('Number of Characters', fontsize = 12)
plt.grid(True)

counts, bins, bars = plt.hist(comment_length, alpha = 0.75)

print('Resume Average Char Length: ' + str(round(comment_length.mean(), 1)))
print('Resume Median Char Length: ' + str(round(comment_length.median(), 1)))
print('Resume Variance Char Length: ' + str(round(comment_length.std(), 1)))
print('Resume Min Char Length: ' + str(round(comment_length.min(), 1)))
print('Resume Max Char Length: ' + str(round(comment_length.max(), 1)))
# Out:
# Resume Average Char Length: 5982.0
# Resume Median Char Length: 5341.0
# Resume Variance Char Length: 3452.7
# Resume Min Char Length: 957
# Resume Max Char Length: 79399

# %% [markdown]
# ### Predictor Variables EDA

# %%
predictors = [];

for i in range(len(train_data_original)):
    predictors.append(train_data_original['predictions'][i])
    
predictors_ = pd.DataFrame(predictors)

# %%
predictors_.describe()
# Out:
#        work_company work_stayed work_title
# count         44397       44397      44397
# unique        36752           2      23999
# top         Walmart        True    Cashier
# freq            321       25435        568

# %%
predictors_['work_company'][0]
# Out:
# 'The Kensington school'

# %%
len(predictors_['work_company'].unique())
# Out:
# 36752

# %%
# Lowercase the text
predictors_['work_company'] = predictors_['work_company'].apply(lambda x: x.lower())

# Attempt to remove css that is encased between {| and |
predictors_['work_company'] = predictors_['work_company'].apply(lambda x: re.sub(re.compile('{|.*?|'),'',x))

# Removing line breaks
predictors_['work_company'] = predictors_['work_company'].map(lambda x: x.splitlines()).astype(str)

# Remove html tags in <>
predictors_['work_company'] = predictors_['work_company'].apply(lambda x: re.sub(re.compile('<.*?>'),'',x))

# Remove content in curly braces {}, which include entities and more css
predictors_['work_company'] = predictors_['work_company'].apply(lambda x: re.sub(re.compile('{.*?}'),'',x))

# Remove punctuation
predictors_['work_company'] = predictors_['work_company'].str.replace('[^\w\s]','')

# Remove Special Characters
predictors_['work_company'] = predictors_['work_company'].str.replace('[^a-zA-Z ]',' ')

# %%
print(len(predictors_['work_company'].unique()))
print(predictors_['work_title'][0])
print(len(predictors_['work_title'].unique()))
# Out:
# 35411
# Drive Test Engineer
# 23999

# %%
# Lowercase the text

predictors_['work_title'] = predictors_['work_title'].apply(lambda x: x.lower())
predictors_['work_title'] = predictors_['work_title'].str.replace('[/]',' ')

# Attempt to remove css that is encased between {| and |
predictors_['work_title'] = predictors_['work_title'].apply(lambda x: re.sub(re.compile('{|.*?|'),'',x))

# Removing line breaks
predictors_['work_title'] = predictors_['work_title'].map(lambda x: x.splitlines()).astype(str)

# Remove html tags in <>
predictors_['work_title'] = predictors_['work_title'].apply(lambda x: re.sub(re.compile('<.*?>'),'',x))

# Remove content in curly braces {}, which include entities and more css
predictors_['work_title'] = predictors_['work_title'].apply(lambda x: re.sub(re.compile('{.*?}'),'',x))

# Remove punctuation
predictors_['work_title'] = predictors_['work_title'].str.replace('[^\w\s]','')

# Remove Special Characters
predictors_['work_title'] = predictors_['work_title'].str.replace('[^a-zA-Z ]',' ')

# %%
print(len(predictors_['work_title'].unique()))
print(predictors_['work_title'][4])
print(predictors_['work_stayed'][0])
# Out:
# 22638
# consumer loan underwriter
# False

# %% [markdown]
# ### Potential Interesting Features
#
# - whether or not you're going to stay at the same job
# - whether you're going into a different job function
# - whether you're going to stay at the same company
# - whether you're going get promoted?
#
# - level of candidate
# - classification of candidate
# - diversity?
#
# - skills overlap between current and last job

# %%
len_ = int(len(train_data_original)/4)
print(len_)
train_data_ = train_data_original[len_:]
test_data_ = train_data_original[:len_]

predictors_train_ = predictors_[len_:]
predictors_test = predictors_[:len_]

model_results = []
# Out:
# 11099

# %%
vectorizer_train = TfidfVectorizer(sublinear_tf = True, lowercase = True)
train_fit = vectorizer_train.fit(train_data_['data'])
train_transformed = vectorizer_train.transform(train_data_['data'])
dev_transformed = vectorizer_train.transform(test_data_['data'])
logis_regression = LogisticRegression()
logis_regression.fit(train_transformed, predictors_train_['work_stayed'].astype(int))
pred = logis_regression.predict_proba(dev_transformed)
f1score_logis = logis_regression.score(dev_transformed, predictors_test['work_stayed'].astype(int)) 
accuracy = round(f1score_logis, 6)
log_loss_ = round(log_loss(predictors_test['work_stayed'].astype(int), pred), 6)

model_results.append({"accuracy" : accuracy, "name" : "TFIDF HTML - Predict Stay at Job", "log_loss": log_loss_})

# %%
print("Accuracy: " + str(accuracy))
print("Log Loss: " + str(log_loss_))
# Out:
# Accuracy: 0.756735
# Log Loss: 0.520343

# %%
vectorizer_train_plain = TfidfVectorizer(sublinear_tf = True, lowercase = True)
train_fit_plain = vectorizer_train_plain.fit(train_data_['plain_data'])
train_transformed_plain = vectorizer_train_plain.transform(train_data_['plain_data'])
dev_transformed_plain = vectorizer_train_plain.transform(test_data_['plain_data'])

logis_regression_plain = LogisticRegression()
logis_regression_plain.fit(train_transformed_plain, predictors_train_['work_stayed'].astype(int))
pred_plain = logis_regression_plain.predict_proba(dev_transformed_plain)

f1score_logis = logis_regression_plain.score(dev_transformed_plain, predictors_test['work_stayed'].astype(int))

accuracy = round(f1score_logis, 6)
log_loss_ = round(log_loss(predictors_test['work_stayed'].astype(int), pred_plain), 6)

model_results.append({"accuracy" : accuracy, "name" : "TFIDF Plain Text - Predict Stay at Job", "log_loss": log_loss_})

# %%
print("Accuracy: " + str(accuracy))
print("Log Loss: " + str(log_loss_))
# Out:
# Accuracy: 0.650149
# Log Loss: 0.623826

# %%
model_results
# Out:
# [{'accuracy': 0.756735,
#   'name': 'TFIDF HTML - Predict Stay at Job',
#   'log_loss': 0.520343},
#  {'accuracy': 0.650149,
#   'name': 'TFIDF Plain Text - Predict Stay at Job',
#   'log_loss': 0.623826}]

# %%
# http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
correct_values = predictors_test['work_stayed'].astype(int)
logis_regression_pred = logis_regression.predict(dev_transformed) 

confusion_mat = confusion_matrix(correct_values, logis_regression_pred)

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(confusion_mat, classes=[0,1], title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(confusion_mat, classes=[0,1], normalize=True, title='Normalized confusion matrix')

plt.show()

# %%
correct_values = predictors_test['work_stayed'].astype(int)
logis_regression_pred = logis_regression_plain.predict(dev_transformed_plain) 

confusion_mat = confusion_matrix(correct_values, logis_regression_pred)

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(confusion_mat, classes=[0,1], title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(confusion_mat, classes=[0,1], normalize=True, title='Normalized confusion matrix')

plt.show()

# %%
# Print some examples of our vocabulary

def construct_columns_for_top_vocab(vectorizer_train, logis_regression):
    
    # Initialize empty helper vectors and get feature names
    feature_names = vectorizer_train.get_feature_names()
    num_top_features = 10
    all_indices = []
    all_indices_labels = []
    all_indices_values = []
    all_indices_values_with_labels = {}
    
    # https://stackoverflow.com/questions/6910641/how-do-i-get-indices-of-n-maximum-values-in-a-numpy-array
    indices = (-logis_regression.coef_[0]).argsort()[:num_top_features]
    all_indices.extend(indices)
            
    # Getting all the indices and then adding the feature names for each category
    for i, value in enumerate(all_indices):
        all_indices_labels.append(feature_names[value])
        all_indices_values.append([])
        all_indices_values[i].append(round(logis_regression.coef_[0][value], 3))
        all_indices_values_with_labels[feature_names[value]] = all_indices_values[i]
        
    return all_indices_values_with_labels


showValues = construct_columns_for_top_vocab(vectorizer_train, logis_regression)
df = pd.DataFrame.from_dict(showValues, orient='index')
display(df)

showValues = construct_columns_for_top_vocab(vectorizer_train_plain, logis_regression_plain)
df = pd.DataFrame.from_dict(showValues, orient='index')
display(df)
# Out:
#                       0
# name             28.135
# itemprop         13.673
# addresslocality  13.519
# postaladdress    13.519
# address          13.318
# schema            7.628
# itemtype          7.622
# org               7.606
# http              7.462
# 2016              7.039
#                0
# 2016       6.603
# currently  3.473
# 2015       3.261
# manage     3.070
# fresno     2.616
# lead       2.425
# are        2.407
# current    2.314
# lafayette  2.289
# have       2.179

# %%
multinomial = MultinomialNB()
multinomial.fit(train_transformed, predictors_train_['work_stayed'].astype(int))
f1score_multi = multinomial.score(dev_transformed, predictors_test['work_stayed'].astype(int)) 

pred_multi = multinomial.predict_proba(dev_transformed)

accuracy = round(f1score_multi, 6)
log_loss_ = round(log_loss(predictors_test['work_stayed'].astype(int), pred_multi), 6)

print("Accuracy: " + str(accuracy))
print("Log Loss: " + str(log_loss_))
model_results.append({"accuracy" : accuracy, "name" : "TFIDF HTML NB - Predict Stay at Job", "log_loss": log_loss_})
# Out:
# Accuracy: 0.571538
# Log Loss: 1.20385

# %%
multinomial_plain = MultinomialNB()
multinomial_plain.fit(train_transformed_plain, predictors_train_['work_stayed'].astype(int))
f1score_multi = multinomial_plain.score(dev_transformed_plain, predictors_test['work_stayed'].astype(int)) 

pred_plain_multi = multinomial_plain.predict_proba(dev_transformed_plain)

accuracy = round(f1score_multi, 6)
log_loss_ = round(log_loss(predictors_test['work_stayed'].astype(int), pred_plain_multi), 6)

print("Accuracy: " + str(accuracy))
print("Log Loss: " + str(log_loss_))
model_results.append({"accuracy" : accuracy, "name" : "TFIDF Plain NB - Predict Stay at Job", "log_loss": log_loss_})
# Out:
# Accuracy: 0.583206
# Log Loss: 0.900991

# %%
showValues = construct_columns_for_top_vocab(vectorizer_train, multinomial)
df = pd.DataFrame.from_dict(showValues, orient='index')
display(df)
# Out:
#                   0
# div          -6.103
# class        -6.179
# span         -6.459
# id           -6.472
# itemprop     -6.585
# br           -6.628
# section      -6.667
# and          -6.687
# data_display -6.732
# to           -6.735

# %%
showValues = construct_columns_for_top_vocab(vectorizer_train_plain, multinomial_plain)
df = pd.DataFrame.from_dict(showValues, orient='index')
display(df)
# Out:
#               0
# and      -6.088
# to       -6.113
# in       -6.396
# of       -6.412
# the      -6.428
# for      -6.506
# with     -6.616
# work     -6.637
# skills   -6.770
# customer -6.791

# %%
from sklearn.base import TransformerMixin
from sklearn.pipeline import FeatureUnion

# %%
# Loading list of stopwords from nltk corpus
stop_words = stopwords.words('english')

# Helper function for finding the percent of stop words in the message
def contains_stop_words(x):
    count = 0
    
    tokens = x.lower().split()
    for value in tokens:
        if value in stop_words:
            count = count + 1
    
    return count / float(len(tokens))

# The word length function for counting how long individual words are
def word_length(x):
    total_chars = len(x)
    num_words = len(x.split())
    return total_chars / float(num_words)

# Helper function for finding the number of unique words
def unique_words(x):
    num_words = len(set(x.lower().split()))
    return num_words

def capitalized_percent(x):
    total_chars = len(x)
    num_capi = len(re.findall(r'[A-Z]', x))
    return num_capi / float(total_chars)

# Helper function for calculating the percent of non-alpha numeric characters
def non_alphanumeric_percent(x):
    total_chars = len(x)
    num_special = len(re.findall(r'[^0-9a-zA-Z ]', x))
    return num_special / float(total_chars)

# Helper function for calculating the percent of non-alpha numeric non-period, comma, dash characters
def non_alphanumeric_noperiodscommas_percent(x):
    total_chars = len(x)
    num_special = len(re.findall(r'[^0-9a-zA-Z.,-/ ]', x))
    return num_special / float(total_chars)

# Helper function for calculating the percent of non-alpha-numeric specific punctuation characters
def non_alphanumeric_specificpunc_percent(x):
    total_chars = len(x)
    num_special = len(re.findall(r'[!@$%&*]', x))
    return num_special / float(total_chars)

# Helper function for calculating the percent of just ! characters
def non_alphanumeric_just_exclamation_percent(x):
    total_chars = len(x)
    num_special = len(re.findall(r'[!]', x))
    return num_special / float(total_chars)

# Class transformer for TextLengthTransformer
class TextLengthTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: len(x) > 150 )).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self

# Class transformer for TokenLengthTransformer
class TokenLengthTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: len([word for word in x.split() if word]))).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self

# Class transformer for AverageWordLengthTransformer
class AverageWordLengthTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: word_length(x))).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self

# Class transformer for AverageWordLengthNormalTransformer
class AverageWordLengthNormalTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: word_length(x) > 100)).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self
    
# Class transformer for CapitalizedPercentTransformer
class CapitalizedPercentTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: capitalized_percent(x))).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self

# Class transformer for SpecificPunctuationTransformer
class SpecificPunctuationTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: non_alphanumeric_specificpunc_percent(x))).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self

# Class transformer for SpecificPunctuationExclamaTransformer
class SpecificPunctuationExclamaTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: non_alphanumeric_just_exclamation_percent(x))).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self

# Class transformer for UniqueWordsTransformer
class UniqueWordsTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: unique_words(x))).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self
    
# Class transformer for ContainsStopWordsTransformer
class ContainsStopWordsTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: contains_stop_words(x))).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self

class SpecificPunctuationTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: non_alphanumeric_specificpunc_percent(x))).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self

# %%
pipe_all = Pipeline([
    ('features', FeatureUnion([
        ('TextLength', TextLengthTransformer()),
        ('TokenLength', TokenLengthTransformer()),
        ('AverageWordLength', AverageWordLengthTransformer()),
        ('AverageWordLengthNormal', AverageWordLengthNormalTransformer()),
        ('UniqueWords', UniqueWordsTransformer()),
        ('tfdif_features', Pipeline([
            ('cv', CountVectorizer()),
            ('tfidf', TfidfTransformer(sublinear_tf = True)),
        ])),
    ])),
    ('logit', LogisticRegression()),

])

pipe_all.fit(train_data_['plain_data'], predictors_train_['work_stayed'].astype(int))
f1score_logis = pipe_all.score(test_data_['plain_data'], predictors_test['work_stayed'].astype(int))
pred_pipe = pipe_all.predict_proba(test_data_['plain_data'])

accuracy = round(f1score_logis, 6)
log_loss_ = round(log_loss(predictors_test['work_stayed'].astype(int), pred_pipe), 6)

print("Accuracy: " + str(accuracy))
print("Log Loss: " + str(log_loss_))
model_results.append({"accuracy" : accuracy, "name" : "TFIDF Plain Log Pipeline [*all] - Predict Stay at Job", "log_loss": log_loss_})
# Out:
# Accuracy: 0.650419
# Log Loss: 0.62472

# %%
pipe_all = Pipeline([
    ('features', FeatureUnion([
        ('TextLength', TextLengthTransformer()),
        ('TokenLength', TokenLengthTransformer()),
        ('AverageWordLength', AverageWordLengthTransformer()),
        ('AverageWordLengthNormal', AverageWordLengthNormalTransformer()),
        ('UniqueWords', UniqueWordsTransformer()),
        ('tfdif_features', Pipeline([
            ('cv', CountVectorizer()),
            ('tfidf', TfidfTransformer(sublinear_tf = True)),
        ])),
    ])),
    ('logit', LogisticRegression()),

])

pipe_all.fit(train_data_['data'], predictors_train_['work_stayed'].astype(int))
f1score_logis = pipe_all.score(test_data_['data'], predictors_test['work_stayed'].astype(int))
pred_pipe = pipe_all.predict_proba(test_data_['data'])

accuracy = round(f1score_logis, 6)
log_loss_ = round(log_loss(predictors_test['work_stayed'].astype(int), pred_pipe), 6)

print("Accuracy: " + str(accuracy))
print("Log Loss: " + str(log_loss_))
model_results.append({"accuracy" : accuracy, "name" : "TFIDF HTML Log Pipeline [*all] - Predict Stay at Job", "log_loss": log_loss_})
# Out:
# Accuracy: 0.735607
# Log Loss: 0.546627

# %%
model_results
# Out:
# [{'accuracy': 0.736913,
#   'name': 'TFIDF HTML - Predict Stay at Job',
#   'log_loss': 0.545848},
#  {'accuracy': 0.650329,
#   'name': 'TFIDF Plain Text - Predict Stay at Job',
#   'log_loss': 0.625412},
#  {'accuracy': 0.650419,
#   'name': 'TFIDF Plain Log Pipeline [*all] - Predict Stay at Job',
#   'log_loss': 0.62472},
#  {'accuracy': 0.735607,
#   'name': 'TFIDF HTML Log Pipeline [*all] - Predict Stay at Job',
#   'log_loss': 0.546627}]

# %%
import gensim.models.keyedvectors as word2vec
import keras
import gc

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation
from keras.layers import Bidirectional, GlobalMaxPool1D,Bidirectional
from keras.models import Model
from keras import initializers, regularizers, constraints, optimizers, layers

# load word2vec, slimmed down version for performance reasons
word2vecDict = word2vec.KeyedVectors.load_word2vec_format("data/GoogleNews-vectors-negative300-SLIM.bin", binary = True)
embedding_dictionary = dict()

# create the embeddings index from word2vec vocabulary
for word in word2vecDict.wv.vocab:
    embedding_dictionary[word] = word2vecDict.word_vec(word)

### TUNABLE PARAMETERS WE DID NOT TUNE DUE TO RUN TIME DURATION
max_length_cutoff = 200
batch_size = 32
epochs = 3
vocab_size = 16000
embedding_layer = 300

# Initialize tokenizer with a default vocab size, fit on training data
# tokenizer = Tokenizer(num_words = vocab_size)
# tokenizer.fit_on_texts(list(train_data_['data']))

# # for training and test data
# list_tokenized_train = tokenizer.texts_to_sequences(train_data_['data'])
# tokenized_padded_train = pad_sequences(list_tokenized_train, maxlen = max_length_cutoff)

# list_tokenized_test = tokenizer.texts_to_sequences(test_data_['data'])
# tokenized_padded_test = pad_sequences(list_tokenized_test, maxlen = max_length_cutoff)
# Out:
# /Users/sxc2/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /Users/sxc2/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
# https://www.kaggle.com/amberhahn/using-f-score-to-evaluate-the-lstm-model
def model_F_score(newp,newy_test):
    TP=0
    FN=0
    FP=0
    for i in range(len(newp)-1):
        test_prof=newy_test[i+1]-newy_test[i]
        p_prof=newp[i+1] - newp[i]

        if((test_prof>=0) and (p_prof>=0)):
            TP=TP+1
        if ((test_prof>= 0) and (p_prof<0)):
            FN=FN+1
        if ((test_prof<0) and (p_prof>=0)):
            FP=FP+1

    Precision=float(TP)/float(TP+FP)
    Recall=float(TP)/float(TP+FN)

    Fscore= 2.0*Precision*Recall/(Precision+Recall)
    print('classification F score: %.5f' % (Fscore))
    return Fscore

# model_F_score(predictors_test['work_stayed'].astype(int), lstm_nn_pred)

# %%
model_predictions = {}

# %%
from keras import backend as K

# https://stackoverflow.com/questions/43547402/how-to-calculate-f1-macro-in-keras
def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
def train_lstm_rnn(_epochs, _embedding_layer, data_name, _max_length_cutoff, _optimizer, _dropout):

    global model_results
    global embedding_dictionary
    
    # tunable?
    output_dim = 60
    
    tokenizer_ = Tokenizer(num_words = vocab_size)
    tokenizer_.fit_on_texts(list(train_data_[data_name]))

    # for training and test data
    list_tokenized_train_ = tokenizer_.texts_to_sequences(train_data_[data_name])
    tokenized_padded_train_ = pad_sequences(list_tokenized_train_, maxlen = _max_length_cutoff)

    list_tokenized_test_ = tokenizer_.texts_to_sequences(test_data_[data_name])
    tokenized_padded_test_ = pad_sequences(list_tokenized_test_, maxlen = _max_length_cutoff)

    number_words_ = len(tokenizer_.word_index)
    embedding_values_ = np.stack(list(embedding_dictionary.values()))
    
    _mean, _std = embedding_values_.mean(), embedding_values_.std()
    embedding_matrix_ = np.random.normal(_mean, _std, (number_words_, _embedding_layer))

    for word, index in tokenizer_.word_index.items():
        index = index - 1
        embedding_vector = embedding_dictionary.get(word)
        if embedding_vector is not None: 
            embedding_matrix_[index] = embedding_vector

    sequence_input_ = Input(shape = (_max_length_cutoff, ))
    x_ = Embedding(len(tokenizer_.word_index), 
                  embedding_matrix_.shape[1], weights = [embedding_matrix_], trainable = False)(sequence_input_)

    x_ = Bidirectional(
        LSTM(output_dim, return_sequences = True, name='lstm_layer', dropout = _dropout, recurrent_dropout = _dropout))(x_)

    x_ = GlobalMaxPool1D()(x_)
    x_ = Dropout(_dropout)(x_)
    x_ = Dense(50, activation = "relu")(x_)
    x_ = Dropout(_dropout)(x_)

    # one output node
    x_ = Dense(1, activation = "sigmoid")(x_)
    model_ = Model(inputs = sequence_input_, outputs = x_)
    model_.compile(loss = 'binary_crossentropy',
                      optimizer = _optimizer,
                      metrics = ['accuracy', 'cosine_proximity', f1])

    # a look at the RNN we're building and its structure
    model_.summary()

    lstm_nn_plain = model_.fit(tokenized_padded_train_, 
                        predictors_train_['work_stayed'], 
                        batch_size = batch_size, epochs = _epochs, validation_split = 0.1)
    lstm_nn_pred_plain = model_.predict(tokenized_padded_test_)
    accuracy = model_F_score(predictors_test['work_stayed'].astype(int), lstm_nn_pred_plain)
    
    model_details_ = "CO:" + str(_max_length_cutoff) + ", E:" + str(_epochs) + ", " + data_name + ", " + _optimizer
    model_predictions[model_details_] = lstm_nn_pred_plain
    model_results.append({"F1 accuracy" : accuracy, "name" : "LSTM: " + model_details_ + " - Predict Stay at Job"})

# %%
train_lstm_rnn(10, 300, 'data', 800, "adam", 0.1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 800)               0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 800, 300)          114940200
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 800, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                6050
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 115,119,581
# Trainable params: 179,381
# Non-trainable params: 114,940,200
# _________________________________________________________________
# Train on 29968 samples, validate on 3330 samples
# Epoch 1/10
# 29968/29968 [==============================] - 1018s 34ms/step - loss: 0.2855 - acc: 0.8415 - cosine_proximity: -0.5752 - f1: 0.8736 - val_loss: 0.1901 - val_acc: 0.8964 - val_cosine_proximity: -0.5796 - val_f1: 0.9157
# Epoch 2/10
# 29968/29968 [==============================] - 1020s 34ms/step - loss: 0.1848 - acc: 0.8991 - cosine_proximity: -0.5752 - f1: 0.9170 - val_loss: 0.1881 - val_acc: 0.8967 - val_cosine_proximity: -0.5796 - val_f1: 0.9162
# Epoch 3/10
# 29968/29968 [==============================] - 1052s 35ms/step - loss: 0.1823 - acc: 0.9002 - cosine_proximity: -0.5752 - f1: 0.9178 - val_loss: 0.1884 - val_acc: 0.8979 - val_cosine_proximity: -0.5796 - val_f1: 0.9169
# Epoch 4/10
# 29968/29968 [==============================] - 1053s 35ms/step - loss: 0.1799 - acc: 0.9016 - cosine_proximity: -0.5752 - f1: 0.9186 - val_loss: 0.1872 - val_acc: 0.9000 - val_cosine_proximity: -0.5796 - val_f1: 0.9176
# Epoch 5/10
# 29968/29968 [==============================] - 1067s 36ms/step - loss: 0.1776 - acc: 0.9015 - cosine_proximity: -0.5752 - f1: 0.9180 - val_loss: 0.1856 - val_acc: 0.9012 - val_cosine_proximity: -0.5796 - val_f1: 0.9182
# Epoch 6/10
# 29968/29968 [==============================] - 1078s 36ms/step - loss: 0.1770 - acc: 0.9038 - cosine_proximity: -0.5752 - f1: 0.9200 - val_loss: 0.1877 - val_acc: 0.9003 - val_cosine_proximity: -0.5796 - val_f1: 0.9189
# Epoch 7/10
# 29968/29968 [==============================] - 1115s 37ms/step - loss: 0.1713 - acc: 0.9075 - cosine_proximity: -0.5752 - f1: 0.9225 - val_loss: 0.1804 - val_acc: 0.9054 - val_cosine_proximity: -0.5796 - val_f1: 0.9208
# Epoch 8/10
# 29968/29968 [==============================] - 1096s 37ms/step - loss: 0.1678 - acc: 0.9100 - cosine_proximity: -0.5752 - f1: 0.9240 - val_loss: 0.1808 - val_acc: 0.9078 - val_cosine_proximity: -0.5796 - val_f1: 0.9244
# Epoch 9/10
# 29968/29968 [==============================] - 1134s 38ms/step - loss: 0.1681 - acc: 0.9118 - cosine_proximity: -0.5752 - f1: 0.9253 - val_loss: 0.1810 - val_acc: 0.8994 - val_cosine_proximity: -0.5796 - val_f1: 0.9156
# Epoch 10/10
# 29968/29968 [==============================] - 1171s 39ms/step - loss: 0.1627 - acc: 0.9145 - cosine_proximity: -0.5752 - f1: 0.9271 - val_loss: 0.1839 - val_acc: 0.8913 - val_cosine_proximity: -0.5796 - val_f1: 0.9052
# classification F score: 0.79117

# %%
def score_accuracy(pred, actual):
    total = 0.0
    correct = 0.0
    for index, value in enumerate(pred):
        if (actual[index] == round(value[0])):
            correct += 1
        total += 1
    return correct / total

# %%
for index in model_predictions:
    score = score_accuracy(model_predictions[index], predictors_test['work_stayed'].astype(int))
    print(str(index) + " score: " + str(score))
# Out:
# CO:800, E:10, data, adam score: 0.8891792053338139

# %%
pickle.dump(model_predictions, open( "data/results_LSTM_stayjob_best.p", "wb" ) )

def print_wrong_examples(pred, actual, details = True, all_results = False):
    count = 0
    for index, value in enumerate(pred):
        if (actual[index] != round(value[0])) and (abs(actual[index] - value[0]) > 0.8):
            print("index:" + str(index) + " actual:" + str(actual[index].astype(int)) + " predicted:" + str(round(value[0])) + " " + str(value[0]))
            if (details):
                print('====================================================================')
                print(test_data_['plain_data'][index])
            count += 1
        if (count > 10) and not all_results:
            break

            
print_wrong_examples(model_predictions['CO:800, E:10, data, adam'], predictors_test['work_stayed'].astype(int), True, True)
# Out:
# index:330 actual:1 predicted:0.0 0.117833495
# ====================================================================
#
#
# paul heatherly
# engineering technician
#
# corinth, ms
# -
#
# to obtain productive employment in my field of experiences
# willing to relocate: anywhere
# authorized to work in the us for any employer
#
#
# work experience
#
#
# test engineer
#
# masterpiece engineer - corinth, ms
#
# -
# june 2015
# responsibilities wiring test fixtures. troubleshooting test fixtures
#
#
# engineering technician
#
# futaba - madison, al
#
# -
# january 2014 to
# responsibilities design, repair, and maintain the running of test fixtures.  accomplishments ability to meet the demands of the company and increase customer satisfaction.  skills used troubleshooting and repair.
#
#
# electronic technician
#
# lg - huntsville, al
#
# -
# december 2013 to
# responsibilities debug equipment, order and replace parts.  accomplishments ability to fix problems increasing output  skills used excellent troubleshooting skills
#
#
# extrusion operator
#
# ilpea - hartselle, al
#
# -
# october 2012 to october 2013
# responsibilities run and maintain extrusion machinery.  made rubber gaskets.  accomplishments exceeded output   skills used ability to fix machinery problems using personal tools
#
#
# engineering technician
# ctdi
# -
# october 2010 to july 2011
# responsible for i was responsible for rma debug and repair for alloptics communication line of product. i also did there test, debug, repair, and software for their new production as well. while at this job i acted as associate test engineer as well as my normal duties. in which i assisted in building test sets platforms and programs for other communication devises for other company products. i also assisted in difficult debug and repairs of other products in the company. i was laid off due to lack of work.
#
#
# test engineer
#
# sanmina-sci - huntsville, al
#
# -
# june 2005 to february 2010
# performed circuit and component level troubleshooting on diagnostic test equipment. identified malfunctioning components and replaced as necessary. utilized required test equipment to perform job responsibilities. read and interpreted schematics and diagnostic manuals. assisted engineering staff in troubleshooting and diagnosing problems with new product designs. performed functional test fixture maintenance, fixture diagnostic and repair, ordering replacement parts for machines and corresponding fixtures, and working closely with the customer to improve test times and cost along with improvements to test procedures. trained and evaluated new test personnel. partnered with other test departments within the production facility to support a wide range of ongoing projects. supervised and provided support to 30+ employees as needed promoted from debug technician to test engineer due to dedication, ability meet deadlines and being able to be available on call. i was laid off from this job due to lack of work.
#
#
# nightshift supervisor/lead test technician
#
# kbm - huntsville, al
#
# -
# january 2004 to june 2005
# directed all functions from the beginning to the end of the operation which included smt wave, hand load, ict test, and fct test, debug, repair, and pack out. supervised, evaluated, and coached an 8 person team while performing my normal duties of test technician which included and wasn't limited to testing, debugging and repairing the product. i quit this job for the opportunity to better my education at sci.
#
#
# refurb technician and lead
#
# palco - huntsville, al
#
# -
# july 2003 to january 2004
# trained personnel on the techniques of refurbishing products to factory guidelines. refurbed, soldered, repaired the product back to functional status according to customer satisfaction. i was laid off from this job due to the lack of work.  skills • associate test engineer (4 years of experience in this position) • engineering test technician (1 year of experience in this position) • functional test technician (3 years of experience in this position) • ict test technician (2 years of experience in this position) • electronic equipment maintenance and repair (6 years of experience in this position)
#
#
# engineering technician
#
# futaba - madison, al
#
# responsibilities test, design, repair test fixtures  skills used trouble shoot and design fixture for boards.
#
#
#
#
# education
#
# computer science
#
# bluefield state college - lewisburg, wv
#
#
#
#
# index:1523 actual:1 predicted:0.0 0.18819243
# ====================================================================
#
#
# greg buehler
# circuit board manufacturing manager of multilayer processes - lone star circuits
#
# rockwall, tx
# -
#
# over 25 years of experience in printed circuit board (psb) manufacturing with excellent work ethic, dependable, adaptable, possessing strong technical and problem solving skills, quickly learning new processes, technologies and machinery.
# authorized to work in the us for any employer
#
#
# work experience
#
#
# circuit board manufacturing manager of multilayer processes
#
# lone star circuits - wylie, tx
#
# -
# february 1999
#
#
# circuit board manufacturing manager shipping
#
# cuplex inc - garland, tx
#
# -
# june 1983 to february 1999
# receiving  •    over 25 years experience in the daily operations and production in printed circuit board manufacturing •    responsible for understanding, interpreting production travelers and application of those instructions for production of circuit boards involving multilayer boards, flex circuits, single sided and double sided assemblies, fine pitch, schematics/blueprints, microscopes and hand tools assembly requiring use of chemicals and working at times within a cleanroom environment. •    adhere to iso9000 procedures of how each area works •    computer literate, with knowledge of paradigm project management and ms office applications •    handled all aspects of lamination, etching, aoi, bond film and punch operating including training new staff and serving as lead and eventually manager of these areas •    excelled in interpreting detailed traveler's schematics, aligning units using text fixtures and proscope measurement software to inspect completed components to ensure conformance to specifications, demonstrating accuracy in the assembly of printed circuit boards, requiring adept precision skills •    analytical, detail-oriented with strong technical and critical-thinking and problem solving skills •    highly focused and results-oriented in supporting complex, deadline-driven operations; •    able to identify goals and priorities and resolve issues in initial stages •    able to analyze technical documentation involving the interpretation of complex instructions and procedures •    performed corrective and weekly preventative maintenance on etching equipment and pre-clean machinery •    adept at developing and maintaining processes that reduce redundancy, improve accuracy and efficiency to achieve organizational goals and objectives •    proficient in document management, operating within an environment for years, managing highly confidential data, materials and information •    demonstrated capability of providing comprehensive support for plant manager, serving as lead and manager over daily production and ensured proper lines of communication were maintained throughout production •    kept inventory list current and eliminated excess inventory to manufacturing and forecasted needs of materials for future production •    responsible for domestic and international shipments of manufactured products, negotiating shipping rates with shipment vendors •    effectively organized and maintained warehouse inventory, responsible for inventory-control in all aspects of warehouse and safety management •    certified fork-lift operator and pallet-jack operator •    ability to prioritize and manage multiple projects simultaneously, effectively handling competing priorities, managing competing demands; able to deal with frequent change, delays, or unexpected events •    self-motivated, able to work independently and multi-task in a fast-paced environment •    energetic, with the ability to interact effectively in a supportive manner with all levels inside and outside of the organization •    developed innovative ways to work smarter with a history of successful implementations of new policies and procedures improving business and production efficiencies •    earned one of the best attendance records in the plant throughout tenure and consistent high marks for meeting quality and productivity goals •    praised for commitment to continuous improvement, predicting assembly problems and suggesting solutions that proved so successful they were adopted throughout the plant
#
#
#
#
# education
#
# diploma
#
# south garland high school
#
# 1980
#
#
#
# additional information
# dear sir or madam:  i have over 25 years of on hands-on experience in the operations and production of printed circuit board manufacturing working in areas of multilayer boards (flex circuits, single and double sided assemblies) and shipping/receiving for both domestic and international shipments.  i am confident that with my work experience and strong work ethic, i would make a strong asset to your team. my core values are integrity, teamwork and a strong commitment to excellence.  i have attached my resume for your review and consideration and would welcome the opportunity for a personal interview, at your earliest convenience, to learn more about the position, and how i can contribute to the company’s continued growth and success. thank you for your time and consideration.  best regards,  greg w. buehler
#
#
# index:2468 actual:0 predicted:1.0 0.82642156
# ====================================================================
#
#
# business manager
# business manager
#
# west chester, pa
# -
#
# authorized to work in the us for any employer
#
#
# work experience
#
#
# business manager
# comfort c'air, inc
# -
# february 2004
# ongoing management of small hvac business. duties include running payroll, accounting reports, tax preparation, expense reports, accounts payable, accounts receivable, etc. works with quickbooks, ms word, ms excel
#
#
# legal assistant
# young &amp; mcgilvery, pc
# -
# february 2008 to september 2012
# administrative and paralegal duties in a medical malpractice defense firm
#
#
# compliance liaison
# eagle national bank
# -
# august 2006 to february 2008
# acts as liaison between the bank and an outside compliance firm to manage kyc and bsa efforts on an on-going basis. review all pertinent reports for five branches for compliance with federal, state and local regulations.
#
#
# branch manager
# eagle national bank
# -
# july 2003 to august 2006
# manage branch with staff of 5, responsible for business development as well as client retention.
#
#
# compliance officer
# us trust company
# -
# october 2001 to december 2002
# administers day to day operations of the pennsylvania office re s pennsylvania and delaware offices in all human resource areas including pre-screening and interviewing potential new employees, payroll and benefits issues, performing background checks, and processing paperwork for new and terminating employees assists compliance officer for the pennsylvania and connecticut offices by maintaining contingency plans for the pennsylvania and delaware offices, maintaining policy and procedure manuals, performing daily, monthly and quarterly audits of trust and banking departments for the pennsylvania office, coordinating investment reviews for all accounts of the pennsylvania office, and maintaining files of completed reviews and audits reviews and monitors daily overdraft reports for pennsylvania, delaware and washington dc offices works with the senior banker and banking administration manager to assure that appropriate reports are filed regarding teller activity, currency transaction reports, suspicious activities, and branch cash flow
#
#
# assistant vice president - operations
# us trust company
# -
# march 2000 to december 2002
#
#
# branch administration manager
# us trust company
# -
# june 1999 to april 2000
# worked with the senior bankers in pennsylvania and connecticut to establish private banking for the pennsylvania office by implementing security procedures, customizing current procedures, and training the client services re ative completed background checks of potential clients opened accounts for clients monitored cash levels of the clients and the branch, completing appropriate federal and corporate forms when applicable
#
#
# branch manager
# prime bank
# -
# may 1993 to june 1999
# october 1998 - june 1999) participated in community and civic organizations to promote goodwill and generate new business supported branch goals as they related to deposit products, loans and referral business assisted in the preparation of financial and regulatory reports required by law and board of directors managed employee appraisal process and coordinated career development activities for the immediate branch staff
#
#
# assistant branch manager
# prime bank
# -
# january 1996 to october 1998
# managed daily operation of branch, including customer service duties related to new accounts, underwriting loans, new business development supervised hiring and training of new employees responsible for assisting branch manager and providing backup to tellers contributed in developing strategic plan for new branches ira department coordinator personal banking re ative teller
#
#
#
#
# education
#
# bachelors of science in business administration
#
# millersville university - millersville, pa
#
#
#
#
# index:2502 actual:1 predicted:0.0 0.0792971
# ====================================================================
#
#
# coordinating vp
#
# zanesville, oh
# -
#
# authorized to work in the us for any employer
#
#
# work experience
#
#
# coordinating vp
#
# j e s basement systems - cumberland, oh
#
# -
# may 2006
# responsibilities in bound and out bound calls, manage several different schedules. payroll, book keeping, employee paper work, word, excel, powerpoint, clerical, manage, set up and work home shows, appointment setting, over seen whole office staff.  manage social media and website presence. payroll assit.  accomplishments notary state of ohio
#
#
# data entry clerk
#
# flex job  - remote
#
# data entry
#
#
# customer service re ative
#
# cardia  - cambridge, oh
#
# -
# june 1998 to september 2005 (7 years, 3 months)
# customer service for resorts
#
#
# customer service
#
# kennedys bakery - cambridge, oh
#
# -
# 1997 to 1998 (1 year)
# cashier making doughnuts and sold doughnuts
#
#
# laborer/helper
#
# lima lite - norwich, oh
#
# -
# april 1996 to april 1997 (1 year)
# cake candles and package them
#
#
# transcription clerk
#
# self employed - cambridge, oh
#
# -
# 2013
# responsibilities transcript from audio.
#
#
# tutor
# cambridge, oh
# responsibilities tutoring elementary children with math and reading.
#
#
# work out of home
#
# self employed - cambridge, oh
#
# responsibilities sewing custom made dresses for on line sales.   also taking pictures and uploading on line with a description of each article. also take personal pictures for family and friends.
#
#
#
#
# education
#
# diploma   in general
#
# general - cambridge, oh
#
# 1994 to 1998
#
#
#
# skills
#
# appointment scheduling, professional phone etiquette, customer service skills, pleasant demeanor, multi-line phone system, databases, quick learner, natural leader, strong customer service skills, bookkeeping (1 year), customer service (10+ years), data entry (1 year), documentation (1 year), word (10+ years), windows xp (2 years), editing (1 year), human resources (1 year), hiring (3 years), management (5 years), marketing (10+ years), notary public (10+ years), office management, sales (10+ years), research (10+ years), typing
#
#
#
# certifications
#
# notary public
# december 2019
#
#
#
# index:3140 actual:0 predicted:1.0 0.93107843
# ====================================================================
#
#
# senator
#
# daly city, ca
# -
#
# skyline college student majoring in psychology seeking a part-time position. aspiring counseling psychologist wanting to provide effective treatment in the healing process of mental health patients. capable, responsible, compassionate, excellent communicator, has experience with various ages and culturally diverse people. recognized as being assertive, enthusiastic and dedicated. proficient in word processing and other systems.
# authorized to work in the us for any employer
#
#
# work experience
#
#
# senator
#
# associated students of skyline college (assc) - san bruno, ca
#
# -
# may 2015
# awarded best student advocate. a re ative of assc and skyline college student population. voted on finances, planned and promoted cultural events advocating learning and cultural diversity. outreached to students. a member of curriculum committee that gave thorough feedback and opinions on newly added skyline college courses.
#
#
# counseling and math assistant internship
#
# hope lutheran church - daly city, ca
#
# -
# june 2011 to july 2014
# awarded most inspirational counselor. supervised and facilitated 40 students for activities, recess and engaged them in learning. motivated peers and campers on team-building, accountability and kindness. assisted campers with first aid kit and resources.
#
#
#
#
# education
#
#
# psychology
#
# skyline college - san bruno, ca
#
# 2014 to
#
#
# high school diploma
#
# westmoor high school - daly city, ca
#
# 2014
#
#
#
#
# skills
#
# microsoft office (6 years), microsoft excel (3 years), event planning (8 years), academic tutor (4 years), fundraising (10+ years), google docs (3 years), student outreach (6 years), community service (7 years), networking (6 years), leadership (6 years), youth outreach (6 years), public speaking (8 years), interpersonal communications (8 years), student advocate (6 years), mental health advocate (6 years), volunteering (6 years), listening (10+ years), teamwork (6 years), team leader (6 years)
#
#
#
# awards
#
#
# most inspirational counselor
# july 2012
# i was awarded this at my summer day camp for my continual efforts with peers, counselors, adults and children with providing a safe space where children could grow.
#
#
# best student advocate
# may 2016
# i was awarded this for re ing and advocating for college students to faculty and fellow senators while serving them during my term.
#
#
# student fundraiser - top 10 seller
# september 2012
# i was a top ten seller out of all the music department at westmoor high school (whs) selling magazines and cookie dough to students, faculty and off-campus. the proceeds went to purchase new instruments for the band, sheet music, uniform storage, music folders and festival entry fees.
#
#
# student fundraiser - top 3 seller
# september 2013
# i was a top three seller in a group out of all the music department at westmoor high school (whs) selling magazines and cookie dough to students, faculty and off-campus. the proceeds went to purchase new instruments for the band, sheet music, uniform storage, music folders and festival entry fees.
#
#
# dean's honors list
# may 2014
# received award fall 2014, spring 2015, fall 2015, and spring 2016.
#
#
#
#
# certifications
#
# mental health first aid
# october 2016 to october 2019
# able to assist until further professional help provided for those with mental illness or disorder with depression, anxiety, psychosis and drug and alcohol addiction.
#
#
#
# additional information
# team and detail-oriented. culturally sensitive. excellent listener and patient. able to follow directions and eager to learn new skills. critical thinker and problem solver. demonstrated clerical and planning skills. honest, attentive, productive, dependable.
#
#
# index:3382 actual:0 predicted:1.0 0.8196309
# ====================================================================
#
#
# inpatient rehabiliation pm&amp;r rt/tr intern
# inpatient rehabiliation pm&amp;r rt/tr intern
#
# san antonio, tx
# -
#
# seeking opportunity to expand my education and experience in therapeutic recreation interventions and assessment and documentation skills, as well as, further my experiences in working with diverse groups of individuals.
# authorized to work in the us for any employer
#
#
# work experience
#
#
# inpatient rehabiliation pm&amp;r rt/tr intern
#
# houston methodist hospital rehabilitation services - houston, tx
#
# -
# august 2016
# * established and maintained professional working relationships * maintained up to 30 patient caseload, and provide rt/tr services utilizing apie process in an efficient and timely manner * uphold hmh icare values and policies * initiate co-treatments with interdisciplinary team members including, pt, ot, &amp; slp for all patient treatment sessions * planned and facilitated in-house group focusing on each pt's individual physical and cognitive goals, however, within a group setting * assisted/co-facilitated community re-entry outings with individual and/or multiple patients including educating on expecations and safety when out in community, and providing physical tasks focused on patient's functional goals for carry-over upon discharge * assisted and co-facilitated animal assisted therapy focusing in individual patients physical and cognitive goals in group setting
#
#
# site supervisor
#
# city of kyle parks and recreation dept - kyle, tx
#
# -
# april 2016 to august 2016
# * planning, coordinating, and supervising programs and activities for the day camp program * staff management, as well as, ensured compliance with required policies, procedures, and regulations, documenting noncompliance as needed * facilitating all required meetings, training, and in-services brought forth * assist in preparing work schedules, and expedite workflow; study and standardize procedures to improve efficiency and effectiveness of operations, and maintain related records and forms process paperwork in an accurate, complete and timely manner * maintain positive interpersonal relations among everyone involved in the day camp program
#
#
# respite care tutor
#
# san marcos cisd special education - san marcos, tx
#
# -
# june 2015 to august 2015
# * provided at home care to special education children * worked on social skills and activities of daily living * provided activities, in home and community settings
#
#
# activity leader
#
# city of san marcos pard - san marcos, tx
#
# -
# may 2015 to august 2015
# * supervised 15-30 children at a time from ages 7-14 * assisted with daily activity coordination and planning * implemented new activities and assisted in teaching staff procedures * assisted in working with children with disabilities and managing behavior * assisted in training other staff in behavior management techniques for children with disabilities * supervised up to 15 children on field trips to various public places
#
#
# server
#
# bj's brewhouse - new braunfels, tx
#
# -
# december 2013 to may 2015
# server * consistently ensured guest satisfaction * performed duties as assigned, while maintaining full knowledge of menus, recipes, and other pertinent information * responsible for constant sanitation, organization, and proper food handling
#
#
# certified server and kitchen trainer
#
# joe's crab shack - austin, tx
#
# -
# march 2012 to september 2013
# supervisor in kitchen and training of new hires
#
#
# lifeguard
#
# city of cedar park pard - cedar park, tx
#
# -
# may 2010 to september 2010
# * learn, remember and administer required skills, such as cpr, ar, first aid, aed and other life saving equipment * maintain a concentrated observation of a given area and persons in area * communicated effectively to enable quick interventions in dangerous situations and to prevent injury to patrons * carried out rescues and initiated necessary emergency action plans rapidly, calmly, and effectively in the event of an injury or patron in distress
#
#
#
#
# education
#
#
# bachelor of science in therapeutic recreation
# texas state university
# march 2017
#
#
# national college
# 2016
#
#
#
#
# awards
#
#
# alpha chi national college honor society
# april 2016
# top 10% of university
#
#
# dean's list
# december 2014
# through december 2016
#
#
# rho phi lambda
# may 2016
# national recreation honor's fraternity
#
#
#
#
# certifications
#
# ctrs-pending
# exam pending- scheduled for march 2017
#
#
#
# additional information
# skills * excellent interpersonal skills, worked in service industry, with many individuals with various levels of abilities, parents, professionals and coworkers * experienced in working effectively with children and adults with physical and cognitive disabilities * microsoft programs such as word, excel, and outlook and powerpoint * driven and organized * able to effectively work independently and interdependently * motivational toward others with great communication skills both verbal and non-verbal * ability to multi-task, perform under pressure, and make adaptations  volunteer efforts &amp; memberships * american therapeutic recreation association- member * texas recreation and parks society-member * association of recreation enthusiasts- texas state university * volunteer: city of san marcos pard special events; san marcos cisd special education; special olympics cell […] • lace.groot@gmail.com 4916 appleseed ct • san antonio, texas • 78238
#
#
# index:3554 actual:1 predicted:0.0 0.16065596
# ====================================================================
#
#
# team lead
#
# terrell, tx
# -
#
# to secure a position within your company that will allow me the ability to utilize my logic, interpersonal, and communication skills.
#
#
# work experience
#
#
# team lead
#
# buc-ee's - terrell, tx
#
# -
# june 2015
# i am responsible for leading a maintenance team to make sure the build clean and well maintained and making sure they doing it in a safe manner. also required register when asked to.
#
#
# aerial lineman
#
# stc utility - balch springs, tx
#
# -
# january 2014 to may 2014
# responsibilities i report to job to get what job site we was required  to work at and get the materials and we would put cable, fiber, coaxial cable.   skills used hard work. fast learner.  punctuality. trustworthiness.
#
#
# valet/parts
#
# sewell lexus - dallas, tx
#
# -
# may 2011 to january 2012
# i valet the customer cars when they arrived and took them to the technicians for they can service them. i delivered parts to the technicians.
#
#
# courtesy clerk/stocker
#
# brookshire's - terrell, tx
#
# -
# may 2008 to july 2010
# i help the customers anyway possible for good customer satisfaction. i restocked the shelves day or night.
#
#
# detention officer
#
# rockwall sheriff dept - rockwall, tx
#
# i was responsible for safety and security of all inmates. i feed, housed, did intake on inmates and did reports.
#
#
#
#
# education
#
#
# emt
#
# mcclennan community college - waco, tx
#
# 2012 to 2013
#
#
# fire protection
#
# mclennan community college waco - waco, tx
#
# 2011 to 2012
#
#
# exercise physiology
#
# baylor university waco - waco, tx
#
# 2010 to 2011
#
#
# diploma
#
# terrell high school - terrell, tx
#
# 2006 to 2010
#
# baylor university and wasn't personally happy
#
#
#
# skills
# customer serivce, computer literate, hard worker, fast learner, don't panic under pressure.
#
#
# additional information
# skills i have very good customer service skills. i get along with anyone and i am very friendly. i can work in any environment. i am a very quick learner. i work well under pressure. i absolutely hate being late to work no matter what situation. i am a people person and i welcome a challenge.
#
#
# index:4623 actual:1 predicted:0.0 0.08201206
# ====================================================================
#
#
# gary sherburne
# machinist 1 - ingersol rand
#
# kent, wa
# -
#
#
#
# work experience
#
#
# machinist 1
#
# ingersol rand - kent, wa
#
# -
# march 2014
# operates an amada ha400 horizontal band saw.  accurately cuts raw metal materials of various sizes and diameters into measured lengths as specified through work orders following the written terminology on work center operations and blue print illustrations.
#
#
# machine shop helper, aerotek staffing
#
# ingersol rand - kent, wa
#
# -
# august 2013 to march 2014
# assist machinist by locating and providing parts needed for order requests, rotating parts using power equipment, or manual pallet jacks from work centers to work centers per work order specification.  services machines upon request of  machinist with coolant and weight oil. housekeeping, painting projects, and other duties assigned as needed.
#
#
# forklift operator
#
# aerotek staffing - seattle, wa
#
# -
# june 2013 to august 2013
# used forklift, pallet jack equipment to expedite palletizing snack food products to staging area in the warehouse for storing tagged and processed for shipment dates.  assisted production staff when needed to package and palletize food snacks when needed.
#
#
# laborer
#
# aerotek staffing - seattle, wa
#
# -
# january 2013 to may 2013
# clean, paint, and stencil logos to 55-gallon drums, and totes used to collect recycled cooking oil.  tools used to perform these tasks are scraping hand tools, electric drill motor with wire brush attachment, pressure washing machine, hand tools for painting, brush, paint roller, paint pan, cleaning degreasing solvent, and air compressed paint sprayer.
#
#
# machine shop helper, aerotek staffing
#
# ingersol rand - kent, wa
#
# -
# june 2012 to december 2012
# assist machinist by locating and providing parts needed for order requests, rotating parts using power equipment, or manual pallet jacks from work centers to work centers per work order specification.  services machines upon request of machinist with coolant and weight oil. housekeeping, painting projects, and other duties assigned as needed.
#
#
# warehouse associate/forklift operator
#
# verizon wireless/aerotek staffing - seattle, wa
#
# -
# december 2009 to june 2012
# assists in maintaining effective and efficient operation for receiving, staging and shipping of inventory. pull and prepare outgoing orders for shipping.  loads outgoing shipments utilizing forklift, pallet jack or manual labor. prepares shipping documentation. unloads incoming shipments. inspects merchandise for damages. labels and scans merchandise into data system. transports merchandise to staging area for delivery or storage. assists in inventory cycle counts.
#
#
# delivery driver
#
# msm construction - seattle, wa
#
# -
# august 2008 to april 2009
# received purchase orders and commuted to variety of vendor sits to purchased materials.   delivered and off loaded materials at construction sites. transported debris from site to transfer station. assisted at construction site as needed. maintained and issued tools and equipment used at work sites.
#
#
# delivery driver
#
# qual fab manufacturing - seattle, wa
#
# -
# september 2007 to may 2008
# packaged and prepared for delivery a variety of custom made items manufactured by this sheet metal fabrication shop. delivered items to customers throughout king and snohomish county area.
#
#
# inventory control clerk
#
# seattle lighthouse for the blind - seattle, wa
#
# -
# january 2005 to july 2007
# performed a variety of warehouse related duties within the production department of this social service organization. loaded/unloaded trucks.  stocked materials in designated area of warehouse.  pulled orders and prepared for shipping. documented incoming and outgoing shipments.  performed regular cycle counts.  maintained daily housekeeping and cleanliness of warehouse area.
#
#
# warehouse associate/delivery driver
#
# sme inc - seattle, wa
#
# -
# november 1998 to may 2004
# performed a variety of warehouse related duties for this electrical contractor. received, counted and recorded shipments of materials and tools.  inspected merchandise for damage. staged items for delivery. loaded truck with materials and delivered to work sites in timely manner. assisted at worksites.
#
#
#
#
# additional information
# qualifications: • highly dependable and motivated individual with strong work ethic offers over fourteen years of experience. • certified forklift operator • excellent written and verbal communication skills • solid computer skills • blue print reading experience • excellent customer service skills • organized and detail oriented individual • productive working either independently or within team environment
#
#
# index:7465 actual:0 predicted:1.0 0.9424017
# ====================================================================
#
#
# baniela johnson, msw, supervisee in social work
# license-eligible clinician (lmhp-s)
#
# north chesterfield, va
# -
#
# license-eligible clinician (lmhp-s) seeking to obtain employment that will diversify my skill-set as lcsw certification is further pursued. 3+ years of experience in mental health, clinical assessments/diagnosis, case management, and crisis intervention. pursuing lcsw certification as approved by the va board of social work in may 2014.
# authorized to work in the us for any employer
#
#
# work experience
#
#
# therapeutic day treatment program director/site lead
# new pathways youth services, inc
# -
# june 2015
# conducted psychotherapy group and individual therapy daily; developed program curriculum for therapeutic day treatment program for 2015-16 school year; provided crisis and supportive counseling for students (client) to enhance their coping and problem solving skills; coordinated clinical assessments/re-assessments for service eligibility/prior authorizations; developed individualized service plans with treatment goals for clients; completed discharge reports as necessary; reviewed/audited client files; provided supervision to case managers; reviewed/authorized case manager's client progress notes.
#
#
# clinical intake assessment specialist
# new pathways youth services, inc
# -
# may 2014 to september 2015
# conducted face-to-face clinical assessments/diagnosis of seriously mental ill individuals upon receiving referrals to determine service eligibility for adult mental health skills building services, intensive in-home services and therapeutic day treatment services; documented clinical assessments, treatment goals, interventions, outcomes, and discharge plans in the client's record aligned with medicaid policies.
#
#
# intake assessment specialist / therapeutic day treatment program director
#
# new pathways youth services, inc - richmond, va
#
# -
# april 2014 to september 2015
#
#
# virginia certified health and physical education teacher
#
# richmond public schools - richmond, va
#
# -
# august 2006 to june 2015
# introduced and engaged students in a variety of physical and health related activities; maintained a safe and orderly classroom that enabled a positive learning environment; implemented district-wide pilot bullying prevention program for richmond public schools (2011-2012); planned and implemented yearly health initiatives for staff, students and parents; developed lesson plans and documented student data to include grade reports; trained students in cpr; served as department chair for the elective department; participated in staff development and attended yearly conferences.
#
#
# intensive in-home counselor
# new pathways youth services, inc
# -
# april 2014 to march 2015
# provided intensive in-home, crisis-oriented counseling and case management to at-risk youth and their families; worked with clients in their homes to foster the development of new and improved coping, problem solving, communication skills and any goals as directly related to the client's individualized treatment plan; developed, implemented and monitored individualized treatment plans in conjunction with referring agencies, other social services professionals, and any stakeholder directly involved in the care of the client and their families served; attended court hearings as necessary for client's directly involved with the richmond juvenile justice system.
#
#
# therapeutic day treatment counselor
# new pathways youth services, inc
# -
# june 2014 to august 2014
# developed program curriculum for summer therapeutic day treatment program; coordinated assessments for service eligibility; developed individualized service plans for clients; provided crisis and supportive counseling for students (client) to enhance their coping and problem solving skills; completed discharge reports as necessary; reviewed/audited client files, and conducted psychotherapy group and individual therapy on a daily basis.
#
#
# intensive in-home counselor
#
# clearr vission support services, inc - richmond, va
#
# -
# may 2012 to april 2014
# provided intensive in-home, crisis-oriented counseling and case management to at-risk youth and their families; worked with clients in their homes to foster the development of new and improved coping, problem solving, communication skills and any goals as directly related to the client's individualized treatment plan; developed, implemented and monitored individualized treatment plans and developed quarterly reports; attended court hearings as necessary for client's directly involved with the richmond juvenile justice system.
#
#
# crisis intervention intern
#
# richmond behavioral health authority - richmond, va
#
# -
# september 2011 to may 2012
# completed intake assessments and assigned triage cases to appropriate rbha units; conducted mental status exams, determined eligibility of temporary detention orders, and provided clinical information to collateral staff; assessed seriously mentally ill individuals as per dsm iv-tr diagnosis in a variety of settings including hospitals, er's, psychiatric units, residential homes and in outdoor public settings; de-escalated crisis situations and developed intervention options and safety plans; provided consultation, information and referral to behavioral healthcare partners in the city of richmond.
#
#
#
#
# education
#
#
# masters of social work in social work
#
# virginia commonwealth university - richmond, va
#
# may 2012
#
#
# bachelor of science in health
#
# virginia state university - petersburg, va
#
# december 2005
#
#
#
#
# skills
#
# social work (3 years), counseling (3 years), teaching (9 years), mental health (3 years), i have experience with utilizing the following counseling therapies: •    psyhcoeducation •    cognitive-behavioral therapy (cbt) •    motivational interviewing •    person-centered therapy •    strengths perspective (3 years)
#
#
#
# certifications
#
# license-eligible clinician (lmhp-s)
#
# cpr / first aid / aed
# july 2016
#
#
# virginia certified teacher
# june 2017
#
#
#
#
# additional information
# cover letter:  to whom it may concern:  i’m a license-eligible clinician (lmhp-s), seeking employment to further enhance my clinical skill set in an effort to assist with obtaining my licensed clinical social worker (lcsw) board certification. i’m currently completing hours towards lcsw certification as approved by the virginia board of social work in may 2014. i have a total of 49 supervision hours remaining towards my lcsw licensure.  my resume, which is enclosed, details my background. although i have been working in the education field for many years, i earned my masters of social work degree in 2012 in an effort to transition careers into the field of social work. as a clinical assessment specialist, crisis intervention worker, mental health counselor, and certified teacher, i have worked with a wide variety of individuals. specifically, i have 3+ years of experience working with adults and adolescents/families with behavioral and mental health challenges.   while enrolled in vcu's master of social work program, i was granted a unique opportunity to work with the richmond city crisis unit (rbha) as an intern under the supervision of mr. robert (bob) durbin. this unique experience allowed me to work with children and adults facing mental health crisis in various settings such as hospitals, residential homes, outdoor public settings, and psychiatric units. in every case, i clinically assessed/diagnosed the individual and addressed their immediate needs. furthermore, my clinical assessment experience as well as my intensive in-home and therapeutic day treatment supervisory experience has allowed me to conduct and document clinical assessments of individuals with serious mental illness, provide individual therapy in the home setting to adults and children suffering from mental illness and behavioral challenges, provide psychotherapy group to children in the school setting, manage caseloads, formulate treatment plans, conduct re-assessments for upcoming annual service authorizations, develop quarterly reports, audit client records, develop program curriculum, provide supervision to case managers as well as participate in juvenile court hearings and provide testimony when required. lastly, my unforgettable three-week travel experience to ghana, west africa with vcu's msw program further provided me with experience on international service efforts to homeless and low-income children and families.  i utilize the following therapies with adults and children: psychoeducation, cognitive-behavioral therapy (cbt), motivational interviewing, person-centered therapy, and the strengths perspective. as a mental health counselor, former teacher and graduate student, as well as a former foster/adopted child of new york city's foster care system, i'm well aware of the importance of strengthening individuals and the family unit. additionally, i understand the importance of aiding individuals in acquiring the appropriate services and resources in order to improve their emotional and physical well-being.  if you're looking for a quick learner and dedicated worker who readily adapts to any environment and is passionate in working with various populations, i strongly believe i am a candidate for this position.   should you have any questions, feel free to contact me at any time via email at: johnsonbj4@gmail.com. i thank you in advance for your consideration with this opportunity.  sincerely,  baniela johnson
#
#
# index:8087 actual:0 predicted:1.0 0.85105264
# ====================================================================
#
#
# charles crawford
#
# corvallis, or
# -
#
# authorized to work in the us for any employer
#
#
# work experience
#
#
# permit technician
#
# the building department llc - eugene, or
#
# -
# april 2013
# answer phone and schedule inspections.  dispatch inspections to field inspectors.  maintain data base for inspections, permits and plan reviews utilizing the building code division's accela/e-permit, an in house proprietary data base called permitpack, and ms excel spreadsheets.  review building plans and permit applications for completeness and compliance with established codes, ordinances, policies, and procedures; process permit applications and plan intake; determine processing needs for projects.  separation of plans into a contractor's copy and a file copy.  copying plan review marks from the contractor's copy to the file copy.  draft and completion of letters requesting more information for incomplete plan reviews.  build strong rapport with county and city hall personnel to facilitate the permit/review/construction and inspection process for the commercial/residential end-user.
#
#
# claims department supervisor
#
# assurant solutions - albany, or
#
# -
# december 2006 to october 2010
# supervise up to 14 regular agents and 2 senior claims re atives.  manage quality and production for the team.  administer and document reviews/recognition and discipline.  organize team meetings and events to build team spirit.  research and resolve supervisor level questions and insurance policy from customers.  participate in management meetings to improve production levels and quality through better business practices.
#
#
# senior claims re ative
#
# signal northwest inc - albany, or
#
# -
# october 2004 to december 2006
# technical support for customer service re atives and escalations. policy support and questions queue. the signal northwest insures wireless cell phone equipment for sprint/nextel
#
#
# farm hand
#
# pugh seed farm, inc - shedd, or
#
# -
# june 2004 to august 2004
# seasonal general farm labor, machinery operation, warehouse duties.
#
#
# customer service
#
# exchangenet inc - corvallis, or
#
# -
# april 2004 to june 2004
# internet signups and connections, helped customers with basic internet and email problems, marketed the exchangenet services.
#
#
# karen pierce, owner
#
# kings blvd seven-eleven - corvallis, or
#
# -
# october 2003 to january 2004
# cash register, retail food and beverage sales.
#
#
# maintenance
#
# burt huddleston - corvallis, or
#
# -
# january 2002 to august 2003
# general labor, yard and property maintenance.
#
#
# support technician
#
# tripod data systems, inc - corvallis, or
#
# -
# august 2000 to november 2001
# under the direction of manager of customer support, researched, resolved, and responded to various customer inquiries received via telephone, email and voice mail.  supported surveying and gps/gis software created for professional licensed surveyors. quality testing of tds software to improve customer service. built a working knowledge of aes products and environment.
#
#
# support technician
#
# advantage energy software - corvallis, or
#
# -
# august 1998 to may 2000
# august 1998 to may 2000 under direction of manager of client services, researched, resolved, and responded to various customer inquiries received via telephone, email and voice mail. resolved technical support issues and concerns of clients relating to unix based aes software and related 3rd party products. quality testing of aes software to improve customer service.  built a working knowledge of aes products and environment, including unix and windows/nt, and third party software used with aes products.  working knowledge of unix and windows/nt hardware configurations, including long distance support and installation of hardware and operating systems.
#
#
# on loan to the staffing specialist for technicians
#
# cdi west corporation - corvallis, or
#
# -
# october 1996 to august 1998
# contracted to hewlett packard corvallis site 815 nw 9th st corvallis or  97330  541-754-3002 coordinator for the direct labor and college intern staffing specialist. on loan to the staffing specialist for technicians. october 1996 to august 1998 with staffing specialist for technicians, assisted in the relocation process of technicians at the corvallis, vancouver, san diego and ft. collins sites.  sourcing of qualified candidates for permanent hire by hewlett packard.  schedule testing and interview times. statistical analysis of candidate pools to insure integrity with the equal employment opportunity act and hewlett packard's commitment to affirmative action. analysis of hiring trends among the hundreds of departments in manufacturing site wide. direct customer service with production and process supervisors and regular full time employees. toured the various clean rooms of manufacturing to gather information for the human resource needs of each department. the staffing department at hewlett packard works as a team to accomplish goals and special projects to meet the obligations of the rapidly changing technology environment. site beta test for the transition and upgrade to oracle data base systems.
#
#
# intern assistant manager
#
# wal-mart stores, inc. 3002 santiam hy - lebanon, or
#
# -
# june 1995 to august 1996
# training as an assistant to the store manager. responsible for up to thirty people per shift. responsible for sales and merchandising on daily basis. trained to both open and close the business. educated in the use and versatility of the world-wide electronic data processing system that the wal-mart uses. schedule and follow tasks for continuous improvement. intense public relations and customer service.
#
#
# assistant office specialist
# college of home economics and education, oregon state university
# -
# october 1994 to june 1996
# assisted in scheduling the dean's national and international agenda.  proofread and screened classified documents and requests for academic grants. dispatch of communication and customer service with faculty and students. intramural coordination and interaction.
#
#
#
#
# education
#
#
# bachelor of science in business administration
#
# oregon state university
#
# august 1996
#
#
# associate of science in business administration
#
# linn-benton community college
#
# august 1994
#
#
# state capitol
#
#
#
#
# skills
#
# administrative assistant (8 years), supervision (6 years)
#
#
#
# additional information
# skills • bachelor of science degree, business administration august 1996 • leadership, supervision, training experience • public relations, collaboration, communication experience
#
#
# index:8461 actual:0 predicted:1.0 0.8465217
# ====================================================================
#
#
# engineering manager
# engineering manager
#
# schaghticoke, ny
# -
#
# authorized to work in the us for any employer
#
#
# work experience
#
#
# engineering manager
#
# pregis, llc - glens falls, ny
#
# -
# 2012
# ...
# index:9040 actual:0 predicted:1.0 0.8095537
# ====================================================================
#
#
# hematology/oncology rn
#
# athens, al
# -
#
#
#
# work experience
#
#
# hematology/oncology rn
#
# children's hospital of orange county - orange, ca
#
# -
# september 2015
# angela holiett, nurse manager  • responsible for the admission and coordination of care and treatment of acute and critical patients with various types of cancer and blood disorders, bone marrow pre and post transplant within a 24 bed unit.  • facilitate and implement physician orders to aid in the completion of patient care with extensive education for adequate discharge process. • administer chemotherapy, blood and/or blood products, harvested stem cells while closely monitoring patients for deteriorating conditions/complications.
#
#
# picu/cardiovascular icu rn
#
# levine's children's hospital - charlotte, nc
#
# -
# january 2015 to august 2015
# diana james, nurse manager  • provide nursing care for critically ill pediatric (infant to teenage) patients in a 12-bed picu and civcu while implementing physicians orders through written and verbal communication.  • solid experience in telemetry, arterial line and central venous pressure monitoring as well as cardiovascular, metabolic, respiratory, neurology and trauma care.
#
#
# picu rn
#
# rady children's hospital - san diego - san diego, ca
#
# -
# april 2014 to january 2015
# jenny shrapnel, nurse manager  • provide nursing care for critically ill pediatric (infant to teenage) patients in a 24-bed picu. • solid experience in telemetry, arterial line and central venous pressure monitoring as well as cardiovascular, metabolic, respiratory, neurology and trauma care.
#
#
# oncology/hematology rn
#
# children's of alabama - birmingham, al
#
# -
# january 2012 to december 2014
# stacy flanagan, nurse manager  • responsible for the care and treatment of acute and critical patients with various types of cancer and blood disorders within a 24 bed unit. • administer chemotherapy, blood and/or blood products while closely monitoring patients for deteriorating conditions/complications.
#
#
# neonatal rn
#
# children's hospital of vanderbilt - nashville, tn
#
# -
# june 2011 to january 2012
# shelly shanks rn, assistant manager of neonatal and newborn service  • the intermediate and special care to newborns having serious neurological disorder, physical complications/deformities, ventilator/jet/oscillator dependent, cardiac abnormalities or those terminally ill in a level iii facility.
#
#
# field rn
#
# athens-limestone home care - athens, al
#
# -
# january 2011 to september 2011
# tina campbell rn, team leader  • perform independent health assessments of individuals and families by evaluating their physical, mental and social and environmental health status; and provide nursing intervention based on assessment of need. • make skilled nursing observations and assessments of client health care status by monitoring and documenting such things as vital signs, pulse, presence of edema, heart and lung auscultation, blood and urine laboratory values, intake and output, consciousness and orientation levels; by completing a health history and evaluation, and evaluating living arrangements. • provide case management for clients by developing care plans, consulting with other health care providers such as physicians and social workers, referring clients to other.
#
#
# pediatric/adult emergency room rn
#
# wesley medical center - wichita, ks
#
# -
# august 2010 to november 2010
# tammy northrope, rnm of adult and pediatric emergency department  • provide emergency medical care to an average of 20 critically ill patients per shift within a 40-bed emergency services department. • ensure the provision of quality emergency medical care to patients requiring emergency treatment in accordance with physician orders, hospital policy, and standard nursing practice.
#
#
# women's and children's float rn
#
# huntsville hospital - huntsville, al
#
# -
# march 2007 to october 2010
# stephanie mccrary, rnm of pediatrics and women/children float pool  pediatric unit: • provide total patient care on a 40 bed intermediate and pre/post-surgical unit for children ages newborn through 19years. • patient assessments and vital signs, medication administration(including careful checking of dosages and avoiding interactions), starting, maintaining, and discontinuing intravenous (iv) lines for fluid, central line access and management, medication, blood, and blood products, sterile dressing change and wound care management. • care/discharge planning with individualizes nursing interventions along with patient/family education.  neonatal icu: • assessment and treatment of neonates, level ii and iii. • provide special care such as supplemental oxygen placement, specialized feeding, intravenous medications and fluid maintenance, obtaining blood specimen collections via arterial, venous or heel sticks.  pediatric icu: • provide nursing care for critically ill pediatric (infant to teenage) patients in a 15-bed picu. • assist ventilator dependent patients. • solid experience in telemetry, arterial line and central venous pressure monitoring as well as cardiovascular, metabolic, neurology and trauma care.  pediatric er: • evaluate, triage and treatment of pediatric patients  ing in level 1, 2, 3 and 4 trauma situations. • perform emergency medical treatments/procedures needed in fast-paced, stressful and tense situations. • work closely as a team player with physicians and/or other healthcare staff to ensure optimal patient care. • coordinate patient referrals and discharge planning activities. • prepare and assist in critical patient transports to outlying facilities.  adult surgical: • patient care and assessment for ent, obstetrical, plastic reconstruction and other post surgical patient recovery. • frequent dressing application and removal involving sterile and non-sterile techniques.  maternal/child: • provide well baby nursery and postpartum care on a 32 bed unit. • assist new mothers struggling with breast feeding, . • procedure assistance and aftercare related to circumcisions. • thoroughly trained in measuring fundal height, uterine massage, steps and procedures to take when excessive bleeding  , monitoring high risk, c-section patients.
#
#
#
#
# education
#
#
# bachelors of science in nursing
#
# university of alabama in huntsville - huntsville, al
#
# august 2010 to may 2012
#
#
# associate of science in nursing
#
# john c. calhoun college - decatur, al
#
# may 2004 to may 2007
#
#
#
#
# index:9638 actual:0 predicted:1.0 0.82539517
# ====================================================================
#
#
# chaplain
# lead chaplain
#
# loma linda, ca
# -
#
# willing to relocate: anywhere
# authorized to work in the us for any employer
#
#
# work experience
#
#
# chaplain
#
# redlands community hospital - redlands, ca
#
# -
# august 2012
# responsibilities provided ministry to all patients, families, and staff, according to their spiritual needs. managed a volunteer staff of chaplains, pastoral care givers, eucharistic ministers and no one dies along participants. established a network of outside clergy to serve the hospital and participated in local clergy associations. performed religious services. attended idt’s, bioethics meetings, palliative care consults, and crisis intervention/sentinel events. conducted bi-weekly behavioral health groups, quarterly grief groups, and in-services as needed. provided 24/7 coverage for er, icu, ob, nicu, pacu, and telemetry.
#
#
# hospice chaplain
#
# family hospice care - palm springs, ca
#
# -
# july 2009 to february 2012 (2 years, 7 months)
# provide group and individual bereavement counseling and spiritual support to patients and care givers on hospice at home, b&amp;c's, and snf's. interview each patient and care giver for a spiritual assessment, identify spiritual needs, and create a plan of care. facilitate grief groups for care givers and provide religious ceremonies. provide training and oversight for volunteers. collaborate with interdisciplinary team in crisis intervention with patients and care givers as needed.
#
#
# on call chaplain
#
# vitas innovative hospice - san bernardino, ca
#
# -
# december 2008 to october 2009 (10 months)
# assist in death visits, medication disposal, bedside end of life counseling, and new patient admits. assist interdisciplinary team in crisis intervention. visit patients and family members to provide for their spiritual needs.
#
#
# palliative care chaplain
#
# providence holy cross medical center - mission hills, ca
#
# -
# august 2008 to july 2009 (11 months)
# visit all dying patients to provide spiritual and emotional support for patients, families, and staff.  facilitate liturgical services and memorial services. assist with interdisciplinary team in and crisis intervention, dnr's, and advance directives. assist volunteer staff with the "no one dies alone" program.
#
#
# chaplain resident
#
# st mary's medical center - san francisco, ca
#
# -
# august 2007 to june 2008 (10 months)
# 3 cpe units) provide full time and on-call chaplain coverage in er, icu, and the oncology unit. i specialized in providing pastoral care to palliative care and actively dying patients and their families. offer spiritual and emotional support for patients, families, and staff. facilitate liturgical services and memorial services.
#
#
# chaplain resident
#
# hospital of university of pennsylvania/ inglis' house - philadelphia, pa
#
# -
# june 2002 to august 2002 (2 months)
# 1 cpe unit) provide spiritual counseling at a 297 bed snf, with a population made up of wheelchair bound multiple sclerosis, spinal cord injury, and cerebral palsy patients. the majority of my work dealt with transitions of patients to different levels of care, e.g. from wheelchair to bedridden. provide memorial services, individual bereavement counseling and led bereavement groups weekly.
#
#
# pastoral intern
#
# lower merion baptist church - bryn mawr, pa
#
# -
# september 2001 to june 2002 (9 months)
# provide pastoral care the students of bryn mawr college along with a weekly bible study. conduct funerals, weekday bible study, sunday school, and sunday worship services. made weekly visitations to home bound church members for pastoral support.  relevant experience
#
#
#
#
# education
#
#
# master of divinity
#
# eastern baptist theological seminary - philadelphia, pa
#
# 2003
#
#
# bs in criminology
#
# university of la verne - la verne, ca
#
# 2000
# index:11027 actual:0 predicted:1.0 0.8569336
# ====================================================================
#
#
# pacs analyst i
#
# o'fallon, mo
# -
#
# information technology professional with 11 year’s experience with installing and supporting multiple operating systems including, window xp, windows 7, windows server 2008, linux, solaris. able to adapt quickly and  learn new systems and to trouble-shoot difficult issues.  able to work well with a team or by myself.  excellent communication skills both verbal and written.  proficient at following procedures with minimal supervision. able to  maintain a balance between customer focused activities and proactively solving many ongoing issues.  coordinated and managed installation of multiple cardiology and radiology systems demonstrating project management skills such as planning, scheduling, organizing, and tracking. supported and managed medical imaging networks, including windows servers and workstations.  administered user accounts in a windows server enterprise and trained users on various vendor specific systems.  multitasked between leading projects and resolving customer issues in a fast paced environment
#
#
# work experience
#
#
# pacs analyst i
# bjc health system/missouri baptist medical center
# -
# june 2007
# •installed and configured window servers for vendor specific needs. •installed and maintained vendor software on windows servers and workstations. •worked with networking team to trouble shoot network issues and ensure quality service. •used applications to parse network data packets to find root cause of network issues. •first line customer support for resolving customer issues.   •multi-tasking was required to handle projects and customer issues. •managed patient data issues by researching clinical data and updating patient database. •worked with vendors to resolve configuration issues and tested software and advised on bug fixes. •lead team projects for installations of software upgrades and migrating data to ensure timely delivery of software. •designed and implemented training programs for end users to ensure understanding of vendor software usage. •managed user accounts on windows servers for end user access. •performed ms sql queries to search and update databases •resolved end user problems with windows workstations by communicating with customer by troubleshooting issue to the root cause in order to fix the problem. •set up meetings with end users to ensure customer satisfaction and quality assurance. •managed desktop computers, laptops, related peripheral and printers.
#
#
# pacs specialist/project manager
# scimage
# -
# september 2004 to may 2007
# •assisted in design and implementation of pacs installations  •documented work flow of patient information and provide detailed site diagrams  •lead projects to coordinate and manage the installation of customers windows servers and workstations. •troubleshot network dicom and hl7 connectivity issues •main point of contact for customers to triage end user issues and bring them to resolution •maintained and updated customers windows servers and workstations  •implemented field upgrades on existing windows software and vendor specific software. •provided training and support to customers and sales re atives  •first line customer support for resolving customer issues.   •troubleshot network issues and used software to sniff network packets to find the root cause of connectivity issues •ran ms sql queries to search and update databases
#
#
# field service engineer
# eastman kodak company
# -
# january 2001 to september 2004
# •coordinated and installed pacs networks for health imaging division  •performed routine maintenance checks for pacs servers and archives  •supported customers through remote and on site service  •diagnosed and resolved network issues pertaining to pacs equipment  •set up and troubleshot new and existing dicom connections  •ensured customer satisfaction maintenance through verbal and written communication  •provided 24x7 support to customers to ensure customer satisfaction
#
#
# field service engineer
# hitachi medical systems of america
# -
# july 1999 to january 2001
# •performed routine preventative maintenance on open mri scanners  •provided emergency maintenance as necessary  •responsible for installing and upgrading product changes  •managed and assisted with new equipment installations  •evaluated sites and analyze test data for potential equipment placement  •responsible for personal inventory of tools and test equipment
#
#
#
#
# education
#
#
# master of business administration
#
# lindenwood university st charles - saint charles, mo
#
# april 2000 to june 2004
#
#
# bachelor of science in electronics engineering technology
#
# devry institute of technology kansas city - kansas city, mo
#
# february 1999 to april 2000
#
#
# master in information systems management
#
# webster university st. louis - st. louis, mo
#
# april 2000

# %%
train_lstm_rnn(5, 300, 'plain_data', 400, "adam", 0.1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 400)               0
# _________________________________________________________________
# embedding_3 (Embedding)      (None, 400, 300)          83066400
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 400, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_3 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                6050
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 83,245,781
# Trainable params: 179,381
# Non-trainable params: 83,066,400
# _________________________________________________________________
# Train on 29968 samples, validate on 3330 samples
# Epoch 1/5
# 29968/29968 [==============================] - 527s 18ms/step - loss: 0.6658 - acc: 0.5943 - cosine_proximity: -0.5752 - f1: 0.6958 - val_loss: 0.6660 - val_acc: 0.5940 - val_cosine_proximity: -0.5796 - val_f1: 0.6240
# Epoch 2/5
# 29968/29968 [==============================] - 504s 17ms/step - loss: 0.6500 - acc: 0.6260 - cosine_proximity: -0.5752 - f1: 0.7050 - val_loss: 0.6517 - val_acc: 0.6246 - val_cosine_proximity: -0.5796 - val_f1: 0.7303
# Epoch 3/5
# 29968/29968 [==============================] - 507s 17ms/step - loss: 0.6365 - acc: 0.6414 - cosine_proximity: -0.5752 - f1: 0.7114 - val_loss: 0.6434 - val_acc: 0.6378 - val_cosine_proximity: -0.5796 - val_f1: 0.6994
# Epoch 4/5
# 29968/29968 [==============================] - 524s 18ms/step - loss: 0.6239 - acc: 0.6544 - cosine_proximity: -0.5752 - f1: 0.7189 - val_loss: 0.6424 - val_acc: 0.6273 - val_cosine_proximity: -0.5796 - val_f1: 0.6521
# Epoch 5/5
# 29968/29968 [==============================] - 566s 19ms/step - loss: 0.6122 - acc: 0.6682 - cosine_proximity: -0.5752 - f1: 0.7268 - val_loss: 0.6254 - val_acc: 0.6616 - val_cosine_proximity: -0.5796 - val_f1: 0.7123
# classification F score: 0.67894

# %%
def print_wrong_examples_xml(pred, actual, details = True, all_results = False):
    count = 0
    for index, value in enumerate(pred):
        if (actual[index] != round(value[0])) and (abs(actual[index] - value[0]) > 0.8):
            print("index:" + str(index) + " actual:" + str(actual[index].astype(int)) + " predicted:" + str(round(value[0])) + " " + str(value[0]))
            if (details):
                print('====================================================================')
                print(test_data_['data'][index])
            count += 1
        if (count > 10) and not all_results:
            break


print_wrong_examples_xml(model_predictions['CO:800, E:10, data, adam'], predictors_test['work_stayed'].astype(int), True, True)
# Out:
# index:330 actual:1 predicted:0.0 0.117833495
# ====================================================================
# <div class="vcard single_form-content" id="resume_body">
# <div class="last basicinfo-content" id="basic_info_row"><div class="data_display" id="basic_info_cell">
# <h1 class="fn " id="resume-contact" itemprop="name">paul heatherly</h1>
# <h2 id="headline" itemprop="jobtitle">engineering technician</h2>
# <div id="contact_info_container">
# <div class="adr" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><p class="locality" id="headline_location" itemprop="addresslocality">corinth, ms</p></div>
# <div class="separator-hyphen">-</div>
# </div>
# <p class="summary" id="res_summary">to obtain productive employment in my field of experiences</p>
# <p id="relocation_status">willing to relocate: anywhere</p>
# <p id="employment_eligibility">authorized to work in the us for any employer</p>
# </div></div>
# <div class="section-item workexperience-content">
# <div><div class="section_title"><h2>work experience</h2></div></div>
# <div class="items-container" id="work-experience-items">
# <div class="work-experience-section " id="workexperience-eeyov4fusqeudln7osniyg"><div class="data_display">
# <p class="work_title title">test engineer</p>
# <div class="work_company"    =""  >
# <span class="bold" itemprop="name">masterpiece engineer</span> <div class="separator-hyphen">-</div> <div class="inline-block" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">corinth, ms</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# june 2015
# <p class="work_description">responsibilities <br/>wiring test fixtures. troubleshooting test fixtures</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eete4agqo8swseibfzyckw"><div class="data_display">
# <p class="work_title title">engineering technician</p>
# <div class="work_company"    =""  >
# <span class="bold" itemprop="name">futaba</span> <div class="separator-hyphen">-</div> <div class="inline-block" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">madison, al</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">january 2014 to  </p>
# <p class="work_description">responsibilities <br/>design, repair, and maintain the running of test fixtures. <br/> <br/>accomplishments <br/>ability to meet the demands of the company and increase customer satisfaction. <br/> <br/>skills used <br/>troubleshooting and repair.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eenk3izt46mqpl9olxgqwg"><div class="data_display">
# <p class="work_title title">electronic technician</p>
# <div class="work_company"    =""  >
# <span class="bold" itemprop="name">lg</span> <div class="separator-hyphen">-</div> <div class="inline-block" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">huntsville, al</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">december 2013 to  </p>
# <p class="work_description">responsibilities <br/>debug equipment, order and replace parts. <br/> <br/>accomplishments <br/>ability to fix problems increasing output <br/> <br/>skills used <br/>excellent troubleshooting skills</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eenk3byf2_yqpl9olxgqwg"><div class="data_display">
# <p class="work_title title">extrusion operator</p>
# <div class="work_company">
# <span class="bold">ilpea</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>hartselle, al</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">october 2012 to october 2013</p>
# <p class="work_description">responsibilities <br/>run and maintain extrusion machinery.  made rubber gaskets. <br/> <br/>accomplishments <br/>exceeded output  <br/> <br/>skills used <br/>ability to fix machinery problems using personal tools</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eehjutryeykcozvroz8ufq"><div class="data_display">
# <p class="work_title title">engineering technician</p>
# <div class="work_company"><span class="bold">ctdi</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">october 2010 to july 2011</p>
# <p class="work_description">responsible for <br/>i was responsible for rma debug and repair for alloptics communication line of product. i also did there test, debug, repair, and software for their new production as well. while at this job i acted as associate test engineer as well as my normal duties. in which i assisted in building test sets platforms and programs for other communication devises for other company products. i also assisted in difficult debug and repairs of other products in the company. i was laid off due to lack of work.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eehjutryeyocozvroz8ufq"><div class="data_display">
# <p class="work_title title">test engineer</p>
# <div class="work_company">
# <span class="bold">sanmina-sci</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>huntsville, al</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">june 2005 to february 2010</p>
# <p class="work_description">performed circuit and component level troubleshooting on diagnostic test equipment. identified malfunctioning components and replaced as necessary. utilized required test equipment to perform job responsibilities. read and interpreted schematics and diagnostic manuals. assisted engineering staff in troubleshooting and diagnosing problems with new product designs. <br/>performed functional test fixture maintenance, fixture diagnostic and repair, ordering replacement parts for machines and corresponding fixtures, and working closely with the customer to improve test times and cost along with improvements to test procedures. trained and evaluated new test personnel. <br/>partnered with other test departments within the production facility to support a wide range of ongoing projects. supervised and provided support to 30+ employees as needed <br/>promoted from debug technician to test engineer due to dedication, ability meet deadlines and being able to be available on call. i was laid off from this job due to lack of work.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eehjutryeyscozvroz8ufq"><div class="data_display">
# <p class="work_title title">nightshift supervisor/lead test technician</p>
# <div class="work_company">
# <span class="bold">kbm</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>huntsville, al</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">january 2004 to june 2005</p>
# <p class="work_description">directed all functions from the beginning to the end of the operation which included smt wave, hand load, ict test, and fct test, debug, repair, and pack out. <br/>supervised, evaluated, and coached an 8 person team while performing my normal duties of test technician which included and wasn't limited to testing, debugging and repairing the product. i quit this job for the opportunity to better my education at sci.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eehjutryeywcozvroz8ufq"><div class="data_display">
# <p class="work_title title">refurb technician and lead</p>
# <div class="work_company">
# <span class="bold">palco</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>huntsville, al</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">july 2003 to january 2004</p>
# <p class="work_description">trained personnel on the techniques of refurbishing products to factory guidelines. <br/>refurbed, soldered, repaired the product back to functional status according to customer satisfaction. i was laid off from this job due to the lack of work. <br/> <br/>skills <br/>• associate test engineer (4 years of experience in this position) <br/>• engineering test technician (1 year of experience in this position) <br/>• functional test technician (3 years of experience in this position) <br/>• ict test technician (2 years of experience in this position) <br/>• electronic equipment maintenance and repair (6 years of experience in this position)</p>
# </div></div>
# <div class="work-experience-section last" id="workexperience-eete4lg8fcgrjspalk2pyg"><div class="data_display">
# <p class="work_title title">engineering technician</p>
# <div class="work_company">
# <span class="bold">futaba</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>madison, al</span></div>
# </div>
# <p class="work_description">responsibilities <br/>test, design, repair test fixtures <br/> <br/>skills used <br/>trouble shoot and design fixture for boards.</p>
# </div></div>
# </div>
# </div>
# <div class="section-item education-content">
# <div><div class="section_title"><h2>education</h2></div></div>
# <div class="items-container" id="education-items"><div class="education-section last" id="education-eehjutryeyecozvroz8ufq"><div class="data_display" itemprop="alumniof"  ="" itemtype="http://schema.org/educationalorganization">
# <p class="edu_title">computer science</p>
# <div class="edu_school">
# <span class="bold" itemprop="name">bluefield state college</span> - <div class="inline-block" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">lewisburg, wv</span></div>
# </div>
# </div></div></div>
# </div>
# </div>
# index:1523 actual:1 predicted:0.0 0.18819243
# ====================================================================
# <div class="vcard single_form-content" id="resume_body">
# <div class="last basicinfo-content" id="basic_info_row"><div class="data_display" id="basic_info_cell">
# <h1 class="fn " id="resume-contact" itemprop="name">greg buehler</h1>
# <h2 id="headline" itemprop="jobtitle">circuit board manufacturing manager of multilayer processes - lone star circuits</h2>
# <div id="contact_info_container">
# <div class="adr" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><p class="locality" id="headline_location" itemprop="addresslocality">rockwall, tx</p></div>
# <div class="separator-hyphen">-</div>
# </div>
# <p class="summary" id="res_summary">over 25 years of experience in printed circuit board (psb) manufacturing with excellent work ethic, dependable, adaptable, possessing strong <br/>technical and problem solving skills, quickly learning new processes, technologies and machinery.</p>
# <p id="employment_eligibility">authorized to work in the us for any employer</p>
# </div></div>
# <div class="section-item workexperience-content">
# <div><div class="section_title"><h2>work experience</h2></div></div>
# <div class="items-container" id="work-experience-items">
# <div class="work-experience-section " id="workexperience-eeub-jucx62ghnssdbw1fw"><div class="data_display">
# <p class="work_title title">circuit board manufacturing manager of multilayer processes</p>
# <div class="work_company"    =""  >
# <span class="bold" itemprop="name">lone star circuits</span> <div class="separator-hyphen">-</div> <div class="inline-block" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">wylie, tx</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# february 1999
# </div></div>
# <div class="work-experience-section last" id="workexperience-eeub-juchr6ghnssdbw1fw"><div class="data_display">
# <p class="work_title title">circuit board manufacturing manager shipping</p>
# <div class="work_company">
# <span class="bold">cuplex inc</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>garland, tx</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">june 1983 to february 1999</p>
# <p class="work_description">receiving <br/> <br/>•    over 25 years experience in the daily operations and production in printed circuit board manufacturing <br/>•    responsible for understanding, interpreting production travelers and application of those instructions for production of circuit boards <br/>involving multilayer boards, flex circuits, single sided and double sided assemblies, fine pitch, schematics/blueprints, microscopes and hand tools assembly requiring use of chemicals and working at times within a cleanroom environment. <br/>•    adhere to iso9000 procedures of how each area works <br/>•    computer literate, with knowledge of paradigm project management and ms office applications <br/>•    handled all aspects of lamination, etching, aoi, bond film and punch operating including training new staff and serving as lead and eventually manager of these areas <br/>•    excelled in interpreting detailed traveler's schematics, aligning units using text fixtures and proscope measurement software to inspect <br/>completed components to ensure conformance to specifications, demonstrating accuracy in the assembly of printed circuit boards, <br/>requiring adept precision skills <br/>•    analytical, detail-oriented with strong technical and critical-thinking and problem solving skills <br/>•    highly focused and results-oriented in supporting complex, deadline-driven operations; <br/>•    able to identify goals and priorities and resolve issues in initial stages <br/>•    able to analyze technical documentation involving the interpretation of complex instructions and procedures <br/>•    performed corrective and weekly preventative maintenance on etching equipment and pre-clean machinery <br/>•    adept at developing and maintaining processes that reduce redundancy, improve accuracy and efficiency to achieve organizational <br/>goals and objectives <br/>•    proficient in document management, operating within an environment for years, managing highly confidential data, materials and information <br/>•    demonstrated capability of providing comprehensive support for plant manager, serving as lead and manager over daily production and ensured proper lines of communication were maintained throughout production <br/>•    kept inventory list current and eliminated excess inventory to manufacturing and forecasted needs of materials for future production <br/>•    responsible for domestic and international shipments of manufactured products, negotiating shipping rates with shipment vendors <br/>•    effectively organized and maintained warehouse inventory, responsible for inventory-control in all aspects of warehouse and safety <br/>management <br/>•    certified fork-lift operator and pallet-jack operator <br/>•    ability to prioritize and manage multiple projects simultaneously, effectively handling competing priorities, managing competing <br/>demands; able to deal with frequent change, delays, or unexpected events <br/>•    self-motivated, able to work independently and multi-task in a fast-paced environment <br/>•    energetic, with the ability to interact effectively in a supportive manner with all levels inside and outside of the organization <br/>•    developed innovative ways to work smarter with a history of successful implementations of new policies and procedures improving <br/>business and production efficiencies <br/>•    earned one of the best attendance records in the plant throughout tenure and consistent high marks for meeting quality and productivity goals <br/>•    praised for commitment to continuous improvement, predicting assembly problems and suggesting solutions that proved so successful they were adopted throughout the plant</p>
# </div></div>
# </div>
# </div>
# <div class="section-item education-content">
# <div><div class="section_title"><h2>education</h2></div></div>
# <div class="items-container" id="education-items"><div class="education-section last" id="education-eeub-jucrc-ghnssdbw1fw"><div class="data_display" itemprop="alumniof"  ="" itemtype="http://schema.org/educationalorganization">
# <p class="edu_title">diploma</p>
# <div class="edu_school">
# <span class="bold" itemprop="name">south garland high school</span><div class="inline-block" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality"></span></div>
# </div>
# <p class="edu_dates">1980</p>
# </div></div></div>
# </div>
# <div class="section-item additionalinfo-content">
# <div><div class="section_title"><h2>additional information</h2></div></div>
# <div class="items-container" id="additionalinfo-items"><div class="last" id="additionalinfo-section"><div class="data_display"><p>dear sir or madam: <br/> <br/>i have over 25 years of on hands-on experience in the operations and production of printed <br/>circuit board manufacturing working in areas of multilayer boards (flex circuits, single and <br/>double sided assemblies) and shipping/receiving for both domestic and international shipments. <br/> <br/>i am confident that with my work experience and strong work ethic, i would make a strong asset to your team. my core values are integrity, teamwork and a strong commitment to excellence. <br/> <br/>i have attached my resume for your review and consideration and would welcome the <br/>opportunity for a personal interview, at your earliest convenience, to learn more about the position, and how i can contribute to the company’s continued growth and success. thank you for your time and consideration. <br/> <br/>best regards, <br/> <br/>greg w. buehler</p></div></div></div>
# </div>
# </div>
# index:2468 actual:0 predicted:1.0 0.82642156
# ====================================================================
# <div class="vcard single_form-content" id="resume_body">
# <div class="last basicinfo-content" id="basic_info_row"><div class="data_display" id="basic_info_cell">
# <h1 class="fn " id="resume-contact" itemprop="name">business manager</h1>
# <h2 id="headline" itemprop="jobtitle">business manager</h2>
# <div id="contact_info_container">
# <div class="adr" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><p class="locality" id="headline_location" itemprop="addresslocality">west chester, pa</p></div>
# <div class="separator-hyphen">-</div>
# </div>
# <p id="employment_eligibility">authorized to work in the us for any employer</p>
# </div></div>
# <div class="section-item workexperience-content">
# <div><div class="section_title"><h2>work experience</h2></div></div>
# <div class="items-container" id="work-experience-items">
# <div class="work-experience-section " id="workexperience-eexzjqhqyg2sgrr4fpmhqa"><div class="data_display">
# <p class="work_title title">business manager</p>
# <div class="work_company"><span class="bold">comfort c'air, inc</span></div>
# <div class="separator-hyphen">-</div>
# february 2004
# <p class="work_description">ongoing management of small hvac business. duties include running payroll, accounting reports, tax preparation, expense reports, accounts payable, accounts receivable, etc. works with quickbooks, ms word, ms excel</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eexzjqhq736sgrr4fpmhqa"><div class="data_display">
# <p class="work_title title">legal assistant</p>
# <div class="work_company"><span class="bold">young &amp; mcgilvery, pc</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">february 2008 to september 2012</p>
# <p class="work_description">administrative and paralegal duties in a medical malpractice defense firm</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eexzjqhrfo-sgrr4fpmhqa"><div class="data_display">
# <p class="work_title title">compliance liaison</p>
# <div class="work_company"><span class="bold">eagle national bank</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">august 2006 to february 2008</p>
# <p class="work_description">acts as liaison between the bank and an outside compliance firm to manage kyc and bsa efforts on an on-going basis. review all pertinent reports for five branches for compliance with federal, state and local regulations.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eexzjqhrpagsgrr4fpmhqa"><div class="data_display">
# <p class="work_title title">branch manager</p>
# <div class="work_company"><span class="bold">eagle national bank</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">july 2003 to august 2006</p>
# <p class="work_description">manage branch with staff of 5, responsible for business development as well as client retention.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eexzjqhrzlksgrr4fpmhqa"><div class="data_display">
# <p class="work_title title">compliance officer</p>
# <div class="work_company"><span class="bold">us trust company</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">october 2001 to december 2002</p>
# <p class="work_description">administers day to day operations of the pennsylvania office <br/>re s pennsylvania and delaware offices in all human resource areas including pre-screening and interviewing potential new employees, payroll and benefits issues, performing background checks, and processing paperwork for new and terminating employees assists compliance officer for the pennsylvania and connecticut offices by maintaining contingency plans for the <br/>pennsylvania and delaware offices, maintaining policy and procedure manuals, performing daily, monthly and quarterly audits of trust and banking departments for the pennsylvania office, coordinating investment reviews for all accounts of the pennsylvania office, and maintaining files of completed reviews and audits reviews and monitors daily overdraft reports for pennsylvania, delaware and washington dc offices works with the senior banker and banking administration <br/>manager to assure that appropriate reports are filed regarding teller activity, currency transaction reports, suspicious activities, and branch cash flow</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eexzjqhrzlosgrr4fpmhqa"><div class="data_display">
# <p class="work_title title">assistant vice president - operations</p>
# <div class="work_company"><span class="bold">us trust company</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">march 2000 to december 2002</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eexzjqhri8ssgrr4fpmhqa"><div class="data_display">
# <p class="work_title title">branch administration manager</p>
# <div class="work_company"><span class="bold">us trust company</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">june 1999 to april 2000</p>
# <p class="work_description">worked with the senior bankers in pennsylvania and connecticut to establish private banking for the pennsylvania office by implementing security procedures, customizing current procedures, and training the client services re ative completed background checks of potential clients <br/>opened accounts for clients monitored cash levels of the clients and the branch, <br/>completing appropriate federal and corporate forms when applicable</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eexzjqhrstwsgrr4fpmhqa"><div class="data_display">
# <p class="work_title title">branch manager</p>
# <div class="work_company"><span class="bold">prime bank</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">may 1993 to june 1999</p>
# <p class="work_description">october 1998 - june 1999) <br/>participated in community and civic organizations to promote goodwill and generate new business <br/>supported branch goals as they related to deposit products, loans and referral business <br/>assisted in the preparation of financial and regulatory reports required by law and board of directors <br/>managed employee appraisal process and coordinated career development activities for the immediate branch staff</p>
# </div></div>
# <div class="work-experience-section last" id="workexperience-eexzjqhrstasgrr4fpmhqa"><div class="data_display">
# <p class="work_title title">assistant branch manager</p>
# <div class="work_company"><span class="bold">prime bank</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">january 1996 to october 1998</p>
# <p class="work_description">managed daily operation of branch, including customer service duties related to new accounts, underwriting loans, new business development supervised hiring and training of new employees <br/>responsible for assisting branch manager and providing backup to tellers contributed in developing strategic plan for new branches <br/>ira department coordinator <br/>personal banking re ative <br/>teller</p>
# </div></div>
# </div>
# </div>
# <div class="section-item education-content">
# <div><div class="section_title"><h2>education</h2></div></div>
# <div class="items-container" id="education-items"><div class="education-section last" id="education-eexzjqhr2eesgrr4fpmhqa"><div class="data_display" itemprop="alumniof"  ="" itemtype="http://schema.org/educationalorganization">
# <p class="edu_title">bachelors of science in business administration</p>
# <div class="edu_school">
# <span class="bold" itemprop="name">millersville university</span> <div class="separator-hyphen">-</div> <div class="inline-block" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">millersville, pa</span></div>
# </div>
# </div></div></div>
# </div>
# </div>
# index:2502 actual:1 predicted:0.0 0.0792971
# ====================================================================
# <div class="vcard single_form-content" id="resume_body">
# <div class="last basicinfo-content" id="basic_info_row"><div class="data_display" id="basic_info_cell">
# <h1 class="fn " id="resume-contact" itemprop="name">coordinating vp</h1>
# <div id="contact_info_container">
# <div class="adr" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><p class="locality" id="headline_location" itemprop="addresslocality">zanesville, oh</p></div>
# <div class="separator-hyphen">-</div>
# </div>
# <p id="employment_eligibility">authorized to work in the us for any employer</p>
# </div></div>
# <div class="section-item workexperience-content">
# <div><div class="section_title"><h2>work experience</h2></div></div>
# <div class="items-container" id="work-experience-items">
# <div class="work-experience-section " id="workexperience-eesft3mcgw2hkqxatb0mla"><div class="data_display">
# <p class="work_title title">coordinating vp</p>
# <div class="work_company"    =""  >
# <span class="bold" itemprop="name">j e s basement systems</span> <div class="separator-hyphen">-</div> <div class="inline-block" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">cumberland, oh</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# may 2006
# <p class="work_description">responsibilities <br/>in bound and out bound calls, manage several different schedules. payroll, book keeping, employee paper work, word, excel, powerpoint, clerical, manage, set up and work home shows, appointment setting, over seen whole office staff.  manage social media and website presence. payroll assit. <br/> <br/>accomplishments <br/>notary state of ohio</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eezemuqwjoawvbkqk6c2ta"><div class="data_display">
# <p class="work_title title">data entry clerk</p>
# <div class="work_company"    =""  >
# <span class="bold" itemprop="name">flex job </span> <div class="separator-hyphen">-</div> <div class="inline-block" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">remote</span></div>
# </div>
# <p class="work_description">data entry</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eeyz-mqkb5svxztgi3rmkq"><div class="data_display">
# <p class="work_title title">customer service re ative</p>
# <div class="work_company">
# <span class="bold">cardia </span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>cambridge, oh</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">june 1998 to september 2005 (7 years, 3 months)</p>
# <p class="work_description">customer service for resorts</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eeyz_cynzgut9eibfzyckw"><div class="data_display">
# <p class="work_title title">customer service</p>
# <div class="work_company">
# <span class="bold">kennedys bakery</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>cambridge, oh</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">1997 to 1998 (1 year)</p>
# <p class="work_description">cashier making doughnuts and sold doughnuts</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eeyz---g9dut9eibfzyckw"><div class="data_display">
# <p class="work_title title">laborer/helper</p>
# <div class="work_company">
# <span class="bold">lima lite</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>norwich, oh</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">april 1996 to april 1997 (1 year)</p>
# <p class="work_description">cake candles and package them</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eeygzcyx8p2hnypalk2pyg"><div class="data_display">
# <p class="work_title title">transcription clerk</p>
# <div class="work_company">
# <span class="bold">self employed</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>cambridge, oh</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">2013 </p>
# <p class="work_description">responsibilities <br/>transcript from audio.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eeyf3cajayssilli6yveoa"><div class="data_display">
# <p class="work_title title">tutor </p>
# <div class="work_company"><div class="inline-block"><span>cambridge, oh</span></div></div>
# <p class="work_description">responsibilities <br/>tutoring elementary children with math and reading.</p>
# </div></div>
# <div class="work-experience-section last" id="workexperience-eeygy7193j-guztgi3rmkq"><div class="data_display">
# <p class="work_title title">work out of home</p>
# <div class="work_company">
# <span class="bold">self employed</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>cambridge, oh</span></div>
# </div>
# <p class="work_description">responsibilities <br/>sewing custom made dresses for on line sales.  <br/> also taking pictures and uploading on line with a description of each article. also take personal pictures for family and friends.</p>
# </div></div>
# </div>
# </div>
# <div class="section-item education-content">
# <div><div class="section_title"><h2>education</h2></div></div>
# <div class="items-container" id="education-items"><div class="education-section last" id="education-eesft52fxj-hkqxatb0mla"><div class="data_display" itemprop="alumniof"  ="" itemtype="http://schema.org/educationalorganization">
# <p class="edu_title">diploma   in general</p>
# <div class="edu_school">
# <span class="bold" itemprop="name">general</span> - <div class="inline-block" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">cambridge, oh</span></div>
# </div>
# <p class="edu_dates">1994 to 1998</p>
# </div></div></div>
# </div>
# <div class="section-item skills-content">
# <div><div class="section_title"><h2>skills</h2></div></div>
# <div class="items-container" id="skills-items"><div class="data_display"><div class="skill-container resume-element">
# <span class="skill-text">appointment scheduling</span>, <span class="skill-text">professional phone etiquette</span>, <span class="skill-text">customer service skills</span>, <span class="skill-text">pleasant demeanor</span>, <span class="skill-text">multi-line phone system</span>, <span class="skill-text">databases</span>, <span class="skill-text">quick learner</span>, <span class="skill-text">natural leader</span>, <span class="skill-text">strong customer service skills</span>, <span class="skill-text">bookkeeping (1 year)</span>, <span class="skill-text">customer service (10+ years)</span>, <span class="skill-text">data entry (1 year)</span>, <span class="skill-text">documentation (1 year)</span>, <span class="skill-text">word (10+ years)</span>, <span class="skill-text">windows xp (2 years)</span>, <span class="skill-text">editing (1 year)</span>, <span class="skill-text">human resources (1 year)</span>, <span class="skill-text">hiring (3 years)</span>, <span class="skill-text">management (5 years)</span>, <span class="skill-text">marketing (10+ years)</span>, <span class="skill-text">notary public (10+ years)</span>, <span class="skill-text">office management</span>, <span class="skill-text">sales (10+ years)</span>, <span class="skill-text">research (10+ years)</span>, <span class="skill-text">typing</span>
# </div></div></div>
# </div>
# <div class="section-item certification-content">
# <div><div class="section_title"><h2>certifications</h2></div></div>
# <div class="items-container" id="certification-items"><div class="certification-section last" id="certification-eew282srwz65ocpalk2pyg"><div class="data_display">
# <p class="certification_title">notary public</p>
# <p class="certification_date">december 2019</p>
# </div></div></div>
# </div>
# </div>
# index:3140 actual:0 predicted:1.0 0.93107843
# ====================================================================
# <div class="vcard single_form-content" id="resume_body">
# <div class="last basicinfo-content" id="basic_info_row"><div class="data_display" id="basic_info_cell">
# <h1 class="fn " id="resume-contact" itemprop="name">senator</h1>
# <div id="contact_info_container">
# <div class="adr" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><p class="locality" id="headline_location" itemprop="addresslocality">daly city, ca</p></div>
# <div class="separator-hyphen">-</div>
# </div>
# <p class="summary" id="res_summary">skyline college student majoring in psychology seeking a part-time position. aspiring counseling psychologist wanting to provide effective treatment in the healing process of mental health patients. capable, responsible, compassionate, excellent communicator, has experience with various ages and culturally diverse people. recognized as being assertive, enthusiastic and dedicated. proficient in word processing and other systems.</p>
# <p id="employment_eligibility">authorized to work in the us for any employer</p>
# </div></div>
# <div class="section-item workexperience-content">
# <div><div class="section_title"><h2>work experience</h2></div></div>
# <div class="items-container" id="work-experience-items">
# <div class="work-experience-section " id="workexperience-eez3v6brinuvk91fpwnzka"><div class="data_display">
# <p class="work_title title">senator</p>
# <div class="work_company">
# <span class="bold">associated students of skyline college (assc)</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>san bruno, ca</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# may 2015
# <p class="work_description">awarded best student advocate. a re ative of assc and skyline college student population. voted on finances, planned and promoted cultural events advocating learning and cultural diversity. outreached to students. a member of curriculum committee that gave thorough feedback and opinions on newly added skyline college courses.</p>
# </div></div>
# <div class="work-experience-section last" id="workexperience-eez3v6brinyvk91fpwnzka"><div class="data_display">
# <p class="work_title title">counseling and math assistant internship</p>
# <div class="work_company">
# <span class="bold">hope lutheran church</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>daly city, ca</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">june 2011 to july 2014</p>
# <p class="work_description">awarded most inspirational counselor. supervised and facilitated 40 students for activities, recess and engaged them in learning. motivated peers and campers on team-building, accountability and kindness. assisted campers with first aid kit and resources.</p>
# </div></div>
# </div>
# </div>
# <div class="section-item education-content">
# <div><div class="section_title"><h2>education</h2></div></div>
# <div class="items-container" id="education-items">
# <div class="education-section " id="education-eez3v6briogvk91fpwnzka"><div class="data_display" itemprop="alumniof"  ="" itemtype="http://schema.org/educationalorganization">
# <p class="edu_title">psychology</p>
# <div class="edu_school">
# <span class="bold" itemprop="name">skyline college</span> <div class="separator-hyphen">-</div> <div class="inline-block" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">san bruno, ca</span></div>
# </div>
# <p class="edu_dates">2014 to  </p>
# </div></div>
# <div class="education-section last" id="education-eez3v6brin-vk91fpwnzka"><div class="data_display" itemprop="alumniof"  ="" itemtype="http://schema.org/educationalorganization">
# <p class="edu_title">high school diploma</p>
# <div class="edu_school">
# <span class="bold" itemprop="name">westmoor high school</span> <div class="separator-hyphen">-</div> <div class="inline-block" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">daly city, ca</span></div>
# </div>
# <p class="edu_dates">2014</p>
# </div></div>
# </div>
# </div>
# <div class="section-item skills-content">
# <div><div class="section_title"><h2>skills</h2></div></div>
# <div class="items-container" id="skills-items"><div class="data_display"><div class="skill-container resume-element">
# <span class="skill-text">microsoft office (6 years)</span>, <span class="skill-text">microsoft excel (3 years)</span>, <span class="skill-text">event planning (8 years)</span>, <span class="skill-text">academic tutor (4 years)</span>, <span class="skill-text">fundraising (10+ years)</span>, <span class="skill-text">google docs (3 years)</span>, <span class="skill-text">student outreach (6 years)</span>, <span class="skill-text">community service (7 years)</span>, <span class="skill-text">networking (6 years)</span>, <span class="skill-text">leadership (6 years)</span>, <span class="skill-text">youth outreach (6 years)</span>, <span class="skill-text">public speaking (8 years)</span>, <span class="skill-text">interpersonal communications (8 years)</span>, <span class="skill-text">student advocate (6 years)</span>, <span class="skill-text">mental health advocate (6 years)</span>, <span class="skill-text">volunteering (6 years)</span>, <span class="skill-text">listening (10+ years)</span>, <span class="skill-text">teamwork (6 years)</span>, <span class="skill-text">team leader (6 years)</span>
# </div></div></div>
# </div>
# <div class="section-item awards-content">
# <div><div class="section_title"><h2>awards</h2></div></div>
# <div class="items-container" id="award-items">
# <div class="award-section " id="award-eez3wewvz6qvk91fpwnzka"><div class="data_display">
# <p class="award_title">most inspirational counselor</p>
# <p class="award_date">july 2012</p>
# <p class="award_description">i was awarded this at my summer day camp for my continual efforts with peers, counselors, adults and children with providing a safe space where children could grow.</p>
# </div></div>
# <div class="award-section " id="award-eez3whrmw6ivk91fpwnzka"><div class="data_display">
# <p class="award_title">best student advocate</p>
# <p class="award_date">may 2016</p>
# <p class="award_description">i was awarded this for re ing and advocating for college students to faculty and fellow senators while serving them during my term.</p>
# </div></div>
# <div class="award-section " id="award-eeay_ulsclunkfli6yveoa"><div class="data_display">
# <p class="award_title">student fundraiser - top 10 seller</p>
# <p class="award_date">september 2012</p>
# <p class="award_description">i was a top ten seller out of all the music department at westmoor high school (whs) selling magazines and cookie dough to students, faculty and off-campus. the proceeds went to purchase new instruments for the band, sheet music, uniform storage, music folders and festival entry fees.</p>
# </div></div>
# <div class="award-section " id="award-eeay_0zmkvqf_clhbgsw1q"><div class="data_display">
# <p class="award_title">student fundraiser - top 3 seller</p>
# <p class="award_date">september 2013</p>
# <p class="award_description">i was a top three seller in a group out of all the music department at westmoor high school (whs) selling magazines and cookie dough to students, faculty and off-campus. the proceeds went to purchase new instruments for the band, sheet music, uniform storage, music folders and festival entry fees.</p>
# </div></div>
# <div class="award-section last" id="award-eeay_3pnj-q3e3tcoxaklq"><div class="data_display">
# <p class="award_title">dean's honors list</p>
# <p class="award_date">may 2014</p>
# <p class="award_description">received award fall 2014, spring 2015, fall 2015, and spring 2016.</p>
# </div></div>
# </div>
# </div>
# <div class="section-item certification-content">
# <div><div class="section_title"><h2>certifications</h2></div></div>
# <div class="items-container" id="certification-items"><div class="certification-section last" id="certification-eeay_rtdtqgakytele7s5a"><div class="data_display">
# <p class="certification_title">mental health first aid</p>
# <p class="certification_date">october 2016 to october 2019</p>
# <p class="certification_description">able to assist until further professional help provided for those with mental illness or disorder with depression, anxiety, psychosis and drug and alcohol addiction.</p>
# </div></div></div>
# </div>
# <div class="section-item additionalinfo-content">
# <div><div class="section_title"><h2>additional information</h2></div></div>
# <div class="items-container" id="additionalinfo-items"><div class="last" id="additionalinfo-section"><div class="data_display"><p>team and detail-oriented. culturally sensitive. excellent listener and patient. able to follow directions and eager to learn new skills. critical thinker and problem solver. demonstrated clerical and planning skills. honest, attentive, productive, dependable.</p></div></div></div>
# </div>
# </div>
# index:3382 actual:0 predicted:1.0 0.8196309
# ====================================================================
# <div class="vcard single_form-content" id="resume_body">
# <div class="last basicinfo-content" id="basic_info_row"><div class="data_display" id="basic_info_cell">
# <h1 class="fn " id="resume-contact" itemprop="name">inpatient rehabiliation pm&amp;r rt/tr intern</h1>
# <h2 id="headline" itemprop="jobtitle">inpatient rehabiliation pm&amp;r rt/tr intern</h2>
# <div id="contact_info_container">
# <div class="adr" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><p class="locality" id="headline_location" itemprop="addresslocality">san antonio, tx</p></div>
# <div class="separator-hyphen">-</div>
# </div>
# <p class="summary" id="res_summary">seeking opportunity to expand my education and experience in therapeutic recreation interventions and assessment and documentation skills, as well as, further my experiences in working with diverse groups of individuals.</p>
# <p id="employment_eligibility">authorized to work in the us for any employer</p>
# </div></div>
# <div class="section-item workexperience-content">
# <div><div class="section_title"><h2>work experience</h2></div></div>
# <div class="items-container" id="work-experience-items">
# <div class="work-experience-section " id="workexperience-eea8a0zu38w99vn7osniyg"><div class="data_display">
# <p class="work_title title">inpatient rehabiliation pm&amp;r rt/tr intern</p>
# <div class="work_company">
# <span class="bold">houston methodist hospital rehabilitation services</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>houston, tx</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# august 2016
# <p class="work_description">* established and maintained professional working relationships <br/>* maintained up to 30 patient caseload, and provide rt/tr services utilizing apie process in an efficient and timely manner <br/>* uphold hmh icare values and policies <br/>* initiate co-treatments with interdisciplinary team members including, pt, ot, &amp; slp for all patient treatment sessions <br/>* planned and facilitated in-house group focusing on each pt's individual physical and cognitive goals, however, within a group setting <br/>* assisted/co-facilitated community re-entry outings with individual and/or multiple patients including educating on expecations and safety when out in community, and providing physical tasks focused on patient's functional goals for carry-over upon discharge <br/>* assisted and co-facilitated animal assisted therapy focusing in individual patients physical and cognitive goals in group setting</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eea8a0zu38a99vn7osniyg"><div class="data_display">
# <p class="work_title title">site supervisor</p>
# <div class="work_company">
# <span class="bold">city of kyle parks and recreation dept</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>kyle, tx</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">april 2016 to august 2016</p>
# <p class="work_description">* planning, coordinating, and supervising programs and activities for the day camp program <br/>* staff management, as well as, ensured compliance with required policies, procedures, and regulations, documenting noncompliance as needed <br/>* facilitating all required meetings, training, and in-services brought forth <br/>* assist in preparing work schedules, and expedite workflow; study and standardize procedures to improve efficiency and effectiveness of operations, and maintain related records and forms process paperwork in an accurate, complete and timely manner <br/>* maintain positive interpersonal relations among everyone involved in the day camp program</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eea8a0zu38e99vn7osniyg"><div class="data_display">
# <p class="work_title title">respite care tutor</p>
# <div class="work_company">
# <span class="bold">san marcos cisd special education</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>san marcos, tx</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">june 2015 to august 2015</p>
# <p class="work_description">* provided at home care to special education children <br/>* worked on social skills and activities of daily living <br/>* provided activities, in home and community settings</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eea8a0zu38i99vn7osniyg"><div class="data_display">
# <p class="work_title title">activity leader</p>
# <div class="work_company">
# <span class="bold">city of san marcos pard</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>san marcos, tx</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">may 2015 to august 2015</p>
# <p class="work_description">* supervised 15-30 children at a time from ages 7-14 <br/>* assisted with daily activity coordination and planning <br/>* implemented new activities and assisted in teaching staff procedures <br/>* assisted in working with children with disabilities and managing behavior <br/>* assisted in training other staff in behavior management techniques for children with disabilities <br/>* supervised up to 15 children on field trips to various public places</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eea8a0zu38m99vn7osniyg"><div class="data_display">
# <p class="work_title title">server</p>
# <div class="work_company">
# <span class="bold">bj's brewhouse</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>new braunfels, tx</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# ...
# <div class="work-experience-section " id="workexperience-eenjjybyapyfsr9olxgqwg"><div class="data_display">
# <p class="work_title title">chaplain</p>
# <div class="work_company">
# <span class="bold">redlands community hospital</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>redlands, ca</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# august 2012
# <p class="work_description">responsibilities <br/>provided ministry to all patients, families, and staff, according to their spiritual needs. managed a volunteer staff of chaplains, pastoral care givers, eucharistic ministers and no one dies along participants. established a network of outside clergy to serve the hospital and participated in local clergy associations. performed religious services. attended idt’s, bioethics meetings, palliative care consults, and crisis intervention/sentinel events. conducted bi-weekly behavioral health groups, quarterly grief groups, and in-services as needed. provided 24/7 coverage for er, icu, ob, nicu, pacu, and telemetry.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eefpxvl9_-cweroqxcdria"><div class="data_display">
# <p class="work_title title">hospice chaplain</p>
# <div class="work_company">
# <span class="bold">family hospice care</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>palm springs, ca</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">july 2009 to february 2012 (2 years, 7 months)</p>
# <p class="work_description">provide group and individual bereavement counseling and spiritual support to patients and care givers on hospice at home, b&amp;c's, and snf's. interview each patient and care giver for a spiritual assessment, identify spiritual needs, and create a plan of care. facilitate grief groups for care givers and provide religious ceremonies. provide training and oversight for volunteers. collaborate with interdisciplinary team in crisis intervention with patients and care givers as needed.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eefpxvl9_-gweroqxcdria"><div class="data_display">
# <p class="work_title title">on call chaplain</p>
# <div class="work_company">
# <span class="bold">vitas innovative hospice</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>san bernardino, ca</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">december 2008 to october 2009 (10 months)</p>
# <p class="work_description">assist in death visits, medication disposal, bedside end of life counseling, and new patient admits. assist interdisciplinary team in crisis intervention. visit patients and family members to provide for their spiritual needs.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eefpxvl9_-kweroqxcdria"><div class="data_display">
# <p class="work_title title">palliative care chaplain</p>
# <div class="work_company">
# <span class="bold">providence holy cross medical center</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>mission hills, ca</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">august 2008 to july 2009 (11 months)</p>
# <p class="work_description">visit all dying patients to provide spiritual and emotional support for patients, families, and staff.  facilitate liturgical services and memorial services. assist with interdisciplinary team in and crisis intervention, dnr's, and advance directives. assist volunteer staff with the "no one dies alone" program.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eefpxvl9_-oweroqxcdria"><div class="data_display">
# <p class="work_title title">chaplain resident</p>
# <div class="work_company">
# <span class="bold">st mary's medical center</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>san francisco, ca</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">august 2007 to june 2008 (10 months)</p>
# <p class="work_description">3 cpe units) <br/>provide full time and on-call chaplain coverage in er, icu, and the oncology unit. i specialized in providing pastoral care to palliative care and actively dying patients and their families. offer spiritual and emotional support for patients, families, and staff. facilitate liturgical services and memorial services.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eefpxvl-jviweroqxcdria"><div class="data_display">
# <p class="work_title title">chaplain resident</p>
# <div class="work_company">
# <span class="bold">hospital of university of pennsylvania/ inglis' house</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>philadelphia, pa</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">june 2002 to august 2002 (2 months)</p>
# <p class="work_description">1 cpe unit) <br/>provide spiritual counseling at a 297 bed snf, with a population made up of wheelchair bound multiple sclerosis, spinal cord injury, and cerebral palsy patients. the majority of my work dealt with transitions of patients to different levels of care, e.g. from wheelchair to bedridden. provide memorial services, individual bereavement counseling and led bereavement groups weekly.</p>
# </div></div>
# <div class="work-experience-section last" id="workexperience-eefpxvl-jvmweroqxcdria"><div class="data_display">
# <p class="work_title title">pastoral intern</p>
# <div class="work_company">
# <span class="bold">lower merion baptist church</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>bryn mawr, pa</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">september 2001 to june 2002 (9 months)</p>
# <p class="work_description">provide pastoral care the students of bryn mawr college along with a weekly bible study. conduct funerals, weekday bible study, sunday school, and sunday worship services. made weekly visitations to home bound church members for pastoral support. <br/> <br/>relevant experience</p>
# </div></div>
# </div>
# </div>
# <div class="section-item education-content">
# <div><div class="section_title"><h2>education</h2></div></div>
# <div class="items-container" id="education-items">
# <div class="education-section " id="education-eefpxvl-jv6weroqxcdria"><div class="data_display" itemprop="alumniof"  ="" itemtype="http://schema.org/educationalorganization">
# <p class="edu_title">master of divinity</p>
# <div class="edu_school">
# <span class="bold" itemprop="name">eastern baptist theological seminary</span> <div class="separator-hyphen">-</div> <div class="inline-block" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">philadelphia, pa</span></div>
# </div>
# <p class="edu_dates">2003</p>
# </div></div>
# <div class="education-section last" id="education-eefpxvl-jwcweroqxcdria"><div class="data_display" itemprop="alumniof"  ="" itemtype="http://schema.org/educationalorganization">
# <p class="edu_title">bs in criminology</p>
# <div class="edu_school">
# <span class="bold" itemprop="name">university of la verne</span> <div class="separator-hyphen">-</div> <div class="inline-block" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">la verne, ca</span></div>
# </div>
# <p class="edu_dates">2000</p>
# </div></div>
# </div>
# </div>
# </div>
# index:11027 actual:0 predicted:1.0 0.8569336
# ====================================================================
# <div class="vcard single_form-content" id="resume_body">
# <div class="last basicinfo-content" id="basic_info_row"><div class="data_display" id="basic_info_cell">
# <h1 class="fn " id="resume-contact" itemprop="name">pacs analyst i</h1>
# <div id="contact_info_container">
# <div class="adr" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><p class="locality" id="headline_location" itemprop="addresslocality">o'fallon, mo</p></div>
# <div class="separator-hyphen">-</div>
# </div>
# <p class="summary" id="res_summary">information technology professional with 11 year’s experience with installing and supporting multiple operating systems including, window xp, windows 7, windows server 2008, linux, solaris. able to adapt quickly and  learn new systems and to trouble-shoot difficult issues.  able to work well with a team or by myself.  excellent communication skills both verbal and written.  proficient at following procedures with minimal supervision. able to  maintain a balance between customer focused activities and proactively solving many ongoing issues.  coordinated and managed installation of multiple cardiology and radiology systems demonstrating project management skills such as planning, scheduling, organizing, and tracking. supported and managed medical imaging networks, including windows servers and workstations.  administered user accounts in a windows server enterprise and trained users on various vendor specific systems.  multitasked between leading projects and resolving customer issues in a fast paced environment</p>
# </div></div>
# <div class="section-item workexperience-content">
# <div><div class="section_title"><h2>work experience</h2></div></div>
# <div class="items-container" id="work-experience-items">
# <div class="work-experience-section " id="workexperience-eegxsvf1rjemtroqxcdria"><div class="data_display">
# <p class="work_title title">pacs analyst i</p>
# <div class="work_company"><span class="bold">bjc health system/missouri baptist medical center</span></div>
# <div class="separator-hyphen">-</div>
# june 2007
# <p class="work_description">•installed and configured window servers for vendor specific needs. <br/>•installed and maintained vendor software on windows servers and workstations. <br/>•worked with networking team to trouble shoot network issues and ensure quality service. <br/>•used applications to parse network data packets to find root cause of network issues. <br/>•first line customer support for resolving customer issues.   <br/>•multi-tasking was required to handle projects and customer issues. <br/>•managed patient data issues by researching clinical data and updating patient database. <br/>•worked with vendors to resolve configuration issues and tested software and advised on bug fixes. <br/>•lead team projects for installations of software upgrades and migrating data to ensure timely delivery of software. <br/>•designed and implemented training programs for end users to ensure understanding of vendor software usage. <br/>•managed user accounts on windows servers for end user access. <br/>•performed ms sql queries to search and update databases <br/>•resolved end user problems with windows workstations by communicating with customer by troubleshooting issue to the root cause in order to fix the problem. <br/>•set up meetings with end users to ensure customer satisfaction and quality assurance. <br/>•managed desktop computers, laptops, related peripheral and printers.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eegxsvf1rjimtroqxcdria"><div class="data_display">
# <p class="work_title title">pacs specialist/project manager</p>
# <div class="work_company"><span class="bold">scimage</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">september 2004 to may 2007</p>
# <p class="work_description">•assisted in design and implementation of pacs installations  <br/>•documented work flow of patient information and provide detailed site diagrams  <br/>•lead projects to coordinate and manage the installation of customers windows servers and workstations. <br/>•troubleshot network dicom and hl7 connectivity issues <br/>•main point of contact for customers to triage end user issues and bring them to resolution <br/>•maintained and updated customers windows servers and workstations  <br/>•implemented field upgrades on existing windows software and vendor specific software. <br/>•provided training and support to customers and sales re atives  <br/>•first line customer support for resolving customer issues.   <br/>•troubleshot network issues and used software to sniff network packets to find the root cause of connectivity issues <br/>•ran ms sql queries to search and update databases</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eegxsvf1rjmmtroqxcdria"><div class="data_display">
# <p class="work_title title">field service engineer</p>
# <div class="work_company"><span class="bold">eastman kodak company</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">january 2001 to september 2004</p>
# <p class="work_description">•coordinated and installed pacs networks for health imaging division  <br/>•performed routine maintenance checks for pacs servers and archives  <br/>•supported customers through remote and on site service  <br/>•diagnosed and resolved network issues pertaining to pacs equipment  <br/>•set up and troubleshot new and existing dicom connections  <br/>•ensured customer satisfaction maintenance through verbal and written communication  <br/>•provided 24x7 support to customers to ensure customer satisfaction</p>
# </div></div>
# <div class="work-experience-section last" id="workexperience-eegxsvf1rjqmtroqxcdria"><div class="data_display">
# <p class="work_title title">field service engineer</p>
# <div class="work_company"><span class="bold">hitachi medical systems of america</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">july 1999 to january 2001</p>
# <p class="work_description">•performed routine preventative maintenance on open mri scanners  <br/>•provided emergency maintenance as necessary  <br/>•responsible for installing and upgrading product changes  <br/>•managed and assisted with new equipment installations  <br/>•evaluated sites and analyze test data for potential equipment placement  <br/>•responsible for personal inventory of tools and test equipment</p>
# </div></div>
# </div>
# </div>
# <div class="section-item education-content">
# <div><div class="section_title"><h2>education</h2></div></div>
# <div class="items-container" id="education-items">
# <div class="education-section " id="education-eegxsvf1rj6mtroqxcdria"><div class="data_display" itemprop="alumniof"  ="" itemtype="http://schema.org/educationalorganization">
# <p class="edu_title">master of business administration</p>
# <div class="edu_school">
# <span class="bold" itemprop="name">lindenwood university st charles</span> <div class="separator-hyphen">-</div> <div class="inline-block" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">saint charles, mo</span></div>
# </div>
# <p class="edu_dates">april 2000 to june 2004</p>
# </div></div>
# <div class="education-section " id="education-eegxsvf1rkcmtroqxcdria"><div class="data_display" itemprop="alumniof"  ="" itemtype="http://schema.org/educationalorganization">
# <p class="edu_title">bachelor of science in electronics engineering technology</p>
# <div class="edu_school">
# <span class="bold" itemprop="name">devry institute of technology kansas city</span> <div class="separator-hyphen">-</div> <div class="inline-block" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">kansas city, mo</span></div>
# </div>
# <p class="edu_dates">february 1999 to april 2000</p>
# </div></div>
# <div class="education-section last" id="education-eegxsvf1rjymtroqxcdria"><div class="data_display" itemprop="alumniof"  ="" itemtype="http://schema.org/educationalorganization">
# <p class="edu_title">master in information systems management</p>
# <div class="edu_school">
# <span class="bold" itemprop="name">webster university st. louis</span> <div class="separator-hyphen">-</div> <div class="inline-block" itemprop="address"  ="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">st. louis, mo</span></div>
# </div>
# <p class="edu_dates">april 2000</p>
# </div></div>
# </div>
# </div>
# </div>

# %%
def print_wrong_plain_data_correct_data(pred_data, pred_plain, actual, details = False):
    count = 0
    for index, value in enumerate(pred_plain):
        if (actual[index] != round(value[0])) and (round(pred_data[index][0]) != round(value[0])):
            if (details) and abs(pred_data[index][0] - value[0]) > 0.3 and (actual[index] == 0):
                count += 1
                print('====================================================================')
                print(test_data_['plain_data'][index])
                print('====================================================================')
                print(test_data_['data'][index])
                print("index:" + str(index) + " actual:" + str(actual[index].astype(int)) + " predicted plain:" + str(value[0]))
                print("index:" + str(index) + " actual:" + str(actual[index].astype(int)) + " predicted html:" + str(pred_data[index]))
            elif (not details):
                print("index:" + str(index) + " actual:" + str(actual[index].astype(int)) + " predicted plain:" + str(value[0]))
                print("index:" + str(index) + " actual:" + str(actual[index].astype(int)) + " predicted html:" + str(pred_data[index]))

        if count > 10:
            break

print_wrong_plain_data_correct_data(model_predictions['CO:400, E:5, plain_data, adam'], model_predictions['CO:800, E:10, data, adam'], predictors_test['work_stayed'].astype(int))
# Out:
# index:8 actual:1 predicted plain:0.42834678
# index:8 actual:1 predicted html:[0.65]
# index:27 actual:1 predicted plain:0.42471987
# index:27 actual:1 predicted html:[0.55]
# index:42 actual:1 predicted plain:0.43715522
# index:42 actual:1 predicted html:[0.63]
# index:68 actual:1 predicted plain:0.49748135
# index:68 actual:1 predicted html:[0.6]
# index:70 actual:1 predicted plain:0.42758316
# index:70 actual:1 predicted html:[0.81]
# index:71 actual:1 predicted plain:0.48489422
# index:71 actual:1 predicted html:[0.68]
# index:84 actual:1 predicted plain:0.45139697
# index:84 actual:1 predicted html:[0.62]
# index:102 actual:1 predicted plain:0.48700598
# index:102 actual:1 predicted html:[0.58]
# index:105 actual:1 predicted plain:0.43261495
# index:105 actual:1 predicted html:[0.62]
# index:135 actual:1 predicted plain:0.4744674
# index:135 actual:1 predicted html:[0.76]
# index:140 actual:1 predicted plain:0.46266282
# index:140 actual:1 predicted html:[0.67]
# index:163 actual:1 predicted plain:0.44126117
# index:163 actual:1 predicted html:[0.7]
# index:166 actual:1 predicted plain:0.42830318
# index:166 actual:1 predicted html:[0.7]
# index:216 actual:1 predicted plain:0.49291143
# index:216 actual:1 predicted html:[0.5]
# index:237 actual:1 predicted plain:0.3011597
# index:237 actual:1 predicted html:[0.66]
# index:264 actual:1 predicted plain:0.47365007
# index:264 actual:1 predicted html:[0.66]
# index:308 actual:1 predicted plain:0.4315043
# index:308 actual:1 predicted html:[0.71]
# index:327 actual:1 predicted plain:0.45567137
# index:327 actual:1 predicted html:[0.55]
# index:330 actual:1 predicted plain:0.117833495
# index:330 actual:1 predicted html:[0.58]
# index:353 actual:1 predicted plain:0.48489904
# index:353 actual:1 predicted html:[0.81]
# index:462 actual:1 predicted plain:0.3973805
# index:462 actual:1 predicted html:[0.72]
# index:468 actual:0 predicted plain:0.5472493
# index:468 actual:0 predicted html:[0.35]
# index:498 actual:1 predicted plain:0.47903693
# index:498 actual:1 predicted html:[0.75]
# index:506 actual:1 predicted plain:0.36029667
# index:506 actual:1 predicted html:[0.68]
# index:541 actual:1 predicted plain:0.3217509
# index:541 actual:1 predicted html:[0.63]
# index:559 actual:0 predicted plain:0.504824
# index:559 actual:0 predicted html:[0.49]
# index:644 actual:1 predicted plain:0.4558419
# index:644 actual:1 predicted html:[0.68]
# index:684 actual:1 predicted plain:0.4908132
# index:684 actual:1 predicted html:[0.62]
# index:697 actual:1 predicted plain:0.47837085
# index:697 actual:1 predicted html:[0.6]
# index:709 actual:1 predicted plain:0.43561673
# index:709 actual:1 predicted html:[0.63]
# index:726 actual:0 predicted plain:0.5594211
# index:726 actual:0 predicted html:[0.42]
# index:733 actual:0 predicted plain:0.6344972
# index:733 actual:0 predicted html:[0.39]
# index:735 actual:1 predicted plain:0.44291285
# index:735 actual:1 predicted html:[0.62]
# index:747 actual:1 predicted plain:0.4749474
# index:747 actual:1 predicted html:[0.6]
# index:753 actual:0 predicted plain:0.59723866
# index:753 actual:0 predicted html:[0.28]
# index:759 actual:1 predicted plain:0.4944786
# index:759 actual:1 predicted html:[0.57]
# index:775 actual:1 predicted plain:0.49296275
# index:775 actual:1 predicted html:[0.71]
# index:776 actual:1 predicted plain:0.46318233
# index:776 actual:1 predicted html:[0.55]
# index:778 actual:0 predicted plain:0.7538954
# index:778 actual:0 predicted html:[0.5]
# index:832 actual:1 predicted plain:0.39741817
# index:832 actual:1 predicted html:[0.75]
# index:851 actual:1 predicted plain:0.49829197
# index:851 actual:1 predicted html:[0.58]
# index:866 actual:1 predicted plain:0.43328324
# index:866 actual:1 predicted html:[0.56]
# index:888 actual:1 predicted plain:0.42946994
# index:888 actual:1 predicted html:[0.65]
# index:899 actual:1 predicted plain:0.40822685
# index:899 actual:1 predicted html:[0.64]
# index:935 actual:1 predicted plain:0.4652082
# index:935 actual:1 predicted html:[0.68]
# index:958 actual:1 predicted plain:0.3836958
# index:958 actual:1 predicted html:[0.5]
# index:960 actual:1 predicted plain:0.49063003
# index:960 actual:1 predicted html:[0.53]
# index:964 actual:1 predicted plain:0.44889906
# index:964 actual:1 predicted html:[0.75]
# index:971 actual:1 predicted plain:0.48892075
# index:971 actual:1 predicted html:[0.7]
# index:1006 actual:1 predicted plain:0.47676492
# index:1006 actual:1 predicted html:[0.71]
# index:1043 actual:1 predicted plain:0.45403218
# index:1043 actual:1 predicted html:[0.6]
# index:1050 actual:1 predicted plain:0.43403786
# index:1050 actual:1 predicted html:[0.58]
# index:1056 actual:0 predicted plain:0.51267666
# index:1056 actual:0 predicted html:[0.49]
# index:1069 actual:1 predicted plain:0.43829697
# index:1069 actual:1 predicted html:[0.62]
# index:1089 actual:1 predicted plain:0.42331052
# index:1089 actual:1 predicted html:[0.53]
# index:1096 actual:1 predicted plain:0.47000754
# index:1096 actual:1 predicted html:[0.8]
# index:1104 actual:1 predicted plain:0.4759078
# index:1104 actual:1 predicted html:[0.71]
# index:1110 actual:1 predicted plain:0.48893198
# index:1110 actual:1 predicted html:[0.71]
# index:1168 actual:1 predicted plain:0.43553755
# index:1168 actual:1 predicted html:[0.51]
# index:1178 actual:1 predicted plain:0.40159953
# index:1178 actual:1 predicted html:[0.65]
# index:1211 actual:1 predicted plain:0.47172934
# index:1211 actual:1 predicted html:[0.53]
# index:1223 actual:1 predicted plain:0.4039206
# index:1223 actual:1 predicted html:[0.63]
# index:1239 actual:1 predicted plain:0.4470629
# index:1239 actual:1 predicted html:[0.67]
# index:1258 actual:1 predicted plain:0.34692892
# index:1258 actual:1 predicted html:[0.69]
# index:1305 actual:1 predicted plain:0.47080556
# index:1305 actual:1 predicted html:[0.52]
# index:1311 actual:1 predicted plain:0.36292082
# index:1311 actual:1 predicted html:[0.74]
# index:1331 actual:1 predicted plain:0.42061797
# index:1331 actual:1 predicted html:[0.73]
# index:1337 actual:0 predicted plain:0.6959882
# index:1337 actual:0 predicted html:[0.48]
# index:1345 actual:1 predicted plain:0.45887864
# index:1345 actual:1 predicted html:[0.58]
# index:1360 actual:1 predicted plain:0.4652566
# index:1360 actual:1 predicted html:[0.72]
# index:1371 actual:1 predicted plain:0.4347867
# index:1371 actual:1 predicted html:[0.63]
# index:1376 actual:0 predicted plain:0.60080355
# index:1376 actual:0 predicted html:[0.38]
# index:1378 actual:1 predicted plain:0.3320264
# index:1378 actual:1 predicted html:[0.62]
# index:1411 actual:1 predicted plain:0.41334733
# index:1411 actual:1 predicted html:[0.54]
# index:1423 actual:1 predicted plain:0.49564746
# index:1423 actual:1 predicted html:[0.69]
# index:1433 actual:1 predicted plain:0.42592725
# index:1433 actual:1 predicted html:[0.73]
# index:1438 actual:0 predicted plain:0.5096244
# index:1438 actual:0 predicted html:[0.49]
# index:1471 actual:0 predicted plain:0.61125183
# index:1471 actual:0 predicted html:[0.37]
# index:1506 actual:1 predicted plain:0.41238058
# index:1506 actual:1 predicted html:[0.67]
# index:1510 actual:1 predicted plain:0.48290524
# index:1510 actual:1 predicted html:[0.58]
# index:1523 actual:1 predicted plain:0.18819243
# index:1523 actual:1 predicted html:[0.65]
# index:1533 actual:1 predicted plain:0.33463672
# index:1533 actual:1 predicted html:[0.74]
# index:1535 actual:1 predicted plain:0.4197577
# index:1535 actual:1 predicted html:[0.67]
# index:1550 actual:1 predicted plain:0.46283692
# index:1550 actual:1 predicted html:[0.54]
# index:1561 actual:0 predicted plain:0.6327786
# index:1561 actual:0 predicted html:[0.46]
# index:1588 actual:1 predicted plain:0.47243017
# index:1588 actual:1 predicted html:[0.64]
# index:1617 actual:1 predicted plain:0.45819142
# index:1617 actual:1 predicted html:[0.54]
# index:1620 actual:1 predicted plain:0.49243414
# index:1620 actual:1 predicted html:[0.5]
# index:1623 actual:1 predicted plain:0.4863018
# index:1623 actual:1 predicted html:[0.62]
# index:1656 actual:0 predicted plain:0.73625445
# index:1656 actual:0 predicted html:[0.49]
# index:1662 actual:1 predicted plain:0.38669598
# index:1662 actual:1 predicted html:[0.57]
# index:1684 actual:1 predicted plain:0.33450678
# index:1684 actual:1 predicted html:[0.64]
# index:1694 actual:1 predicted plain:0.39734328
# index:1694 actual:1 predicted html:[0.66]
# index:1712 actual:1 predicted plain:0.4746678
# index:1712 actual:1 predicted html:[0.8]
# index:1751 actual:1 predicted plain:0.45438918
# index:1751 actual:1 predicted html:[0.75]
# index:1767 actual:1 predicted plain:0.4229157
# index:1767 actual:1 predicted html:[0.66]
# index:1827 actual:1 predicted plain:0.48036003
# index:1827 actual:1 predicted html:[0.55]
# index:1886 actual:1 predicted plain:0.49875256
# index:1886 actual:1 predicted html:[0.57]
# index:1914 actual:1 predicted plain:0.22136505
# index:1914 actual:1 predicted html:[0.8]
# index:1990 actual:1 predicted plain:0.4593109
# index:1990 actual:1 predicted html:[0.64]
# index:1991 actual:1 predicted plain:0.4254748
# index:1991 actual:1 predicted html:[0.67]
# index:1994 actual:1 predicted plain:0.44265547
# index:1994 actual:1 predicted html:[0.58]
# index:2039 actual:1 predicted plain:0.48942685
# index:2039 actual:1 predicted html:[0.59]
# index:2057 actual:1 predicted plain:0.42243823
# index:2057 actual:1 predicted html:[0.58]
# index:2065 actual:0 predicted plain:0.6674747
# index:2065 actual:0 predicted html:[0.47]
# index:2070 actual:1 predicted plain:0.49452612
# index:2070 actual:1 predicted html:[0.73]
# index:2094 actual:1 predicted plain:0.3898557
# index:2094 actual:1 predicted html:[0.64]
# index:2099 actual:1 predicted plain:0.36095914
# index:2099 actual:1 predicted html:[0.66]
# index:2114 actual:1 predicted plain:0.4973281
# index:2114 actual:1 predicted html:[0.68]
# index:2173 actual:1 predicted plain:0.4422468
# index:2173 actual:1 predicted html:[0.59]
# index:2183 actual:1 predicted plain:0.3435286
# index:2183 actual:1 predicted html:[0.68]
# index:2198 actual:1 predicted plain:0.38038898
# index:2198 actual:1 predicted html:[0.74]
# index:2223 actual:1 predicted plain:0.49962536
# index:2223 actual:1 predicted html:[0.66]
# index:2258 actual:1 predicted plain:0.47436842
# index:2258 actual:1 predicted html:[0.74]
# index:2270 actual:1 predicted plain:0.45739082
# index:2270 actual:1 predicted html:[0.55]
# index:2314 actual:1 predicted plain:0.4610777
# index:2314 actual:1 predicted html:[0.66]
# index:2335 actual:1 predicted plain:0.49414304
# index:2335 actual:1 predicted html:[0.72]
# index:2338 actual:1 predicted plain:0.47377795
# index:2338 actual:1 predicted html:[0.8]
# index:2393 actual:1 predicted plain:0.41791838
# index:2393 actual:1 predicted html:[0.56]
# index:2502 actual:1 predicted plain:0.0792971
# index:2502 actual:1 predicted html:[0.5]
# index:2521 actual:1 predicted plain:0.42484906
# index:2521 actual:1 predicted html:[0.59]
# index:2577 actual:1 predicted plain:0.48159364
# index:2577 actual:1 predicted html:[0.66]
# index:2586 actual:1 predicted plain:0.45704812
# index:2586 actual:1 predicted html:[0.51]
# index:2592 actual:0 predicted plain:0.69627196
# index:2592 actual:0 predicted html:[0.36]
# index:2615 actual:1 predicted plain:0.46692643
# index:2615 actual:1 predicted html:[0.86]
# index:2619 actual:1 predicted plain:0.47518888
# index:2619 actual:1 predicted html:[0.61]
# index:2630 actual:0 predicted plain:0.6738157
# index:2630 actual:0 predicted html:[0.48]
# index:2651 actual:1 predicted plain:0.45496598
# index:2651 actual:1 predicted html:[0.76]
# index:2655 actual:1 predicted plain:0.42798725
# index:2655 actual:1 predicted html:[0.62]
# index:2661 actual:1 predicted plain:0.42231268
# index:2661 actual:1 predicted html:[0.63]
# index:2668 actual:1 predicted plain:0.4274066
# index:2668 actual:1 predicted html:[0.64]
# index:2672 actual:1 predicted plain:0.45010033
# index:2672 actual:1 predicted html:[0.82]
# index:2701 actual:1 predicted plain:0.44692153
# index:2701 actual:1 predicted html:[0.66]
# index:2715 actual:1 predicted plain:0.48454648
# index:2715 actual:1 predicted html:[0.79]
# index:2733 actual:1 predicted plain:0.464352
# index:2733 actual:1 predicted html:[0.76]
# index:2786 actual:1 predicted plain:0.44024777
# index:2786 actual:1 predicted html:[0.7]
# index:2787 actual:0 predicted plain:0.67895824
# index:2787 actual:0 predicted html:[0.48]
# index:2810 actual:1 predicted plain:0.4371612
# index:2810 actual:1 predicted html:[0.61]
# index:2816 actual:1 predicted plain:0.44978413
# index:2816 actual:1 predicted html:[0.76]
# index:2819 actual:1 predicted plain:0.47366333
# index:2819 actual:1 predicted html:[0.56]
# index:2849 actual:1 predicted plain:0.49319583
# index:2849 actual:1 predicted html:[0.66]
# index:2858 actual:1 predicted plain:0.36411986
# index:2858 actual:1 predicted html:[0.6]
# index:2874 actual:1 predicted plain:0.45868823
# index:2874 actual:1 predicted html:[0.69]
# index:2882 actual:1 predicted plain:0.49020308
# index:2882 actual:1 predicted html:[0.59]
# index:2903 actual:1 predicted plain:0.49502438
# index:2903 actual:1 predicted html:[0.79]
# index:2916 actual:1 predicted plain:0.4574701
# index:2916 actual:1 predicted html:[0.65]
# index:2953 actual:1 predicted plain:0.43177038
# index:2953 actual:1 predicted html:[0.57]
# index:2985 actual:1 predicted plain:0.46298513
# index:2985 actual:1 predicted html:[0.66]
# index:2991 actual:1 predicted plain:0.37954497
# index:2991 actual:1 predicted html:[0.76]
# index:2996 actual:1 predicted plain:0.43696693
# index:2996 actual:1 predicted html:[0.82]
# index:2999 actual:0 predicted plain:0.5181871
# index:2999 actual:0 predicted html:[0.31]
# index:3029 actual:1 predicted plain:0.46610078
# index:3029 actual:1 predicted html:[0.56]
# index:3075 actual:1 predicted plain:0.4100838
# index:3075 actual:1 predicted html:[0.65]
# index:3104 actual:1 predicted plain:0.39731503
# index:3104 actual:1 predicted html:[0.64]
# index:3151 actual:1 predicted plain:0.48940504
# index:3151 actual:1 predicted html:[0.76]
# index:3176 actual:1 predicted plain:0.42872542
# index:3176 actual:1 predicted html:[0.79]
# index:3200 actual:0 predicted plain:0.56354934
# index:3200 actual:0 predicted html:[0.17]
# index:3205 actual:1 predicted plain:0.44928995
# index:3205 actual:1 predicted html:[0.68]
# index:3224 actual:1 predicted plain:0.45702907
# index:3224 actual:1 predicted html:[0.51]
# index:3253 actual:1 predicted plain:0.48123884
# index:3253 actual:1 predicted html:[0.71]
# index:3321 actual:1 predicted plain:0.4553808
# index:3321 actual:1 predicted html:[0.78]
# index:3336 actual:1 predicted plain:0.4818994
# index:3336 actual:1 predicted html:[0.66]
# index:3365 actual:1 predicted plain:0.4630592
# index:3365 actual:1 predicted html:[0.63]
# index:3407 actual:1 predicted plain:0.47785026
# index:3407 actual:1 predicted html:[0.69]
# index:3409 actual:1 predicted plain:0.41653138
# index:3409 actual:1 predicted html:[0.65]
# index:3483 actual:1 predicted plain:0.41290897
# index:3483 actual:1 predicted html:[0.73]
# index:3498 actual:0 predicted plain:0.6366402
# index:3498 actual:0 predicted html:[0.39]
# index:3500 actual:1 predicted plain:0.46969858
# index:3500 actual:1 predicted html:[0.76]
# index:3518 actual:0 predicted plain:0.67352474
# index:3518 actual:0 predicted html:[0.46]
# index:3519 actual:0 predicted plain:0.5008025
# index:3519 actual:0 predicted html:[0.45]
# index:3540 actual:0 predicted plain:0.5999639
# index:3540 actual:0 predicted html:[0.38]
# index:3553 actual:0 predicted plain:0.53937477
# index:3553 actual:0 predicted html:[0.35]
# index:3629 actual:1 predicted plain:0.36905563
# index:3629 actual:1 predicted html:[0.61]
# index:3630 actual:1 predicted plain:0.3494165
# index:3630 actual:1 predicted html:[0.58]
# index:3726 actual:1 predicted plain:0.45030883
# index:3726 actual:1 predicted html:[0.6]
# index:3741 actual:1 predicted plain:0.4947727
# index:3741 actual:1 predicted html:[0.68]
# index:3777 actual:1 predicted plain:0.45325842
# index:3777 actual:1 predicted html:[0.58]
# index:3830 actual:1 predicted plain:0.43117735
# index:3830 actual:1 predicted html:[0.58]
# index:3843 actual:0 predicted plain:0.51991034
# index:3843 actual:0 predicted html:[0.48]
# index:3933 actual:1 predicted plain:0.42883036
# index:3933 actual:1 predicted html:[0.61]
# index:3942 actual:1 predicted plain:0.3315202
# index:3942 actual:1 predicted html:[0.7]
# index:3967 actual:1 predicted plain:0.4731136
# index:3967 actual:1 predicted html:[0.52]
# index:3991 actual:1 predicted plain:0.40771595
# index:3991 actual:1 predicted html:[0.61]
# index:4063 actual:1 predicted plain:0.47863758
# index:4063 actual:1 predicted html:[0.77]
# index:4090 actual:1 predicted plain:0.36502942
# index:4090 actual:1 predicted html:[0.71]
# index:4099 actual:1 predicted plain:0.4386133
# index:4099 actual:1 predicted html:[0.54]
# index:4103 actual:1 predicted plain:0.41075522
# index:4103 actual:1 predicted html:[0.68]
# index:4144 actual:0 predicted plain:0.5438341
# index:4144 actual:0 predicted html:[0.5]
# index:4150 actual:1 predicted plain:0.49862182
# index:4150 actual:1 predicted html:[0.52]
# index:4171 actual:1 predicted plain:0.4402966
# index:4171 actual:1 predicted html:[0.56]
# index:4183 actual:0 predicted plain:0.51486075
# index:4183 actual:0 predicted html:[0.36]
# index:4241 actual:1 predicted plain:0.41921744
# index:4241 actual:1 predicted html:[0.54]
# index:4244 actual:1 predicted plain:0.4734453
# index:4244 actual:1 predicted html:[0.73]
# index:4247 actual:0 predicted plain:0.6096159
# index:4247 actual:0 predicted html:[0.23]
# index:4292 actual:1 predicted plain:0.37188566
# index:4292 actual:1 predicted html:[0.8]
# index:4310 actual:1 predicted plain:0.4066218
# index:4310 actual:1 predicted html:[0.63]
# index:4347 actual:1 predicted plain:0.4768942
# index:4347 actual:1 predicted html:[0.68]
# index:4360 actual:1 predicted plain:0.41798398
# index:4360 actual:1 predicted html:[0.72]
# index:4365 actual:1 predicted plain:0.45516214
# index:4365 actual:1 predicted html:[0.63]
# index:4446 actual:1 predicted plain:0.47505414
# index:4446 actual:1 predicted html:[0.52]
# index:4465 actual:0 predicted plain:0.53699064
# index:4465 actual:0 predicted html:[0.26]
# index:4483 actual:1 predicted plain:0.42964306
# index:4483 actual:1 predicted html:[0.67]
# index:4515 actual:0 predicted plain:0.6529221
# index:4515 actual:0 predicted html:[0.41]
# index:4516 actual:1 predicted plain:0.44104344
# index:4516 actual:1 predicted html:[0.74]
# index:4532 actual:1 predicted plain:0.4541544
# index:4532 actual:1 predicted html:[0.74]
# index:4613 actual:1 predicted plain:0.46074823
# index:4613 actual:1 predicted html:[0.75]
# index:4672 actual:0 predicted plain:0.76339954
# index:4672 actual:0 predicted html:[0.48]
# index:4674 actual:1 predicted plain:0.460079
# index:4674 actual:1 predicted html:[0.63]
# index:4695 actual:1 predicted plain:0.42853415
# index:4695 actual:1 predicted html:[0.69]
# index:4714 actual:1 predicted plain:0.4335625
# index:4714 actual:1 predicted html:[0.68]
# index:4745 actual:0 predicted plain:0.5628195
# index:4745 actual:0 predicted html:[0.39]
# index:4755 actual:1 predicted plain:0.41600698
# index:4755 actual:1 predicted html:[0.79]
# index:4774 actual:1 predicted plain:0.37893894
# index:4774 actual:1 predicted html:[0.5]
# index:4785 actual:1 predicted plain:0.49828866
# index:4785 actual:1 predicted html:[0.62]
# index:4793 actual:1 predicted plain:0.46969438
# index:4793 actual:1 predicted html:[0.5]
# index:4812 actual:1 predicted plain:0.3086128
# index:4812 actual:1 predicted html:[0.6]
# index:4819 actual:1 predicted plain:0.38294113
# index:4819 actual:1 predicted html:[0.52]
# index:4840 actual:1 predicted plain:0.41381502
# index:4840 actual:1 predicted html:[0.66]
# index:4857 actual:1 predicted plain:0.4686039
# index:4857 actual:1 predicted html:[0.72]
# index:4862 actual:1 predicted plain:0.49157873
# index:4862 actual:1 predicted html:[0.65]
# index:4892 actual:1 predicted plain:0.4797435
# index:4892 actual:1 predicted html:[0.75]
# index:4897 actual:1 predicted plain:0.46284923
# index:4897 actual:1 predicted html:[0.81]
# index:4903 actual:1 predicted plain:0.40835246
# index:4903 actual:1 predicted html:[0.51]
# index:4905 actual:1 predicted plain:0.42177927
# index:4905 actual:1 predicted html:[0.76]
# index:4907 actual:0 predicted plain:0.77749014
# index:4907 actual:0 predicted html:[0.43]
# index:4913 actual:1 predicted plain:0.47425386
# index:4913 actual:1 predicted html:[0.57]
# index:4924 actual:1 predicted plain:0.49596804
# index:4924 actual:1 predicted html:[0.79]
# index:4939 actual:1 predicted plain:0.44284353
# index:4939 actual:1 predicted html:[0.59]
# index:4940 actual:1 predicted plain:0.335652
# index:4940 actual:1 predicted html:[0.64]
# index:4942 actual:1 predicted plain:0.49477208
# index:4942 actual:1 predicted html:[0.73]
# index:5026 actual:1 predicted plain:0.45521384
# index:5026 actual:1 predicted html:[0.53]
# index:5054 actual:1 predicted plain:0.47805533
# index:5054 actual:1 predicted html:[0.73]
# index:5075 actual:1 predicted plain:0.48904133
# index:5075 actual:1 predicted html:[0.66]
# index:5093 actual:1 predicted plain:0.4957577
# index:5093 actual:1 predicted html:[0.62]
# index:5109 actual:1 predicted plain:0.47367758
# index:5109 actual:1 predicted html:[0.65]
# index:5138 actual:1 predicted plain:0.49870673
# index:5138 actual:1 predicted html:[0.62]
# index:5139 actual:1 predicted plain:0.38183945
# index:5139 actual:1 predicted html:[0.66]
# index:5147 actual:1 predicted plain:0.35484603
# index:5147 actual:1 predicted html:[0.69]
# index:5148 actual:1 predicted plain:0.46422797
# index:5148 actual:1 predicted html:[0.62]
# index:5150 actual:0 predicted plain:0.6185679
# index:5150 actual:0 predicted html:[0.41]
# index:5152 actual:0 predicted plain:0.71893376
# index:5152 actual:0 predicted html:[0.42]
# index:5171 actual:1 predicted plain:0.45904732
# index:5171 actual:1 predicted html:[0.79]
# index:5189 actual:0 predicted plain:0.51856613
# index:5189 actual:0 predicted html:[0.31]
# index:5194 actual:1 predicted plain:0.41741148
# index:5194 actual:1 predicted html:[0.67]
# index:5220 actual:1 predicted plain:0.45677465
# index:5220 actual:1 predicted html:[0.7]
# index:5224 actual:1 predicted plain:0.4534824
# index:5224 actual:1 predicted html:[0.69]
# index:5242 actual:1 predicted plain:0.33288097
# index:5242 actual:1 predicted html:[0.52]
# index:5271 actual:1 predicted plain:0.49961966
# index:5271 actual:1 predicted html:[0.84]
# index:5288 actual:1 predicted plain:0.4885246
# index:5288 actual:1 predicted html:[0.68]
# index:5289 actual:1 predicted plain:0.41492817
# index:5289 actual:1 predicted html:[0.64]
# index:5324 actual:1 predicted plain:0.49109414
# index:5324 actual:1 predicted html:[0.67]
# index:5340 actual:1 predicted plain:0.48224553
# index:5340 actual:1 predicted html:[0.68]
# index:5356 actual:1 predicted plain:0.4492167
# index:5356 actual:1 predicted html:[0.66]
# index:5358 actual:0 predicted plain:0.5019728
# index:5358 actual:0 predicted html:[0.44]
# index:5387 actual:1 predicted plain:0.40350184
# index:5387 actual:1 predicted html:[0.65]
# index:5395 actual:0 predicted plain:0.5273541
# index:5395 actual:0 predicted html:[0.31]
# index:5451 actual:1 predicted plain:0.40593714
# index:5451 actual:1 predicted html:[0.52]
# index:5466 actual:1 predicted plain:0.28975445
# index:5466 actual:1 predicted html:[0.64]
# index:5485 actual:0 predicted plain:0.59173733
# index:5485 actual:0 predicted html:[0.48]
# index:5520 actual:1 predicted plain:0.49566987
# index:5520 actual:1 predicted html:[0.8]
# index:5521 actual:1 predicted plain:0.46145734
# index:5521 actual:1 predicted html:[0.7]
# index:5585 actual:1 predicted plain:0.4380267
# index:5585 actual:1 predicted html:[0.69]
# index:5587 actual:1 predicted plain:0.349079
# index:5587 actual:1 predicted html:[0.66]
# index:5592 actual:1 predicted plain:0.41805825
# index:5592 actual:1 predicted html:[0.56]
# index:5595 actual:1 predicted plain:0.46134415
# index:5595 actual:1 predicted html:[0.73]
# index:5606 actual:0 predicted plain:0.5744566
# index:5606 actual:0 predicted html:[0.28]
# index:5612 actual:1 predicted plain:0.47275424
# index:5612 actual:1 predicted html:[0.68]
# index:5617 actual:1 predicted plain:0.45497337
# index:5617 actual:1 predicted html:[0.67]
# index:5638 actual:1 predicted plain:0.4414297
# index:5638 actual:1 predicted html:[0.54]
# index:5646 actual:1 predicted plain:0.479335
# index:5646 actual:1 predicted html:[0.58]
# index:5654 actual:1 predicted plain:0.46436203
# index:5654 actual:1 predicted html:[0.67]
# index:5657 actual:1 predicted plain:0.40389067
# index:5657 actual:1 predicted html:[0.64]
# index:5716 actual:1 predicted plain:0.43799344
# index:5716 actual:1 predicted html:[0.79]
# index:5738 actual:1 predicted plain:0.44725397
# index:5738 actual:1 predicted html:[0.68]
# index:5753 actual:1 predicted plain:0.36166942
# index:5753 actual:1 predicted html:[0.75]
# index:5758 actual:1 predicted plain:0.4517519
# index:5758 actual:1 predicted html:[0.79]
# index:5763 actual:1 predicted plain:0.43490663
# index:5763 actual:1 predicted html:[0.63]
# index:5785 actual:1 predicted plain:0.35498607
# index:5785 actual:1 predicted html:[0.7]
# index:5798 actual:1 predicted plain:0.49824676
# index:5798 actual:1 predicted html:[0.69]
# index:5815 actual:1 predicted plain:0.46497744
# index:5815 actual:1 predicted html:[0.53]
# index:5819 actual:1 predicted plain:0.43556476
# index:5819 actual:1 predicted html:[0.69]
# index:5830 actual:1 predicted plain:0.40440264
# index:5830 actual:1 predicted html:[0.62]
# index:5835 actual:1 predicted plain:0.45923606
# index:5835 actual:1 predicted html:[0.55]
# index:5845 actual:0 predicted plain:0.5611385
# index:5845 actual:0 predicted html:[0.48]
# index:5859 actual:1 predicted plain:0.44748148
# index:5859 actual:1 predicted html:[0.56]
# index:5921 actual:1 predicted plain:0.48709387
# index:5921 actual:1 predicted html:[0.6]
# index:5933 actual:1 predicted plain:0.36017945
# index:5933 actual:1 predicted html:[0.64]
# index:5969 actual:1 predicted plain:0.4775734
# index:5969 actual:1 predicted html:[0.71]
# index:5988 actual:1 predicted plain:0.4578252
# index:5988 actual:1 predicted html:[0.62]
# index:5992 actual:0 predicted plain:0.5507442
# index:5992 actual:0 predicted html:[0.46]
# index:6008 actual:1 predicted plain:0.4014401
# index:6008 actual:1 predicted html:[0.84]
# index:6013 actual:1 predicted plain:0.4546529
# index:6013 actual:1 predicted html:[0.67]
# index:6018 actual:0 predicted plain:0.60562557
# index:6018 actual:0 predicted html:[0.31]
# index:6023 actual:1 predicted plain:0.42554125
# index:6023 actual:1 predicted html:[0.61]
# index:6024 actual:1 predicted plain:0.39808205
# index:6024 actual:1 predicted html:[0.73]
# index:6129 actual:0 predicted plain:0.6878087
# index:6129 actual:0 predicted html:[0.49]
# index:6146 actual:1 predicted plain:0.4312327
# index:6146 actual:1 predicted html:[0.53]
# index:6161 actual:0 predicted plain:0.5181727
# index:6161 actual:0 predicted html:[0.4]
# index:6175 actual:1 predicted plain:0.37371418
# index:6175 actual:1 predicted html:[0.82]
# index:6179 actual:1 predicted plain:0.4149423
# index:6179 actual:1 predicted html:[0.65]
# index:6183 actual:1 predicted plain:0.42396763
# index:6183 actual:1 predicted html:[0.6]
# index:6185 actual:1 predicted plain:0.3950751
# index:6185 actual:1 predicted html:[0.55]
# index:6213 actual:1 predicted plain:0.42443198
# index:6213 actual:1 predicted html:[0.74]
# index:6231 actual:1 predicted plain:0.44594377
# index:6231 actual:1 predicted html:[0.7]
# index:6264 actual:1 predicted plain:0.3999413
# index:6264 actual:1 predicted html:[0.61]
# index:6279 actual:1 predicted plain:0.358703
# index:6279 actual:1 predicted html:[0.67]
# index:6282 actual:1 predicted plain:0.46481064
# index:6282 actual:1 predicted html:[0.65]
# index:6284 actual:1 predicted plain:0.49114636
# index:6284 actual:1 predicted html:[0.75]
# index:6339 actual:1 predicted plain:0.30789337
# index:6339 actual:1 predicted html:[0.53]
# index:6402 actual:1 predicted plain:0.3048824
# index:6402 actual:1 predicted html:[0.62]
# index:6411 actual:1 predicted plain:0.31897533
# index:6411 actual:1 predicted html:[0.53]
# index:6427 actual:1 predicted plain:0.45963037
# index:6427 actual:1 predicted html:[0.65]
# index:6441 actual:1 predicted plain:0.40619203
# index:6441 actual:1 predicted html:[0.69]
# index:6455 actual:1 predicted plain:0.48966697
# index:6455 actual:1 predicted html:[0.68]
# index:6474 actual:1 predicted plain:0.44101194
# index:6474 actual:1 predicted html:[0.68]
# index:6500 actual:0 predicted plain:0.6099663
# index:6500 actual:0 predicted html:[0.49]
# index:6517 actual:1 predicted plain:0.47203895
# index:6517 actual:1 predicted html:[0.74]
# index:6557 actual:1 predicted plain:0.36580184
# index:6557 actual:1 predicted html:[0.64]
# index:6570 actual:1 predicted plain:0.3607842
# index:6570 actual:1 predicted html:[0.79]
# index:6573 actual:1 predicted plain:0.38773116
# index:6573 actual:1 predicted html:[0.62]
# index:6585 actual:1 predicted plain:0.37859136
# index:6585 actual:1 predicted html:[0.85]
# index:6590 actual:1 predicted plain:0.34366465
# index:6590 actual:1 predicted html:[0.64]
# index:6597 actual:1 predicted plain:0.4103525
# index:6597 actual:1 predicted html:[0.59]
# index:6614 actual:1 predicted plain:0.44493642
# index:6614 actual:1 predicted html:[0.51]
# index:6650 actual:1 predicted plain:0.4787352
# index:6650 actual:1 predicted html:[0.69]
# index:6699 actual:0 predicted plain:0.5807938
# index:6699 actual:0 predicted html:[0.28]
# index:6772 actual:1 predicted plain:0.43345326
# index:6772 actual:1 predicted html:[0.57]
# index:6844 actual:1 predicted plain:0.2969792
# index:6844 actual:1 predicted html:[0.58]
# index:6845 actual:1 predicted plain:0.49466044
# index:6845 actual:1 predicted html:[0.69]
# index:6864 actual:1 predicted plain:0.48833779
# index:6864 actual:1 predicted html:[0.7]
# index:6874 actual:0 predicted plain:0.50913453
# index:6874 actual:0 predicted html:[0.49]
# index:6957 actual:1 predicted plain:0.44935155
# index:6957 actual:1 predicted html:[0.64]
# index:6961 actual:1 predicted plain:0.43522525
# index:6961 actual:1 predicted html:[0.55]
# index:6988 actual:1 predicted plain:0.44964015
# index:6988 actual:1 predicted html:[0.68]
# index:7018 actual:1 predicted plain:0.44917977
# index:7018 actual:1 predicted html:[0.63]
# index:7066 actual:1 predicted plain:0.32291788
# index:7066 actual:1 predicted html:[0.56]
# index:7069 actual:0 predicted plain:0.6311557
# index:7069 actual:0 predicted html:[0.46]
# index:7108 actual:1 predicted plain:0.41329134
# index:7108 actual:1 predicted html:[0.64]
# index:7118 actual:0 predicted plain:0.64588535
# index:7118 actual:0 predicted html:[0.41]
# index:7121 actual:1 predicted plain:0.43000102
# index:7121 actual:1 predicted html:[0.7]
# index:7123 actual:1 predicted plain:0.43511644
# index:7123 actual:1 predicted html:[0.79]
# index:7134 actual:1 predicted plain:0.47775796
# index:7134 actual:1 predicted html:[0.67]
# index:7172 actual:1 predicted plain:0.4735511
# index:7172 actual:1 predicted html:[0.51]
# index:7220 actual:1 predicted plain:0.4238736
# index:7220 actual:1 predicted html:[0.67]
# index:7227 actual:1 predicted plain:0.30532026
# index:7227 actual:1 predicted html:[0.65]
# index:7288 actual:0 predicted plain:0.6667626
# index:7288 actual:0 predicted html:[0.31]
# index:7290 actual:1 predicted plain:0.46901715
# index:7290 actual:1 predicted html:[0.82]
# index:7310 actual:1 predicted plain:0.45362064
# index:7310 actual:1 predicted html:[0.57]
# index:7316 actual:1 predicted plain:0.49712908
# index:7316 actual:1 predicted html:[0.69]
# index:7321 actual:1 predicted plain:0.42143783
# index:7321 actual:1 predicted html:[0.54]
# index:7325 actual:0 predicted plain:0.5199314
# index:7325 actual:0 predicted html:[0.38]
# index:7349 actual:1 predicted plain:0.34013113
# index:7349 actual:1 predicted html:[0.56]
# index:7368 actual:1 predicted plain:0.28289318
# index:7368 actual:1 predicted html:[0.77]
# index:7374 actual:1 predicted plain:0.49703968
# index:7374 actual:1 predicted html:[0.51]
# index:7384 actual:1 predicted plain:0.34050804
# index:7384 actual:1 predicted html:[0.68]
# index:7386 actual:1 predicted plain:0.40376714
# index:7386 actual:1 predicted html:[0.69]
# index:7408 actual:1 predicted plain:0.45419404
# index:7408 actual:1 predicted html:[0.61]
# index:7415 actual:1 predicted plain:0.4161734
# index:7415 actual:1 predicted html:[0.56]
# index:7431 actual:1 predicted plain:0.4599422
# index:7431 actual:1 predicted html:[0.59]
# index:7458 actual:1 predicted plain:0.45893657
# index:7458 actual:1 predicted html:[0.55]
# index:7505 actual:0 predicted plain:0.58876103
# index:7505 actual:0 predicted html:[0.5]
# index:7527 actual:1 predicted plain:0.39708295
# index:7527 actual:1 predicted html:[0.7]
# index:7536 actual:1 predicted plain:0.41648406
# index:7536 actual:1 predicted html:[0.64]
# index:7548 actual:1 predicted plain:0.48738742
# index:7548 actual:1 predicted html:[0.8]
# index:7550 actual:1 predicted plain:0.45787656
# index:7550 actual:1 predicted html:[0.71]
# index:7552 actual:0 predicted plain:0.5474755
# index:7552 actual:0 predicted html:[0.45]
# index:7555 actual:1 predicted plain:0.491367
# index:7555 actual:1 predicted html:[0.58]
# index:7595 actual:1 predicted plain:0.48749998
# index:7595 actual:1 predicted html:[0.77]
# index:7609 actual:1 predicted plain:0.24270456
# index:7609 actual:1 predicted html:[0.79]
# index:7643 actual:1 predicted plain:0.3985876
# index:7643 actual:1 predicted html:[0.65]
# index:7722 actual:1 predicted plain:0.4398559
# index:7722 actual:1 predicted html:[0.61]
# index:7733 actual:1 predicted plain:0.47458363
# index:7733 actual:1 predicted html:[0.7]
# index:7757 actual:1 predicted plain:0.4754864
# index:7757 actual:1 predicted html:[0.7]
# index:7772 actual:1 predicted plain:0.41202936
# index:7772 actual:1 predicted html:[0.78]
# index:7788 actual:1 predicted plain:0.45447993
# index:7788 actual:1 predicted html:[0.7]
# index:7793 actual:0 predicted plain:0.5582551
# index:7793 actual:0 predicted html:[0.43]
# index:7852 actual:0 predicted plain:0.7000406
# index:7852 actual:0 predicted html:[0.48]
# index:7863 actual:1 predicted plain:0.44665435
# index:7863 actual:1 predicted html:[0.87]
# index:7875 actual:0 predicted plain:0.5843589
# index:7875 actual:0 predicted html:[0.4]
# index:7904 actual:1 predicted plain:0.38782272
# index:7904 actual:1 predicted html:[0.65]
# index:7945 actual:0 predicted plain:0.54754406
# index:7945 actual:0 predicted html:[0.21]
# index:7974 actual:1 predicted plain:0.4582538
# index:7974 actual:1 predicted html:[0.64]
# index:7996 actual:0 predicted plain:0.58753633
# index:7996 actual:0 predicted html:[0.41]
# index:7999 actual:1 predicted plain:0.49527645
# index:7999 actual:1 predicted html:[0.75]
# index:8003 actual:1 predicted plain:0.4749918
# index:8003 actual:1 predicted html:[0.58]
# index:8011 actual:1 predicted plain:0.38400206
# index:8011 actual:1 predicted html:[0.73]
# index:8036 actual:1 predicted plain:0.39052618
# index:8036 actual:1 predicted html:[0.71]
# index:8056 actual:1 predicted plain:0.45730868
# index:8056 actual:1 predicted html:[0.7]
# index:8078 actual:1 predicted plain:0.2832239
# index:8078 actual:1 predicted html:[0.81]
# index:8096 actual:1 predicted plain:0.42690164
# index:8096 actual:1 predicted html:[0.55]
# index:8117 actual:1 predicted plain:0.43010324
# index:8117 actual:1 predicted html:[0.81]
# index:8171 actual:0 predicted plain:0.6089528
# index:8171 actual:0 predicted html:[0.44]
# index:8196 actual:1 predicted plain:0.33142442
# index:8196 actual:1 predicted html:[0.77]
# index:8240 actual:1 predicted plain:0.4042632
# index:8240 actual:1 predicted html:[0.62]
# index:8245 actual:1 predicted plain:0.44020283
# index:8245 actual:1 predicted html:[0.67]
# index:8246 actual:1 predicted plain:0.43234828
# index:8246 actual:1 predicted html:[0.74]
# index:8264 actual:1 predicted plain:0.27205783
# index:8264 actual:1 predicted html:[0.56]
# index:8301 actual:1 predicted plain:0.494021
# index:8301 actual:1 predicted html:[0.74]
# index:8327 actual:0 predicted plain:0.64246106
# index:8327 actual:0 predicted html:[0.37]
# index:8337 actual:1 predicted plain:0.4376982
# index:8337 actual:1 predicted html:[0.72]
# index:8378 actual:1 predicted plain:0.37761953
# index:8378 actual:1 predicted html:[0.66]
# index:8394 actual:1 predicted plain:0.39324626
# index:8394 actual:1 predicted html:[0.79]
# index:8410 actual:1 predicted plain:0.49195498
# index:8410 actual:1 predicted html:[0.75]
# index:8427 actual:0 predicted plain:0.5409673
# index:8427 actual:0 predicted html:[0.5]
# index:8433 actual:1 predicted plain:0.41941074
# index:8433 actual:1 predicted html:[0.68]
# index:8441 actual:1 predicted plain:0.4590941
# index:8441 actual:1 predicted html:[0.69]
# index:8445 actual:1 predicted plain:0.46493694
# index:8445 actual:1 predicted html:[0.7]
# index:8456 actual:1 predicted plain:0.45853475
# index:8456 actual:1 predicted html:[0.56]
# index:8463 actual:0 predicted plain:0.70545226
# index:8463 actual:0 predicted html:[0.41]
# index:8555 actual:1 predicted plain:0.3710972
# index:8555 actual:1 predicted html:[0.58]
# index:8570 actual:1 predicted plain:0.38814455
# index:8570 actual:1 predicted html:[0.52]
# index:8573 actual:1 predicted plain:0.46583542
# index:8573 actual:1 predicted html:[0.59]
# index:8607 actual:0 predicted plain:0.5067788
# index:8607 actual:0 predicted html:[0.22]
# index:8659 actual:0 predicted plain:0.55178744
# index:8659 actual:0 predicted html:[0.49]
# index:8666 actual:1 predicted plain:0.44710255
# index:8666 actual:1 predicted html:[0.7]
# index:8691 actual:0 predicted plain:0.65523684
# index:8691 actual:0 predicted html:[0.49]
# index:8717 actual:1 predicted plain:0.4683632
# index:8717 actual:1 predicted html:[0.76]
# index:8743 actual:1 predicted plain:0.46303204
# index:8743 actual:1 predicted html:[0.55]
# index:8754 actual:1 predicted plain:0.30973908
# index:8754 actual:1 predicted html:[0.79]
# index:8894 actual:1 predicted plain:0.4108583
# index:8894 actual:1 predicted html:[0.71]
# index:8907 actual:0 predicted plain:0.5224876
# index:8907 actual:0 predicted html:[0.48]
# index:8921 actual:0 predicted plain:0.5843347
# index:8921 actual:0 predicted html:[0.44]
# index:8963 actual:1 predicted plain:0.4722545
# index:8963 actual:1 predicted html:[0.55]
# index:8982 actual:0 predicted plain:0.5588162
# index:8982 actual:0 predicted html:[0.41]
# index:8983 actual:1 predicted plain:0.45364857
# index:8983 actual:1 predicted html:[0.66]
# index:9033 actual:1 predicted plain:0.45657247
# index:9033 actual:1 predicted html:[0.72]
# index:9092 actual:1 predicted plain:0.4503375
# index:9092 actual:1 predicted html:[0.57]
# index:9111 actual:1 predicted plain:0.49272525
# index:9111 actual:1 predicted html:[0.74]
# index:9178 actual:1 predicted plain:0.35786706
# index:9178 actual:1 predicted html:[0.51]
# index:9193 actual:1 predicted plain:0.34188667
# index:9193 actual:1 predicted html:[0.68]
# index:9211 actual:1 predicted plain:0.4130217
# index:9211 actual:1 predicted html:[0.78]
# index:9259 actual:1 predicted plain:0.31523633
# index:9259 actual:1 predicted html:[0.69]
# index:9269 actual:1 predicted plain:0.49637774
# index:9269 actual:1 predicted html:[0.66]
# index:9282 actual:1 predicted plain:0.43019518
# index:9282 actual:1 predicted html:[0.65]
# index:9296 actual:0 predicted plain:0.56827015
# index:9296 actual:0 predicted html:[0.29]
# index:9312 actual:1 predicted plain:0.47397134
# index:9312 actual:1 predicted html:[0.63]
# index:9328 actual:1 predicted plain:0.459331
# index:9328 actual:1 predicted html:[0.73]
# index:9340 actual:1 predicted plain:0.43267858
# index:9340 actual:1 predicted html:[0.74]
# index:9342 actual:1 predicted plain:0.37537658
# index:9342 actual:1 predicted html:[0.51]
# index:9343 actual:1 predicted plain:0.3764381
# index:9343 actual:1 predicted html:[0.52]
# index:9353 actual:1 predicted plain:0.47850692
# index:9353 actual:1 predicted html:[0.75]
# index:9410 actual:1 predicted plain:0.4930335
# index:9410 actual:1 predicted html:[0.65]
# index:9444 actual:1 predicted plain:0.49625856
# index:9444 actual:1 predicted html:[0.69]
# index:9456 actual:1 predicted plain:0.47338277
# index:9456 actual:1 predicted html:[0.71]
# index:9478 actual:1 predicted plain:0.4292814
# index:9478 actual:1 predicted html:[0.72]
# index:9489 actual:1 predicted plain:0.4495203
# index:9489 actual:1 predicted html:[0.68]
# index:9503 actual:1 predicted plain:0.39645985
# index:9503 actual:1 predicted html:[0.75]
# index:9546 actual:1 predicted plain:0.46603948
# index:9546 actual:1 predicted html:[0.75]
# index:9550 actual:1 predicted plain:0.49519792
# index:9550 actual:1 predicted html:[0.68]
# index:9557 actual:1 predicted plain:0.49507967
# index:9557 actual:1 predicted html:[0.59]
# index:9567 actual:0 predicted plain:0.7222215
# index:9567 actual:0 predicted html:[0.5]
# index:9580 actual:1 predicted plain:0.35973606
# index:9580 actual:1 predicted html:[0.58]
# index:9609 actual:1 predicted plain:0.2794766
# index:9609 actual:1 predicted html:[0.72]
# index:9632 actual:1 predicted plain:0.40936586
# index:9632 actual:1 predicted html:[0.64]
# index:9644 actual:1 predicted plain:0.45656747
# index:9644 actual:1 predicted html:[0.66]
# index:9645 actual:1 predicted plain:0.49983948
# index:9645 actual:1 predicted html:[0.77]
# index:9674 actual:1 predicted plain:0.44547036
# index:9674 actual:1 predicted html:[0.58]
# index:9679 actual:0 predicted plain:0.57370377
# index:9679 actual:0 predicted html:[0.5]
# index:9706 actual:1 predicted plain:0.36622807
# index:9706 actual:1 predicted html:[0.65]
# index:9729 actual:1 predicted plain:0.49008536
# index:9729 actual:1 predicted html:[0.58]
# index:9770 actual:1 predicted plain:0.353874
# index:9770 actual:1 predicted html:[0.72]
# index:9816 actual:1 predicted plain:0.37672788
# index:9816 actual:1 predicted html:[0.82]
# index:9829 actual:1 predicted plain:0.49744746
# index:9829 actual:1 predicted html:[0.6]
# index:9855 actual:1 predicted plain:0.40639228
# index:9855 actual:1 predicted html:[0.71]
# index:9856 actual:1 predicted plain:0.48572046
# index:9856 actual:1 predicted html:[0.69]
# index:9877 actual:1 predicted plain:0.23509328
# index:9877 actual:1 predicted html:[0.58]
# index:9920 actual:1 predicted plain:0.48045084
# index:9920 actual:1 predicted html:[0.64]
# index:10002 actual:1 predicted plain:0.45237106
# index:10002 actual:1 predicted html:[0.59]
# index:10007 actual:1 predicted plain:0.37349147
# index:10007 actual:1 predicted html:[0.71]
# index:10059 actual:1 predicted plain:0.37302086
# index:10059 actual:1 predicted html:[0.51]
# index:10067 actual:1 predicted plain:0.42098784
# index:10067 actual:1 predicted html:[0.59]
# index:10081 actual:1 predicted plain:0.42209363
# index:10081 actual:1 predicted html:[0.76]
# index:10106 actual:1 predicted plain:0.49598277
# index:10106 actual:1 predicted html:[0.56]
# index:10144 actual:1 predicted plain:0.4675134
# index:10144 actual:1 predicted html:[0.68]
# index:10157 actual:0 predicted plain:0.7306118
# index:10157 actual:0 predicted html:[0.37]
# index:10170 actual:1 predicted plain:0.34747967
# index:10170 actual:1 predicted html:[0.72]
# index:10174 actual:1 predicted plain:0.42410558
# index:10174 actual:1 predicted html:[0.79]
# index:10209 actual:1 predicted plain:0.45464346
# index:10209 actual:1 predicted html:[0.71]
# index:10287 actual:1 predicted plain:0.47300002
# index:10287 actual:1 predicted html:[0.58]
# index:10381 actual:1 predicted plain:0.3423113
# index:10381 actual:1 predicted html:[0.71]
# index:10458 actual:0 predicted plain:0.5879409
# index:10458 actual:0 predicted html:[0.3]
# index:10466 actual:1 predicted plain:0.48694956
# index:10466 actual:1 predicted html:[0.61]
# index:10518 actual:1 predicted plain:0.42986134
# index:10518 actual:1 predicted html:[0.57]
# index:10539 actual:1 predicted plain:0.37301108
# index:10539 actual:1 predicted html:[0.66]
# index:10542 actual:1 predicted plain:0.37590665
# index:10542 actual:1 predicted html:[0.78]
# index:10564 actual:1 predicted plain:0.41732612
# index:10564 actual:1 predicted html:[0.78]
# index:10573 actual:1 predicted plain:0.47769538
# index:10573 actual:1 predicted html:[0.84]
# index:10581 actual:0 predicted plain:0.59880376
# index:10581 actual:0 predicted html:[0.44]
# index:10600 actual:1 predicted plain:0.42393655
# index:10600 actual:1 predicted html:[0.76]
# index:10604 actual:1 predicted plain:0.4940419
# index:10604 actual:1 predicted html:[0.61]
# index:10633 actual:1 predicted plain:0.4649424
# index:10633 actual:1 predicted html:[0.65]
# index:10661 actual:1 predicted plain:0.4912922
# index:10661 actual:1 predicted html:[0.75]
# index:10707 actual:1 predicted plain:0.4076334
# index:10707 actual:1 predicted html:[0.77]
# index:10708 actual:0 predicted plain:0.5895793
# index:10708 actual:0 predicted html:[0.45]
# index:10718 actual:1 predicted plain:0.458219
# index:10718 actual:1 predicted html:[0.56]
# index:10757 actual:1 predicted plain:0.39623243
# index:10757 actual:1 predicted html:[0.75]
# index:10761 actual:1 predicted plain:0.42101493
# index:10761 actual:1 predicted html:[0.7]
# index:10809 actual:1 predicted plain:0.47166705
# index:10809 actual:1 predicted html:[0.8]
# index:10810 actual:1 predicted plain:0.40800625
# index:10810 actual:1 predicted html:[0.64]
# index:10838 actual:1 predicted plain:0.3641356
# index:10838 actual:1 predicted html:[0.71]
# index:10856 actual:1 predicted plain:0.4246329
# index:10856 actual:1 predicted html:[0.69]
# index:10859 actual:1 predicted plain:0.49152225
# index:10859 actual:1 predicted html:[0.72]
# index:10879 actual:1 predicted plain:0.4942883
# index:10879 actual:1 predicted html:[0.58]
# index:10891 actual:1 predicted plain:0.4348841
# index:10891 actual:1 predicted html:[0.75]
# index:10902 actual:1 predicted plain:0.29077974
# index:10902 actual:1 predicted html:[0.52]
# index:10945 actual:1 predicted plain:0.47619677
# index:10945 actual:1 predicted html:[0.75]
# index:11013 actual:1 predicted plain:0.48190826
# index:11013 actual:1 predicted html:[0.74]
# index:11023 actual:1 predicted plain:0.4915152
# index:11023 actual:1 predicted html:[0.73]
# index:11042 actual:1 predicted plain:0.4335017
# index:11042 actual:1 predicted html:[0.53]
# index:11044 actual:1 predicted plain:0.42570037
# index:11044 actual:1 predicted html:[0.7]
# index:11056 actual:0 predicted plain:0.5318195
# index:11056 actual:0 predicted html:[0.41]
# index:11062 actual:1 predicted plain:0.32822856
# index:11062 actual:1 predicted html:[0.67]

# %%
print_wrong_plain_data_correct_data(model_predictions['CO:400, E:5, plain_data, adam'], model_predictions['CO:800, E:10, data, adam'], predictors_test['work_stayed'].astype(int), True)

# %%
def norm_pred(lstm_out):
    results = []
    for index, value in enumerate(lstm_out):
        results.append(round(value[0]))
    return results


norm_ = norm_pred(model_predictions['CO:800, E:10, data, adam'])
confusion_mat = confusion_matrix(predictors_test['work_stayed'].astype(int), norm_)

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(3,4))
plot_confusion_matrix(confusion_mat, classes=[0,1], title='HTML')

# %%
norm_ = norm_pred(model_predictions['CO:400, E:5, plain_data, adam'])
confusion_mat = confusion_matrix(predictors_test['work_stayed'].astype(int), norm_)

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(3,4))
plot_confusion_matrix(confusion_mat, classes=[0,1], title='Plain Text')

# %%
train_lstm_rnn(5, 300, 'data', 400, "adam", 0.1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 400)               0
# _________________________________________________________________
# embedding_3 (Embedding)      (None, 400, 300)          83308500
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 400, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_3 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                6050
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 83,487,881
# Trainable params: 179,381
# Non-trainable params: 83,308,500
# _________________________________________________________________
# Train on 19979 samples, validate on 2220 samples
# Epoch 1/5
# 19979/19979 [==============================] - 338s 17ms/step - loss: 0.5717 - acc: 0.6620 - cosine_proximity: -0.5747 - f1: 0.7437 - val_loss: 0.4943 - val_acc: 0.7167 - val_cosine_proximity: -0.5734 - val_f1: 0.7983
# Epoch 2/5
# 19979/19979 [==============================] - 332s 17ms/step - loss: 0.4716 - acc: 0.7318 - cosine_proximity: -0.5747 - f1: 0.7997 - val_loss: 0.4653 - val_acc: 0.7351 - val_cosine_proximity: -0.5734 - val_f1: 0.8089
# Epoch 3/5
# 19979/19979 [==============================] - 321s 16ms/step - loss: 0.4583 - acc: 0.7395 - cosine_proximity: -0.5747 - f1: 0.8085 - val_loss: 0.4611 - val_acc: 0.7351 - val_cosine_proximity: -0.5734 - val_f1: 0.8081
# Epoch 4/5
# 19979/19979 [==============================] - 317s 16ms/step - loss: 0.4538 - acc: 0.7404 - cosine_proximity: -0.5747 - f1: 0.8084 - val_loss: 0.4576 - val_acc: 0.7383 - val_cosine_proximity: -0.5734 - val_f1: 0.8098
# Epoch 5/5
# 19979/19979 [==============================] - 321s 16ms/step - loss: 0.4520 - acc: 0.7427 - cosine_proximity: -0.5747 - f1: 0.8082 - val_loss: 0.4556 - val_acc: 0.7374 - val_cosine_proximity: -0.5734 - val_f1: 0.8100
# classification F score: 0.71718

# %%
train_lstm_rnn(5, 300, 'plain_data', 400, "adam", 0.1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 400)               0
# _________________________________________________________________
# embedding_4 (Embedding)      (None, 400, 300)          63059100
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 400, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_4 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                6050
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 63,238,481
# Trainable params: 179,381
# Non-trainable params: 63,059,100
# _________________________________________________________________
# Train on 19979 samples, validate on 2220 samples
# Epoch 1/5
# 19979/19979 [==============================] - 332s 17ms/step - loss: 0.6716 - acc: 0.5853 - cosine_proximity: -0.5747 - f1: 0.7000 - val_loss: 0.6602 - val_acc: 0.6036 - val_cosine_proximity: -0.5734 - val_f1: 0.7157
# Epoch 2/5
# 19979/19979 [==============================] - 336s 17ms/step - loss: 0.6578 - acc: 0.6107 - cosine_proximity: -0.5747 - f1: 0.6992 - val_loss: 0.6555 - val_acc: 0.6257 - val_cosine_proximity: -0.5734 - val_f1: 0.6901
# Epoch 3/5
# 19979/19979 [==============================] - 339s 17ms/step - loss: 0.6488 - acc: 0.6256 - cosine_proximity: -0.5747 - f1: 0.7029 - val_loss: 0.6486 - val_acc: 0.6207 - val_cosine_proximity: -0.5734 - val_f1: 0.6714
# Epoch 4/5
# 19979/19979 [==============================] - 338s 17ms/step - loss: 0.6359 - acc: 0.6389 - cosine_proximity: -0.5747 - f1: 0.7070 - val_loss: 0.6390 - val_acc: 0.6315 - val_cosine_proximity: -0.5734 - val_f1: 0.6808
# Epoch 5/5
# 19979/19979 [==============================] - 339s 17ms/step - loss: 0.6190 - acc: 0.6583 - cosine_proximity: -0.5747 - f1: 0.7196 - val_loss: 0.6342 - val_acc: 0.6383 - val_cosine_proximity: -0.5734 - val_f1: 0.7103
# classification F score: 0.66921

# %%
train_lstm_rnn(5, 300, 'data', 800, "adam", 0.1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 800)               0
# _________________________________________________________________
# embedding_5 (Embedding)      (None, 800, 300)          83308500
# _________________________________________________________________
# bidirectional_5 (Bidirection (None, 800, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_5 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 50)                6050
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 83,487,881
# Trainable params: 179,381
# Non-trainable params: 83,308,500
# _________________________________________________________________
# Train on 19979 samples, validate on 2220 samples
# Epoch 1/5
# 19979/19979 [==============================] - 685s 34ms/step - loss: 0.5541 - acc: 0.6894 - cosine_proximity: -0.5747 - f1: 0.7531 - val_loss: 0.5548 - val_acc: 0.8288 - val_cosine_proximity: -0.5734 - val_f1: 0.8672
# Epoch 2/5
# 19979/19979 [==============================] - 687s 34ms/step - loss: 0.2393 - acc: 0.8786 - cosine_proximity: -0.5747 - f1: 0.8982 - val_loss: 0.1912 - val_acc: 0.8973 - val_cosine_proximity: -0.5734 - val_f1: 0.9142
# Epoch 3/5
# 19979/19979 [==============================] - 687s 34ms/step - loss: 0.1915 - acc: 0.8958 - cosine_proximity: -0.5747 - f1: 0.9141 - val_loss: 0.1872 - val_acc: 0.9000 - val_cosine_proximity: -0.5734 - val_f1: 0.9181
# Epoch 4/5
# 19979/19979 [==============================] - 687s 34ms/step - loss: 0.1917 - acc: 0.8955 - cosine_proximity: -0.5747 - f1: 0.9128 - val_loss: 0.1876 - val_acc: 0.9009 - val_cosine_proximity: -0.5734 - val_f1: 0.9187
# Epoch 5/5
# 19979/19979 [==============================] - 687s 34ms/step - loss: 0.1856 - acc: 0.8986 - cosine_proximity: -0.5747 - f1: 0.9166 - val_loss: 0.1849 - val_acc: 0.8995 - val_cosine_proximity: -0.5734 - val_f1: 0.9177
# classification F score: 0.78281

# %%
train_lstm_rnn(5, 300, 'plain_data', 800, "adam", 0.1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 800)               0
# _________________________________________________________________
# embedding_6 (Embedding)      (None, 800, 300)          63059100
# _________________________________________________________________
# bidirectional_6 (Bidirection (None, 800, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_6 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 120)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 50)                6050
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 63,238,481
# Trainable params: 179,381
# Non-trainable params: 63,059,100
# _________________________________________________________________
# Train on 19979 samples, validate on 2220 samples
# Epoch 1/5
# 19979/19979 [==============================] - 678s 34ms/step - loss: 0.6710 - acc: 0.5876 - cosine_proximity: -0.5747 - f1: 0.7052 - val_loss: 0.6623 - val_acc: 0.5901 - val_cosine_proximity: -0.5734 - val_f1: 0.7260
# Epoch 2/5
# 19979/19979 [==============================] - 683s 34ms/step - loss: 0.6511 - acc: 0.6163 - cosine_proximity: -0.5747 - f1: 0.6965 - val_loss: 0.6409 - val_acc: 0.6338 - val_cosine_proximity: -0.5734 - val_f1: 0.7090
# Epoch 3/5
# 19979/19979 [==============================] - 683s 34ms/step - loss: 0.6348 - acc: 0.6399 - cosine_proximity: -0.5747 - f1: 0.7058 - val_loss: 0.6339 - val_acc: 0.6369 - val_cosine_proximity: -0.5734 - val_f1: 0.6708
# Epoch 4/5
# 19979/19979 [==============================] - 683s 34ms/step - loss: 0.6148 - acc: 0.6595 - cosine_proximity: -0.5747 - f1: 0.7142 - val_loss: 0.6133 - val_acc: 0.6599 - val_cosine_proximity: -0.5734 - val_f1: 0.7116
# Epoch 5/5
# 19979/19979 [==============================] - 684s 34ms/step - loss: 0.6014 - acc: 0.6743 - cosine_proximity: -0.5747 - f1: 0.7250 - val_loss: 0.6207 - val_acc: 0.6509 - val_cosine_proximity: -0.5734 - val_f1: 0.7309
# classification F score: 0.68748

# %%
train_lstm_rnn(10, 300, 'data', 800, "adam", 0.1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 800)               0
# _________________________________________________________________
# embedding_7 (Embedding)      (None, 800, 300)          83308500
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, 800, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_7 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 120)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 50)                6050
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 83,487,881
# Trainable params: 179,381
# Non-trainable params: 83,308,500
# _________________________________________________________________
# Train on 19979 samples, validate on 2220 samples
# Epoch 1/10
# 19979/19979 [==============================] - 685s 34ms/step - loss: 0.3927 - acc: 0.7816 - cosine_proximity: -0.5747 - f1: 0.8311 - val_loss: 0.1816 - val_acc: 0.9108 - val_cosine_proximity: -0.5734 - val_f1: 0.9262
# Epoch 2/10
# 19979/19979 [==============================] - 689s 34ms/step - loss: 0.1800 - acc: 0.9079 - cosine_proximity: -0.5747 - f1: 0.9234 - val_loss: 0.1775 - val_acc: 0.9095 - val_cosine_proximity: -0.5734 - val_f1: 0.9248
# Epoch 3/10
# 19979/19979 [==============================] - 688s 34ms/step - loss: 0.1745 - acc: 0.9083 - cosine_proximity: -0.5747 - f1: 0.9236 - val_loss: 0.1768 - val_acc: 0.9104 - val_cosine_proximity: -0.5734 - val_f1: 0.9257
# Epoch 4/10
# 19979/19979 [==============================] - 691s 35ms/step - loss: 0.1730 - acc: 0.9090 - cosine_proximity: -0.5747 - f1: 0.9240 - val_loss: 0.1749 - val_acc: 0.9113 - val_cosine_proximity: -0.5734 - val_f1: 0.9267
# Epoch 5/10
# 19979/19979 [==============================] - 690s 35ms/step - loss: 0.1719 - acc: 0.9094 - cosine_proximity: -0.5747 - f1: 0.9248 - val_loss: 0.1754 - val_acc: 0.9113 - val_cosine_proximity: -0.5734 - val_f1: 0.9267
# Epoch 6/10
# 19979/19979 [==============================] - 690s 35ms/step - loss: 0.1694 - acc: 0.9109 - cosine_proximity: -0.5747 - f1: 0.9259 - val_loss: 0.1753 - val_acc: 0.9108 - val_cosine_proximity: -0.5734 - val_f1: 0.9264
# Epoch 7/10
# 19979/19979 [==============================] - 690s 35ms/step - loss: 0.1672 - acc: 0.9115 - cosine_proximity: -0.5747 - f1: 0.9260 - val_loss: 0.1765 - val_acc: 0.9104 - val_cosine_proximity: -0.5734 - val_f1: 0.9257
# Epoch 8/10
# 19979/19979 [==============================] - 705s 35ms/step - loss: 0.1650 - acc: 0.9126 - cosine_proximity: -0.5747 - f1: 0.9270 - val_loss: 0.1796 - val_acc: 0.9117 - val_cosine_proximity: -0.5734 - val_f1: 0.9270
# Epoch 9/10
# 19979/19979 [==============================] - 711s 36ms/step - loss: 0.1620 - acc: 0.9156 - cosine_proximity: -0.5747 - f1: 0.9282 - val_loss: 0.1831 - val_acc: 0.9108 - val_cosine_proximity: -0.5734 - val_f1: 0.9259
# Epoch 10/10
# 19979/19979 [==============================] - 712s 36ms/step - loss: 0.1561 - acc: 0.9183 - cosine_proximity: -0.5747 - f1: 0.9298 - val_loss: 0.1840 - val_acc: 0.9090 - val_cosine_proximity: -0.5734 - val_f1: 0.9242
# classification F score: 0.84682

# %%
train_lstm_rnn(10, 300, 'plain_data', 800, "adam", 0.1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 800)               0
# _________________________________________________________________
# embedding_8 (Embedding)      (None, 800, 300)          63059100
# _________________________________________________________________
# bidirectional_8 (Bidirection (None, 800, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_8 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 120)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 50)                6050
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 63,238,481
# Trainable params: 179,381
# Non-trainable params: 63,059,100
# _________________________________________________________________
# Train on 19979 samples, validate on 2220 samples
# Epoch 1/10
# 19979/19979 [==============================] - 700s 35ms/step - loss: 0.6700 - acc: 0.5886 - cosine_proximity: -0.5747 - f1: 0.7026 - val_loss: 0.6544 - val_acc: 0.6162 - val_cosine_proximity: -0.5734 - val_f1: 0.6796
# Epoch 2/10
# 19979/19979 [==============================] - 701s 35ms/step - loss: 0.6530 - acc: 0.6179 - cosine_proximity: -0.5747 - f1: 0.7006 - val_loss: 0.6453 - val_acc: 0.6320 - val_cosine_proximity: -0.5734 - val_f1: 0.6941
# Epoch 3/10
# 19979/19979 [==============================] - 703s 35ms/step - loss: 0.6391 - acc: 0.6328 - cosine_proximity: -0.5747 - f1: 0.7019 - val_loss: 0.6403 - val_acc: 0.6338 - val_cosine_proximity: -0.5734 - val_f1: 0.7225
# Epoch 4/10
# 19979/19979 [==============================] - 702s 35ms/step - loss: 0.6246 - acc: 0.6522 - cosine_proximity: -0.5747 - f1: 0.7113 - val_loss: 0.6273 - val_acc: 0.6459 - val_cosine_proximity: -0.5734 - val_f1: 0.7165
# Epoch 5/10
# 19979/19979 [==============================] - 702s 35ms/step - loss: 0.6075 - acc: 0.6690 - cosine_proximity: -0.5747 - f1: 0.7213 - val_loss: 0.6192 - val_acc: 0.6536 - val_cosine_proximity: -0.5734 - val_f1: 0.6948
# Epoch 6/10
# 19979/19979 [==============================] - 701s 35ms/step - loss: 0.5892 - acc: 0.6852 - cosine_proximity: -0.5747 - f1: 0.7308 - val_loss: 0.6110 - val_acc: 0.6626 - val_cosine_proximity: -0.5734 - val_f1: 0.7118
# Epoch 7/10
# 19979/19979 [==============================] - 702s 35ms/step - loss: 0.5718 - acc: 0.7013 - cosine_proximity: -0.5747 - f1: 0.7425 - val_loss: 0.6094 - val_acc: 0.6613 - val_cosine_proximity: -0.5734 - val_f1: 0.7066
# Epoch 8/10
# 19979/19979 [==============================] - 699s 35ms/step - loss: 0.5530 - acc: 0.7177 - cosine_proximity: -0.5747 - f1: 0.7577 - val_loss: 0.6240 - val_acc: 0.6572 - val_cosine_proximity: -0.5734 - val_f1: 0.6830
# Epoch 9/10
# 19979/19979 [==============================] - 699s 35ms/step - loss: 0.5339 - acc: 0.7332 - cosine_proximity: -0.5747 - f1: 0.7698 - val_loss: 0.6151 - val_acc: 0.6698 - val_cosine_proximity: -0.5734 - val_f1: 0.6932
# Epoch 10/10
# 19979/19979 [==============================] - 826s 41ms/step - loss: 0.5159 - acc: 0.7445 - cosine_proximity: -0.5747 - f1: 0.7777 - val_loss: 0.6270 - val_acc: 0.6581 - val_cosine_proximity: -0.5734 - val_f1: 0.6733
# classification F score: 0.68776

# %%
train_lstm_rnn(15, 300, 'data', 400, "adam", 0.05)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 400)               0
# _________________________________________________________________
# embedding_9 (Embedding)      (None, 400, 300)          83308500
# _________________________________________________________________
# bidirectional_9 (Bidirection (None, 400, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_9 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 120)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 50)                6050
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 83,487,881
# Trainable params: 179,381
# Non-trainable params: 83,308,500
# _________________________________________________________________
# Train on 19979 samples, validate on 2220 samples
# Epoch 1/15
# 19979/19979 [==============================] - 456s 23ms/step - loss: 0.5622 - acc: 0.6709 - cosine_proximity: -0.5747 - f1: 0.7560 - val_loss: 0.4842 - val_acc: 0.7153 - val_cosine_proximity: -0.5734 - val_f1: 0.7969
# Epoch 2/15
# 19979/19979 [==============================] - 472s 24ms/step - loss: 0.4765 - acc: 0.7210 - cosine_proximity: -0.5747 - f1: 0.7933 - val_loss: 0.4826 - val_acc: 0.7171 - val_cosine_proximity: -0.5734 - val_f1: 0.7988
# Epoch 3/15
# 19979/19979 [==============================] - 442s 22ms/step - loss: 0.4734 - acc: 0.7223 - cosine_proximity: -0.5747 - f1: 0.7962 - val_loss: 0.4839 - val_acc: 0.7171 - val_cosine_proximity: -0.5734 - val_f1: 0.7988
# Epoch 4/15
# 19979/19979 [==============================] - 450s 23ms/step - loss: 0.4708 - acc: 0.7229 - cosine_proximity: -0.5747 - f1: 0.7971 - val_loss: 0.4788 - val_acc: 0.7162 - val_cosine_proximity: -0.5734 - val_f1: 0.7970
# Epoch 5/15
# 19979/19979 [==============================] - 449s 22ms/step - loss: 0.4686 - acc: 0.7280 - cosine_proximity: -0.5747 - f1: 0.7987 - val_loss: 0.4777 - val_acc: 0.7050 - val_cosine_proximity: -0.5734 - val_f1: 0.7679
# Epoch 6/15
# 19979/19979 [==============================] - 448s 22ms/step - loss: 0.4661 - acc: 0.7290 - cosine_proximity: -0.5747 - f1: 0.7936 - val_loss: 0.4743 - val_acc: 0.7234 - val_cosine_proximity: -0.5734 - val_f1: 0.7983
# Epoch 7/15
# 19979/19979 [==============================] - 450s 23ms/step - loss: 0.4618 - acc: 0.7346 - cosine_proximity: -0.5747 - f1: 0.7970 - val_loss: 0.4744 - val_acc: 0.7158 - val_cosine_proximity: -0.5734 - val_f1: 0.7868
# Epoch 8/15
# 19979/19979 [==============================] - 448s 22ms/step - loss: 0.4567 - acc: 0.7407 - cosine_proximity: -0.5747 - f1: 0.7990 - val_loss: 0.4715 - val_acc: 0.7243 - val_cosine_proximity: -0.5734 - val_f1: 0.7868
# Epoch 9/15
# 19979/19979 [==============================] - 449s 22ms/step - loss: 0.4500 - acc: 0.7498 - cosine_proximity: -0.5747 - f1: 0.8005 - val_loss: 0.4807 - val_acc: 0.6991 - val_cosine_proximity: -0.5734 - val_f1: 0.7368
# Epoch 10/15
# 19979/19979 [==============================] - 450s 23ms/step - loss: 0.4410 - acc: 0.7602 - cosine_proximity: -0.5747 - f1: 0.8079 - val_loss: 0.4785 - val_acc: 0.7000 - val_cosine_proximity: -0.5734 - val_f1: 0.7370
# Epoch 11/15
# 19979/19979 [==============================] - 449s 22ms/step - loss: 0.4297 - acc: 0.7715 - cosine_proximity: -0.5747 - f1: 0.8136 - val_loss: 0.4746 - val_acc: 0.7360 - val_cosine_proximity: -0.5734 - val_f1: 0.8053
# Epoch 12/15
# 19979/19979 [==============================] - 449s 22ms/step - loss: 0.4146 - acc: 0.7830 - cosine_proximity: -0.5747 - f1: 0.8204 - val_loss: 0.4698 - val_acc: 0.7347 - val_cosine_proximity: -0.5734 - val_f1: 0.7942
# Epoch 13/15
# 19979/19979 [==============================] - 448s 22ms/step - loss: 0.4019 - acc: 0.7942 - cosine_proximity: -0.5747 - f1: 0.8281 - val_loss: 0.5000 - val_acc: 0.6887 - val_cosine_proximity: -0.5734 - val_f1: 0.7156
# Epoch 14/15
# 19979/19979 [==============================] - 450s 23ms/step - loss: 0.3864 - acc: 0.8058 - cosine_proximity: -0.5747 - f1: 0.8355 - val_loss: 0.5005 - val_acc: 0.7027 - val_cosine_proximity: -0.5734 - val_f1: 0.7354
# Epoch 15/15
# 19979/19979 [==============================] - 450s 23ms/step - loss: 0.3643 - acc: 0.8225 - cosine_proximity: -0.5747 - f1: 0.8489 - val_loss: 0.4979 - val_acc: 0.7077 - val_cosine_proximity: -0.5734 - val_f1: 0.7469
# classification F score: 0.71462

# %%
train_lstm_rnn(15, 300, 'plain_data', 400, "adam", 0.05)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        (None, 400)               0
# _________________________________________________________________
# embedding_10 (Embedding)     (None, 400, 300)          63059100
# _________________________________________________________________
# bidirectional_10 (Bidirectio (None, 400, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_10 (Glo (None, 120)               0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 120)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 50)                6050
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 63,238,481
# Trainable params: 179,381
# Non-trainable params: 63,059,100
# _________________________________________________________________
# Train on 19979 samples, validate on 2220 samples
# Epoch 1/15
# 19979/19979 [==============================] - 363s 18ms/step - loss: 0.6679 - acc: 0.5939 - cosine_proximity: -0.5747 - f1: 0.7005 - val_loss: 0.6581 - val_acc: 0.6068 - val_cosine_proximity: -0.5734 - val_f1: 0.7198
# Epoch 2/15
# 19979/19979 [==============================] - 470s 24ms/step - loss: 0.6538 - acc: 0.6174 - cosine_proximity: -0.5747 - f1: 0.7004 - val_loss: 0.6484 - val_acc: 0.6261 - val_cosine_proximity: -0.5734 - val_f1: 0.7164
# Epoch 3/15
# 19979/19979 [==============================] - 454s 23ms/step - loss: 0.6406 - acc: 0.6383 - cosine_proximity: -0.5747 - f1: 0.7102 - val_loss: 0.6419 - val_acc: 0.6360 - val_cosine_proximity: -0.5734 - val_f1: 0.6832
# Epoch 4/15
# 19979/19979 [==============================] - 458s 23ms/step - loss: 0.6151 - acc: 0.6653 - cosine_proximity: -0.5747 - f1: 0.7260 - val_loss: 0.6591 - val_acc: 0.6086 - val_cosine_proximity: -0.5734 - val_f1: 0.5903
# Epoch 5/15
# 19979/19979 [==============================] - 457s 23ms/step - loss: 0.5944 - acc: 0.6832 - cosine_proximity: -0.5747 - f1: 0.7356 - val_loss: 0.6279 - val_acc: 0.6405 - val_cosine_proximity: -0.5734 - val_f1: 0.6996
# Epoch 6/15
# 19979/19979 [==============================] - 458s 23ms/step - loss: 0.5670 - acc: 0.7068 - cosine_proximity: -0.5747 - f1: 0.7512 - val_loss: 0.6465 - val_acc: 0.6383 - val_cosine_proximity: -0.5734 - val_f1: 0.6482
# Epoch 7/15
# 19979/19979 [==============================] - 458s 23ms/step - loss: 0.5364 - acc: 0.7288 - cosine_proximity: -0.5747 - f1: 0.7678 - val_loss: 0.6360 - val_acc: 0.6414 - val_cosine_proximity: -0.5734 - val_f1: 0.7041
# Epoch 8/15
# 19979/19979 [==============================] - 461s 23ms/step - loss: 0.5106 - acc: 0.7483 - cosine_proximity: -0.5747 - f1: 0.7823 - val_loss: 0.6575 - val_acc: 0.6405 - val_cosine_proximity: -0.5734 - val_f1: 0.6978
# Epoch 9/15
# 19979/19979 [==============================] - 458s 23ms/step - loss: 0.4779 - acc: 0.7719 - cosine_proximity: -0.5747 - f1: 0.8011 - val_loss: 0.6834 - val_acc: 0.6234 - val_cosine_proximity: -0.5734 - val_f1: 0.6373
# Epoch 10/15
# 19979/19979 [==============================] - 458s 23ms/step - loss: 0.4490 - acc: 0.7906 - cosine_proximity: -0.5747 - f1: 0.8174 - val_loss: 0.6888 - val_acc: 0.6405 - val_cosine_proximity: -0.5734 - val_f1: 0.7002
# Epoch 11/15
# 19979/19979 [==============================] - 459s 23ms/step - loss: 0.4150 - acc: 0.8112 - cosine_proximity: -0.5747 - f1: 0.8347 - val_loss: 0.7108 - val_acc: 0.6351 - val_cosine_proximity: -0.5734 - val_f1: 0.6891
# Epoch 12/15
# 19979/19979 [==============================] - 461s 23ms/step - loss: 0.3891 - acc: 0.8243 - cosine_proximity: -0.5747 - f1: 0.8458 - val_loss: 0.7437 - val_acc: 0.6360 - val_cosine_proximity: -0.5734 - val_f1: 0.6755
# Epoch 13/15
# 19979/19979 [==============================] - 442s 22ms/step - loss: 0.3621 - acc: 0.8373 - cosine_proximity: -0.5747 - f1: 0.8562 - val_loss: 0.7825 - val_acc: 0.6378 - val_cosine_proximity: -0.5734 - val_f1: 0.7094
# Epoch 14/15
# 19979/19979 [==============================] - 444s 22ms/step - loss: 0.3476 - acc: 0.8466 - cosine_proximity: -0.5747 - f1: 0.8644 - val_loss: 0.8376 - val_acc: 0.6279 - val_cosine_proximity: -0.5734 - val_f1: 0.7140
# Epoch 15/15
# 19979/19979 [==============================] - 444s 22ms/step - loss: 0.3245 - acc: 0.8610 - cosine_proximity: -0.5747 - f1: 0.8774 - val_loss: 0.8098 - val_acc: 0.6324 - val_cosine_proximity: -0.5734 - val_f1: 0.6978
# classification F score: 0.67390

# %%
model_results
# Out:
# [{'accuracy': 0.736418,
#   'name': 'TFIDF HTML - Predict Stay at Job',
#   'log_loss': 0.546574},
#  {'accuracy': 0.736418,
#   'name': 'TFIDF HTML - Predict Stay at Job',
#   'log_loss': 0.546574},
#  {'accuracy': 0.650149,
#   'name': 'TFIDF Plain Text - Predict Stay at Job',
#   'log_loss': 0.626319},
#  {'accuracy': 0.571538,
#   'name': 'TFIDF HTML NB - Predict Stay at Job',
#   'log_loss': 1.20385},
#  {'accuracy': 0.583206,
#   'name': 'TFIDF Plain NB - Predict Stay at Job',
#   'log_loss': 0.900991},
#  {'accuracy': 0.651815,
#   'name': 'TFIDF Plain Log Pipeline [*all] - Predict Stay at Job',
#   'log_loss': 0.626182},
#  {'accuracy': 0.722227,
#   'name': 'TFIDF HTML Log Pipeline [*all] - Predict Stay at Job',
#   'log_loss': 0.566294},
#  {'F1 accuracy': 0.7171775177661333,
#   'name': 'LSTM: CO:400, E:5, data, adam - Predict Stay at Job'},
#  {'F1 accuracy': 0.6692061666726561,
#   'name': 'LSTM: CO:400, E:5, plain_data, adam - Predict Stay at Job'},
#  {'F1 accuracy': 0.7828112680094617,
#   'name': 'LSTM: CO:800, E:5, data, adam - Predict Stay at Job'},
#  {'F1 accuracy': 0.6874821173104435,
#   'name': 'LSTM: CO:800, E:5, plain_data, adam - Predict Stay at Job'},
#  {'F1 accuracy': 0.8468235614202149,
#   'name': 'LSTM: CO:800, E:10, data, adam - Predict Stay at Job'},
#  {'F1 accuracy': 0.6877575149582602,
#   'name': 'LSTM: CO:800, E:10, plain_data, adam - Predict Stay at Job'},
#  {'F1 accuracy': 0.7146184998028886,
#   'name': 'LSTM: CO:400, E:15, data, adam - Predict Stay at Job'},
#  {'F1 accuracy': 0.6739021419872484,
#   'name': 'LSTM: CO:400, E:15, plain_data, adam - Predict Stay at Job'}]

# %%
model_predictions
# Out:
# {'CO:400, E:5, data, adam': array([[0.58],
#         [0.7 ],
#         [1.  ],
#         ...,
#         [0.  ],
#         [0.64],
#         [0.63]], dtype=float32),
#  'CO:400, E:5, plain_data, adam': array([[0.48],
#         [0.81],
#         [0.61],
#         ...,
#         [0.54],
#         [0.6 ],
#         [0.59]], dtype=float32),
#  'CO:800, E:5, data, adam': array([[6.44e-01],
#         [7.09e-01],
#         [1.00e+00],
#         ...,
#         [1.36e-05],
#         [6.39e-01],
#         [1.00e+00]], dtype=float32),
#  'CO:800, E:5, plain_data, adam': array([[0.36],
#         [0.91],
#         [0.8 ],
#         ...,
#         [0.76],
#         [0.6 ],
#         [0.76]], dtype=float32),
#  'CO:800, E:10, data, adam': array([[4.36e-01],
#         [8.89e-01],
#         [1.00e+00],
#         ...,
#         [4.13e-08],
#         [7.53e-01],
#         [1.00e+00]], dtype=float32),
#  'CO:800, E:10, plain_data, adam': array([[0.22],
#         [0.88],
#         [0.62],
#         ...,
#         [0.2 ],
#         [0.4 ],
#         [0.59]], dtype=float32),
#  'CO:400, E:15, data, adam': array([[0.29],
#         [0.48],
#         [1.  ],
#         ...,
#         [0.03],
#         [0.71],
#         [0.74]], dtype=float32),
#  'CO:400, E:15, plain_data, adam': array([[0.73],
#         [0.92],
#         [0.54],
#         ...,
#         [0.96],
#         [0.39],
#         [0.98]], dtype=float32)}

# %%
def score_accuracy(pred, actual):
    total = 0.0
    correct = 0.0
    for index, value in enumerate(pred):
        if (actual[index] == round(value[0])):
            correct += 1
        total += 1
    return correct / total

# %%
for index in model_predictions:
    score = score_accuracy(model_predictions[index], predictors_test['work_stayed'].astype(int))
    print(str(index) + " score: " + str(score))
# Out:
# 16322.0
# 22198.0
# CO:400, E:5, data, adam score: 0.7352914676997928
# 14238.0
# 22198.0
# CO:400, E:5, plain_data, adam score: 0.6414091359581945
# 19932.0
# 22198.0
# CO:800, E:5, data, adam score: 0.8979187314172448
# 14557.0
# 22198.0
# CO:800, E:5, plain_data, adam score: 0.6557797999819803
# 20112.0
# 22198.0
# CO:800, E:10, data, adam score: 0.9060275700513559
# 14633.0
# 22198.0
# CO:800, E:10, plain_data, adam score: 0.6592035318497161
# 15603.0
# 22198.0
# CO:400, E:15, data, adam score: 0.7029011622668709
# 14097.0
# 22198.0
# CO:400, E:15, plain_data, adam score: 0.635057212361474
