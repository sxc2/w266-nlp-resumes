# %% [markdown]
# ## Resume EDA
# #### Resumes (300MB)
#
#
#
# ### Methodology
#
#
# #### 1 <a href='#setup'>Initial Setup</a>
#
# #### 2. <a href='#eda'>Exploratory Analysis</a>
# - 2.0 <a href='#eda'>Cleaning Data</a>
# #### 2. <a href='#future'>Future Extensions</a>

# %% [markdown]
# <a id="setup"></a>
# ## Setup
#
# Let's import the serialized data

# %%
# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

# General libraries
import re
import string
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, json
import unicodedata
from collections import Counter

# NLTK library for stop word removal
from nltk.corpus import stopwords

# SK-learn libraries for learning.
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB

# SK-learn libraries for evaluation.
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer


from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

from sklearn.metrics import log_loss

from xml.dom import minidom
from bs4 import BeautifulSoup as BS

# %%
import pickle
import sys

sys.setrecursionlimit(20000)
train_xml_ = pickle.load( open( "data/train_2_xml.p", "rb" ) )

# %%
train_xml_ = pd.DataFrame(train_xml_)

# shuffle the training data to get rid of implicit order biases
train_data_original = train_xml_.sample(frac = 1)
train_data_original = train_data_original.reset_index()

# %%
train_data_original.describe()
# Out:
#               index
# count  50101.000000
# mean   25050.000000
# std    14463.057255
# min        0.000000
# 25%    12525.000000
# 50%    25050.000000
# 75%    37575.000000
# max    50100.000000

# %%
# Lowercase the text
train_data_original['data'] = train_data_original['data'].apply(lambda x: x.lower())

# Attempt to remove css that is encased between {| and |
#train_data_original['data'] = train_data_original['data'].apply(lambda x: re.sub(re.compile('{|.*?|'),'',x))

# Removing line breaks
#train_data_original['data'] = train_data_original['data'].map(lambda x: x.splitlines()).astype(str)

# Remove html tags in <>
#train_data_original['data'] = train_data_original['data'].apply(lambda x: re.sub(re.compile('<.*?>'),'',x))

# Remove content in curly braces {}, which include entities and more css
#train_data_original['data'] = train_data_original['data'].apply(lambda x: re.sub(re.compile('{.*?}'),'',x))

# Remove indicators in HTML
# train_data_original['data'] = train_data_original['data'].str.replace('itemprop="worksfor"',' ')
# train_data_original['data'] = train_data_original['data'].str.replace('itemtype="http://schema.org/organization"',' ')
# train_data_original['data'] = train_data_original['data'].str.replace('itemscope',' ')
# train_data_original['data'] = train_data_original['data'].str.replace('present',' ')

train_data_original['plain_data'] = train_data_original['data'].apply(lambda x: re.sub('<[^<]+?>', '', x))

# %%
print(train_data_original['data'][0])
print(train_data_original['plain_data'][0])
# print(train_data_original['data'][1])
# print(train_data_original['data'][2])
# Out:
# <div class="vcard single_form-content" id="resume_body">
# <div class="last basicinfo-content" id="basic_info_row"><div class="data_display" id="basic_info_cell">
# <h1 class="fn " id="resume-contact" itemprop="name">foreman</h1>
# <div id="contact_info_container">
# <div class="adr" itemprop="address" itemscope="" itemtype="http://schema.org/postaladdress"><p class="locality" id="headline_location" itemprop="addresslocality">riverdale, il</p></div>
# <div class="separator-hyphen">-</div>
# </div>
# <p class="summary" id="res_summary">to join an interactive organization that offers me a constructive workplace for communication and interaction. able to work within a team but also maintain self-motivation that allows production and no supervision.</p>
# <p id="relocation_status">willing to relocate: anywhere</p>
# <p id="employment_eligibility">authorized to work in the us for any employer</p>
# </div></div>
# <div class="section-item workexperience-content">
# <div><div class="section_title"><h2>work experience</h2></div></div>
# <div class="items-container" id="work-experience-items">
# <div class="work-experience-section " id="workexperience-eezelm8xxestzclhbgsw1q"><div class="data_display">
# <p class="work_title title">foreman</p>
# <div class="work_company" itemprop="worksfor" itemscope="" itemtype="http://schema.org/organization">
# <span class="bold" itemprop="name">suburban landscaping</span> <div class="separator-hyphen">-</div> <div class="inline-block" itemprop="address" itemscope="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">chicago heights, il</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">may 2016 to present</p>
# <p class="work_description">team leader of crew members on projects.  <br/>ensures that all projects are completed and met in a timely matter and that the work of field crew meets quality expectations.  <br/>primary role is to perform herbicide spot treatments on noxious weeds using backpack sprayers.  <br/>responsible for managing multiple projects at once. <br/>responsible for weed removal on both residential and commercial properties</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eew-ymtmzmwmjvn7osniyg"><div class="data_display">
# <p class="work_title title">assistant manager/cashier</p>
# <div class="work_company">
# <span class="bold">19paul smokehouse</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>chicago, il</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">july 2014 to april 2016</p>
# <p class="work_description">responsible for up keeping and filing of store records, time sheets, and employee records.  <br/>responsible for maintaining quality customer service, which included greeting and advising customers. <br/>ordering supplies <br/>problem solving <br/>recruiting, training, and supervising staff <br/>ensuring compliance with licensing, and health and safety guidelines. <br/>cash handling  <br/> <br/>accomplishments <br/>i began as a cashier in july of 2014 and within a year i was promoted as an assistant manager.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eeuw0-nheqwxmgxatb0mla"><div class="data_display">
# <p class="work_title title">laborer</p>
# <div class="work_company">
# <span class="bold">cook county forest preserve district</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>river forest, il</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">may 2012 to august 2013</p>
# <p class="work_description">responsible for maintenance and up keeping of forest preserve grounds, which include cutting, trimming, and picking. <br/>• maintained picnic groves and bathrooms <br/>• some clerical duties performed. <br/>• built customer confidence by actively listening to their concerns and gave appropriate feedback. <br/>• planned work and determined appropriate tools and equipment. <br/>• kept supervisor informed on job progress and material requirements <br/>• preserved perfect attendance record for six months.</p>
# </div></div>
# <div class="work-experience-section last" id="workexperience-eeuw0-nheqaxmgxatb0mla"><div class="data_display">
# <p class="work_title title">cashier/customer service</p>
# <div class="work_company">
# <span class="bold">crisp-n-clean cleaners</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>evergreen park, il</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">november 2008 to may 2012</p>
# <p class="work_description">answered customer telephone calls promptly and in an appropriate manner. <br/>• operated a cash register for cash, check, and credit card transactions <br/>• cleaned and organized the store, including the checkout desk and displays <br/>• handled all customer relations issues in a gracious manner and in accordance with company policies. <br/>• verified that all customers received receipts for their purchases. <br/>• mentored new sales associate to contribute to the store's positive culture.</p>
# </div></div>
# </div>
# </div>
#
# <div class="section-item additionalinfo-content">
# <div><div class="section_title"><h2>additional information</h2></div></div>
# <div class="items-container" id="additionalinfo-items"><div class="last" id="additionalinfo-section"><div class="data_display"><p>skills &amp; abilities <br/>• customer-oriented <br/>• active listening skills <br/> <br/>• computer literate <br/>• stocking <br/>• motivated team player <br/>• personable</p></div></div></div>
# </div>
# </div>
#
#
# foreman
#
# riverdale, il
# -
#
# to join an interactive organization that offers me a constructive workplace for communication and interaction. able to work within a team but also maintain self-motivation that allows production and no supervision.
# willing to relocate: anywhere
# authorized to work in the us for any employer
#
#
# work experience
#
#
# foreman
#
# suburban landscaping - chicago heights, il
#
# -
# may 2016 to present
# team leader of crew members on projects.  ensures that all projects are completed and met in a timely matter and that the work of field crew meets quality expectations.  primary role is to perform herbicide spot treatments on noxious weeds using backpack sprayers.  responsible for managing multiple projects at once. responsible for weed removal on both residential and commercial properties
#
#
# assistant manager/cashier
#
# 19paul smokehouse - chicago, il
#
# -
# july 2014 to april 2016
# responsible for up keeping and filing of store records, time sheets, and employee records.  responsible for maintaining quality customer service, which included greeting and advising customers. ordering supplies problem solving recruiting, training, and supervising staff ensuring compliance with licensing, and health and safety guidelines. cash handling   accomplishments i began as a cashier in july of 2014 and within a year i was promoted as an assistant manager.
#
#
# laborer
#
# cook county forest preserve district - river forest, il
#
# -
# may 2012 to august 2013
# responsible for maintenance and up keeping of forest preserve grounds, which include cutting, trimming, and picking. • maintained picnic groves and bathrooms • some clerical duties performed. • built customer confidence by actively listening to their concerns and gave appropriate feedback. • planned work and determined appropriate tools and equipment. • kept supervisor informed on job progress and material requirements • preserved perfect attendance record for six months.
#
#
# cashier/customer service
#
# crisp-n-clean cleaners - evergreen park, il
#
# -
# november 2008 to may 2012
# answered customer telephone calls promptly and in an appropriate manner. • operated a cash register for cash, check, and credit card transactions • cleaned and organized the store, including the checkout desk and displays • handled all customer relations issues in a gracious manner and in accordance with company policies. • verified that all customers received receipts for their purchases. • mentored new sales associate to contribute to the store's positive culture.
#
#
#
#
#
# additional information
# skills &amp; abilities • customer-oriented • active listening skills  • computer literate • stocking • motivated team player • personable

# %% [markdown]
# ### Questions to Explore
#
#
# - How many folks (%) have no previous experience?
# - How many jobs do folks have on average?
# - What is the average length of resume?

# %%
comment_length = train_data_original['data'].str.len()

plt.figure(figsize=(8,6))
plt.title("Resume Field String Length Histogram")
plt.ylabel('Number of Occurrences', fontsize = 12)
plt.xlabel('Number of Characters', fontsize = 12)
plt.grid(True)

counts, bins, bars = plt.hist(comment_length, alpha = 0.75)

print('Resume Average Char Length: ' + str(round(comment_length.mean(), 1)))
print('Resume Median Char Length: ' + str(round(comment_length.median(), 1)))
print('Resume Variance Char Length: ' + str(round(comment_length.std(), 1)))
print('Resume Min Char Length: ' + str(round(comment_length.min(), 1)))
print('Resume Max Char Length: ' + str(round(comment_length.max(), 1)))
# Out:
# Resume Average Char Length: 4922.9
# Resume Median Char Length: 4287.0
# Resume Variance Char Length: 3298.9
# Resume Min Char Length: 332
# Resume Max Char Length: 82477

# %% [markdown]
# ### Predictor Variables EDA

# %%
predictors = [];

for i in range(len(train_data_original)):
    predictors.append(train_data_original['predictions'][i])
    
predictors_ = pd.DataFrame(predictors)

# %%
predictors_.describe()
# Out:
#        bachelor master
# count     50101  50101
# unique        2      2
# top        True  False
# freq      28403  47594

# %% [markdown]
# ### Potential Interesting Features
#
# - whether or not you're going to stay at the same job
# - whether you're going into a different job function
# - whether you're going to stay at the same company
# - whether you're going get promoted?
#
# - level of candidate
# - classification of candidate
# - diversity?
#
# - given their work experience, whether they have a college degree.

# %%
len_ = int(len(train_data_original)/4)
print(len_)
train_data_ = train_data_original[len_:]
test_data_ = train_data_original[:len_]

predictors_train_ = predictors_[len_:]
predictors_test = predictors_[:len_]

print("training data:" + str(len(train_data_)))
print("test data:" + str(len(test_data_)))

model_results = []
# Out:
# 12525
# training data:37576
# test data:12525

# %%
vectorizer_train = TfidfVectorizer(sublinear_tf = True, lowercase = True)
train_fit = vectorizer_train.fit(train_data_['data'])
train_transformed = vectorizer_train.transform(train_data_['data'])
dev_transformed = vectorizer_train.transform(test_data_['data'])
logis_regression = LogisticRegression()
logis_regression.fit(train_transformed, predictors_train_['bachelor'].astype(int))
pred = logis_regression.predict_proba(dev_transformed)
f1score_logis = logis_regression.score(dev_transformed, predictors_test['bachelor'].astype(int)) 
accuracy = round(f1score_logis, 6)
log_loss_ = round(log_loss(predictors_test['bachelor'].astype(int), pred), 6)

model_results.append({"accuracy" : accuracy, "name" : "TFIDF HTML - Predict Bachelor", "log_loss": log_loss_})

# %%
def score_accuracy_logi(pred, actual):
    total = 0.0
    correct = 0.0
    for index, value in enumerate(pred):
        if (actual[index] == round(value[1])):
            correct += 1
        total += 1
    return correct / total

# %%
print(score_accuracy_logi(pred, predictors_test['bachelor'].astype(int)))

print("Accuracy: " + str(accuracy))
print("Log Loss: " + str(log_loss_))
# Out:
# 0.7357285429141717
# Accuracy: 0.735729
# Log Loss: 0.521058

# %%
vectorizer_train_plain = TfidfVectorizer(sublinear_tf = True, lowercase = True)
train_fit_plain = vectorizer_train_plain.fit(train_data_['plain_data'])
train_transformed_plain = vectorizer_train_plain.transform(train_data_['plain_data'])
dev_transformed_plain = vectorizer_train_plain.transform(test_data_['plain_data'])

logis_regression_plain = LogisticRegression()
logis_regression_plain.fit(train_transformed_plain, predictors_train_['bachelor'].astype(int))
pred_plain = logis_regression_plain.predict_proba(dev_transformed_plain)

f1score_logis = logis_regression_plain.score(dev_transformed_plain, predictors_test['bachelor'].astype(int))

accuracy = round(f1score_logis, 6)
log_loss_ = round(log_loss(predictors_test['bachelor'].astype(int), pred_plain), 6)

model_results.append({"accuracy" : accuracy, "name" : "TFIDF Plain Text - Predict Bachelor", "log_loss": log_loss_})

# %%
print("Accuracy: " + str(accuracy))
print("Log Loss: " + str(log_loss_))
# Out:
# Accuracy: 0.734371
# Log Loss: 0.521902

# %%
# http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
correct_values = predictors_test['bachelor'].astype(int)
logis_regression_pred = logis_regression.predict(dev_transformed) 

confusion_mat = confusion_matrix(correct_values, logis_regression_pred)

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(confusion_mat, classes=[0,1], title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(confusion_mat, classes=[0,1], normalize=True, title='Normalized confusion matrix')

plt.show()

# %%
correct_values = predictors_test['bachelor'].astype(int)
logis_regression_pred = logis_regression_plain.predict(dev_transformed_plain) 

confusion_mat = confusion_matrix(correct_values, logis_regression_pred)

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(confusion_mat, classes=[0,1], title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(confusion_mat, classes=[0,1], normalize=True, title='Normalized confusion matrix')

plt.show()

# %%
# Print some examples of our vocabulary

def construct_columns_for_top_vocab(vectorizer_train, logis_regression):
    
    # Initialize empty helper vectors and get feature names
    feature_names = vectorizer_train.get_feature_names()
    num_top_features = 25
    all_indices = []
    all_indices_labels = []
    all_indices_values = []
    all_indices_values_with_labels = {}
    
    # https://stackoverflow.com/questions/6910641/how-do-i-get-indices-of-n-maximum-values-in-a-numpy-array
    indices = (-logis_regression.coef_[0]).argsort()[:num_top_features]
    all_indices.extend(indices)
            
    # Getting all the indices and then adding the feature names for each category
    for i, value in enumerate(all_indices):
        all_indices_labels.append(feature_names[value])
        all_indices_values.append([])
        all_indices_values[i].append(round(logis_regression.coef_[0][value], 3))
        all_indices_values_with_labels[feature_names[value]] = all_indices_values[i]
        
    return all_indices_values_with_labels


showValues = construct_columns_for_top_vocab(vectorizer_train, logis_regression)
df = pd.DataFrame.from_dict(showValues, orient='index')
display(df)

showValues = construct_columns_for_top_vocab(vectorizer_train_plain, logis_regression_plain)
df = pd.DataFrame.from_dict(showValues, orient='index')
display(df)
# Out:
#                       0
# college           6.650
# university        5.604
# intern            4.666
# research          3.616
# microsoft         3.605
# student           3.049
# headline          2.978
# jobtitle          2.973
# degree            2.811
# teacher           2.751
# powerpoint        2.742
# internship        2.740
# tutor             2.709
# august            2.706
# financial         2.627
# rn                2.561
# students          2.539
# work_description  2.513
# accounting        2.501
# clinical          2.469
# 2012              2.325
# taught            2.213
# of                2.152
# therapy           2.148
# analysis          2.142
#                 0
# college     6.563
# university  5.520
# intern      4.784
# research    3.607
# microsoft   3.117
# student     2.930
# degree      2.864
# tutor       2.791
# of          2.723
# internship  2.653
# financial   2.620
# powerpoint  2.605
# rn          2.534
# teacher     2.532
# students    2.520
# august      2.500
# clinical    2.456
# accounting  2.420
# and         2.327
# therapy     2.306
# taught      2.256
# 2012        2.229
# analysis    2.173
# in          2.119
# present     2.095

# %%
num_examples = 10
counter = 0

for i in range(len(train_data_original['data'])):
    if ('college' in train_data_original['data'][i]):        
        print(train_data_original['data'][i])
        print(train_data_original['plain_data'][i])
        counter += 1
    elif ('education' in train_data_original['data'][i]):  
        print(train_data_original['data'][i])
        print(train_data_original['plain_data'][i])
        counter += 1
        
    if counter > num_examples:
        break
# Out:
# <div class="vcard single_form-content" id="resume_body">
# <div class="last basicinfo-content" id="basic_info_row"><div class="data_display" id="basic_info_cell">
# <h1 class="fn " id="resume-contact" itemprop="name">paul costa</h1>
# <div id="contact_info_container">
# <div class="adr" itemprop="address" itemscope="" itemtype="http://schema.org/postaladdress"><p class="locality" id="headline_location" itemprop="addresslocality">henrico, va</p></div>
# <div class="separator-hyphen">-</div>
# </div>
# <p id="employment_eligibility">authorized to work in the us for any employer</p>
# </div></div>
# <div class="section-item workexperience-content">
# <div><div class="section_title"><h2>work experience</h2></div></div>
# <div class="items-container" id="work-experience-items"><div class="work-experience-section last" id="workexperience-eevuybxx-kegzln7osniyg"><div class="data_display">
# <p class="work_title title">technical support analyst / system admin</p>
# <div class="work_company">
# <span class="bold">pembrooke/escreen/alere</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>richmond, va</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">may 2005 to august 2015</p>
# <p class="work_description">responsibilities <br/>daily responsibilities included monitoring a service desk ticketing system to ensure meeting of service level agreements.   <br/> <br/>accomplishments <br/>•    performed company-wide desktop deployments, os upgrades, and hardware replacements to serve over 100 clients in the business user community. <br/>•    implemented numerous dedicated client telephone service numbers and supported telephony configuration. <br/>•    supported migration of an in-house server room to a co-location data center. <br/>•    mentored new associates to develop understanding of company software and hardware. <br/>•       provided weekend and after hours support.  <br/> <br/>skills used <br/>•    systems installation, configuration, and upgrade support <br/>•    server administration <br/>•    telephony configuration and administration <br/>•    desktop image creation and deployment <br/>•    mobile device deployments <br/>•    technical support and troubleshooting</p>
# </div></div></div>
# </div>
#
# <div class="more_sections "><div class="section-item">
# <div><div class="section_title"><h2>certifications</h2></div></div>
# <div class="items-container" id="certification-items"><div class="certification-section last" id="certification-eevuyfbjfxsgzln7osniyg"><div class="data_display">
# <p class="certification_title">microsoft windows vista mcsa</p>
# <p class="certification_date">march 2010</p>
# </div></div></div>
# </div></div>
# <div class="section-item additionalinfo-content">
# <div><div class="section_title"><h2>additional information</h2></div></div>
# <div class="items-container" id="additionalinfo-items"><div class="last" id="additionalinfo-section"><div class="data_display"><p>additional education: <br/> <br/>learning tree courses - 2009 <br/>active directory users and computers <br/>exchange 2003</p></div></div></div>
# </div>
# </div>
#
#
# paul costa
#
# henrico, va
# -
#
# authorized to work in the us for any employer
#
#
# work experience
#
# technical support analyst / system admin
#
# pembrooke/escreen/alere - richmond, va
#
# -
# may 2005 to august 2015
# responsibilities daily responsibilities included monitoring a service desk ticketing system to ensure meeting of service level agreements.    accomplishments •    performed company-wide desktop deployments, os upgrades, and hardware replacements to serve over 100 clients in the business user community. •    implemented numerous dedicated client telephone service numbers and supported telephony configuration. •    supported migration of an in-house server room to a co-location data center. •    mentored new associates to develop understanding of company software and hardware. •       provided weekend and after hours support.   skills used •    systems installation, configuration, and upgrade support •    server administration •    telephony configuration and administration •    desktop image creation and deployment •    mobile device deployments •    technical support and troubleshooting
#
#
#
#
# certifications
#
# microsoft windows vista mcsa
# march 2010
#
#
#
# additional information
# additional education:  learning tree courses - 2009 active directory users and computers exchange 2003
#
#
# <div class="vcard single_form-content" id="resume_body">
# <div class="last basicinfo-content" id="basic_info_row"><div class="data_display" id="basic_info_cell">
# <h1 class="fn " id="resume-contact" itemprop="name">zachary farmer</h1>
# <h2 id="headline" itemprop="jobtitle">second lieutenant - united states army reserves</h2>
# <div id="contact_info_container">
# <div class="adr" itemprop="address" itemscope="" itemtype="http://schema.org/postaladdress"><p class="locality" id="headline_location" itemprop="addresslocality">fayetteville, nc</p></div>
# <div class="separator-hyphen">-</div>
# </div>
# <p class="summary" id="res_summary">i am college graduate and army reservist seeking a full-time position in which to apply my knowledge and skills honed through experience.  i am looking to build a long-term career with an institution that promotes career and personal development, collaboration among peers, and a positive contribution to the community.</p>
# <p id="employment_eligibility">authorized to work in the us for any employer</p>
# </div></div>
# <div class="section-item workexperience-content">
# <div><div class="section_title"><h2>work experience</h2></div></div>
# <div class="items-container" id="work-experience-items">
# <div class="work-experience-section " id="workexperience-eexzwl0s--cp0cl4kpgzyq"><div class="data_display">
# <p class="work_title title">second lieutenant</p>
# <div class="work_company" itemprop="worksfor" itemscope="" itemtype="http://schema.org/organization">
# <span class="bold" itemprop="name">united states army reserves</span> <div class="separator-hyphen">-</div> <div class="inline-block" itemprop="address" itemscope="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">fort bragg, nc</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">august 2014 to present</p>
# <p class="work_description">865th engineer detachment <br/>• perform monthly training and maintenance exercises <br/>• lead unit during infrastructure reconnaissance and site assessments as ordered <br/>• present required unit annual training</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eexzwl0tivgp0cl4kpgzyq"><div class="data_display">
# <p class="work_title title">day camp counselor</p>
# <div class="work_company">
# <span class="bold">west geauga recreation council</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>chesterland, oh</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">june 2012 to august 2012</p>
# <p class="work_description">• assisted  director in developing camp events and schedule <br/>• supervised children ages 7-12 <br/>• organized and led groups of children in recreational activities</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eexzwl0tsgkp0cl4kpgzyq"><div class="data_display">
# <p class="work_title title">laborer</p>
# <div class="work_company">
# <span class="bold">brienik masonry</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>willoughby, oh</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">may 2009 to august 2011</p>
# <p class="work_description">• prepared materials (mortar, concrete, block, brick and or stone) for assembly <br/>• participated in demolition and clean-up of construction sites</p>
# </div></div>
# <div class="work-experience-section last" id="workexperience-eexzwl0tsgop0cl4kpgzyq"><div class="data_display">
# <p class="work_title title">mason and laborer</p>
# <div class="work_company">
# <span class="bold">farmer construction, incorporated</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>chesterland, oh</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">may 2006 to may 2009</p>
# <p class="work_description">• constructed stone and brick veneers for residential and commercial structures <br/>• prepared materials (mortar, concrete, block, brick and or stone) for assembly <br/>• completed demolition in and clean-up of construction sites</p>
# </div></div>
# </div>
# </div>
#
# <div class="section-item additionalinfo-content">
# <div><div class="section_title"><h2>additional information</h2></div></div>
# <div class="items-container" id="additionalinfo-items"><div class="last" id="additionalinfo-section"><div class="data_display"><p>skills: <br/>• critical thinking for problem solving <br/>• collaborative approach to achieve goals <br/>• intermediate-level proficiency with microsoft word, powerpoint, and excel <br/> <br/>• capable of working under pressure <br/>• strong communication skills <br/>• proven ability to prioritize multiple tasks and responsibilities</p></div></div></div>
# </div>
# </div>
#
#
# zachary farmer
# second lieutenant - united states army reserves
#
# fayetteville, nc
# -
#
# i am college graduate and army reservist seeking a full-time position in which to apply my knowledge and skills honed through experience.  i am looking to build a long-term career with an institution that promotes career and personal development, collaboration among peers, and a positive contribution to the community.
# authorized to work in the us for any employer
#
#
# work experience
#
#
# second lieutenant
#
# united states army reserves - fort bragg, nc
#
# -
# august 2014 to present
# 865th engineer detachment • perform monthly training and maintenance exercises • lead unit during infrastructure reconnaissance and site assessments as ordered • present required unit annual training
#
#
# day camp counselor
#
# west geauga recreation council - chesterland, oh
#
# -
# june 2012 to august 2012
# • assisted  director in developing camp events and schedule • supervised children ages 7-12 • organized and led groups of children in recreational activities
#
#
# laborer
#
# brienik masonry - willoughby, oh
#
# -
# may 2009 to august 2011
# • prepared materials (mortar, concrete, block, brick and or stone) for assembly • participated in demolition and clean-up of construction sites
#
#
# mason and laborer
#
# farmer construction, incorporated - chesterland, oh
#
# -
# may 2006 to may 2009
# • constructed stone and brick veneers for residential and commercial structures • prepared materials (mortar, concrete, block, brick and or stone) for assembly • completed demolition in and clean-up of construction sites
#
#
#
#
#
# additional information
# skills: • critical thinking for problem solving • collaborative approach to achieve goals • intermediate-level proficiency with microsoft word, powerpoint, and excel  • capable of working under pressure • strong communication skills • proven ability to prioritize multiple tasks and responsibilities
#
#
# <div class="vcard single_form-content" id="resume_body">
# <div class="last basicinfo-content" id="basic_info_row"><div class="data_display" id="basic_info_cell">
# <h1 class="fn " id="resume-contact" itemprop="name">police officer</h1>
# <div id="contact_info_container">
# <div class="adr" itemprop="address" itemscope="" itemtype="http://schema.org/postaladdress"><p class="locality" id="headline_location" itemprop="addresslocality">altus, ok</p></div>
# <div class="separator-hyphen">-</div>
# </div>
# <p class="summary" id="res_summary">moving to mountain home afb in 8 days.</p>
# <p id="relocation_status">willing to relocate to: twin falls, id</p>
# <p id="employment_eligibility">authorized to work in the us for any employer</p>
# </div></div>
# <div class="section-item workexperience-content">
# <div><div class="section_title"><h2>work experience</h2></div></div>
# <div class="items-container" id="work-experience-items">
# <div class="work-experience-section " id="workexperience-eeafndxubeqnkfli6yveoa"><div class="data_display">
# <p class="work_title title">police officer</p>
# <div class="work_company">
# <span class="bold">department of defense</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>altus, ok</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">august 2015 to march 2016</p>
# <p class="work_description">maintained security of the base as well as ensure safety on the vital aircraft on the post. <br/>patrol streets and initiate vehicle stops as needed due to which law was violated. <br/>patrol the housing community on base and answer calls for service as needed.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eet1sgwqxbwdwfn7osniyg"><div class="data_display">
# <p class="work_title title">k9 handler/police officer</p>
# <div class="work_company"><span class="bold">city of altus</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">2014 to 2015</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eet1shte4iudwfn7osniyg"><div class="data_display">
# <p class="work_title title">police officer</p>
# <div class="work_company"><span class="bold">city of hobart</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">2013 to 2014</p>
# </div></div>
# <div class="work-experience-section last" id="workexperience-eet1sji7u7mdwfn7osniyg"><div class="data_display">
# <p class="work_title title">911 dispatcher/jailer</p>
# <div class="work_company"><span class="bold">city of weatherford</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">2011 to 2013</p>
# </div></div>
# </div>
# </div>
#
# <div class="section-item skills-content">
# <div><div class="section_title"><h2>skills</h2></div></div>
# <div class="items-container" id="skills-items"><div class="data_display"><div class="skill-container resume-element"><span class="skill-text">medical terminology, types 70+wpm, medical filing (5 years)</span></div></div></div>
# </div>
# <div class="section-item certification-content">
# <div><div class="section_title"><h2>certifications</h2></div></div>
# <div class="items-container" id="certification-items"><div class="certification-section last" id="certification-eeafnlc9mn-nkfli6yveoa"><div class="data_display">
# <p class="certification_title">cleet</p>
# <p class="certification_date">march 2012 to present</p>
# <p class="certification_description">oklahoma council on law enforcement education and training.</p>
# </div></div></div>
# </div>
# </div>
#
#
# police officer
#
# altus, ok
# -
#
# moving to mountain home afb in 8 days.
# willing to relocate to: twin falls, id
# authorized to work in the us for any employer
#
#
# work experience
#
#
# police officer
#
# department of defense - altus, ok
#
# -
# august 2015 to march 2016
# maintained security of the base as well as ensure safety on the vital aircraft on the post. patrol streets and initiate vehicle stops as needed due to which law was violated. patrol the housing community on base and answer calls for service as needed.
#
#
# k9 handler/police officer
# city of altus
# -
# 2014 to 2015
#
#
# police officer
# city of hobart
# -
# 2013 to 2014
#
#
# 911 dispatcher/jailer
# city of weatherford
# -
# 2011 to 2013
#
#
#
#
#
# skills
# medical terminology, types 70+wpm, medical filing (5 years)
#
#
# certifications
#
# cleet
# march 2012 to present
# oklahoma council on law enforcement education and training.
#
#
#
# <div class="vcard single_form-content" id="resume_body">
# <div class="last basicinfo-content" id="basic_info_row"><div class="data_display" id="basic_info_cell">
# <h1 class="fn " id="resume-contact" itemprop="name">paramedic/ cardiac monitor technician</h1>
# <h2 id="headline" itemprop="jobtitle">paramedic/ cardiac monitor technician</h2>
# <div id="contact_info_container">
# <div class="adr" itemprop="address" itemscope="" itemtype="http://schema.org/postaladdress"><p class="locality" id="headline_location" itemprop="addresslocality">fayetteville, tn</p></div>
# <div class="separator-hyphen">-</div>
# </div>
# <p class="summary" id="res_summary">• have been a paramedic since 1988 with extensive medical experience in the field and in a clinical setting. <br/>• able to work well with no supervision. <br/>• currently bls and acls certified</p>
# </div></div>
# <div class="section-item workexperience-content">
# <div><div class="section_title"><h2>work experience</h2></div></div>
# <div class="items-container" id="work-experience-items">
# <div class="work-experience-section " id="workexperience-eel6jrf5_vswgl9olxgqwg"><div class="data_display">
# <p class="work_title title">paramedic/ cardiac monitor technician</p>
# <div class="work_company">
# <span class="bold">cardiolabs, inc</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>franklin, tn</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">august 2007 to november 2011</p>
# <p class="work_description">take calls from patients for ekg event monitoring transmission. locate the patient's file and receive the cardiac rhythm via telephone and computer. using computer gems program, take measurements using computer calipers and interpret the rhythm. fill out the patient report and send it to the patient's cardiologist via fax. follow protocols for priority notification for life threatening abnormal rhythms such as sinus arrest of greater than 2 seconds in duration, new and symptomatic onset of atrial fibrillation, runs of v-tach, etc.  maintain quality control on the reports that are being submitted to the cardiologists. assist other technicians with questionable interpretations. had to maintain a calm demeanor despite multiple transmissions coming in simultaneously, dealing with a wide range in patient ages and ability to comprehend how to operate the monitors, and numerous other variables. required to maintain acls certification paramedic licensure and have an understanding of current hippa laws.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eel6jrf5_vwwgl9olxgqwg"><div class="data_display">
# <p class="work_title title">paramedic/ operations supervisor</p>
# <div class="work_company">
# <span class="bold">cardiolabs, inc</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>nashville, tn</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">august 2007 to march 2009</p>
# <p class="work_description">as operations supervisor, my priorities were in coordinating the daily and weekly schedule to coincide with customer demand and unit deployment. solved day to day issues as they occurred. provided leadership and day to day management of the operations department. conducted employee education and training, tracked attendance and made certain that ambulance calls were completed in an efficient and safe manner. maintained log of employee certifications. maintained medications and fluids and made sure the ambulances were cleaned, stocked, and in working order. staffed ambulance and functioned as a paramedic as needed. when functioning in the role of a paramedic i was required to render medical care to patients as needed or required according to state protocol. <br/> <br/>sept. 2002-aug 2006</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eel6jrf6jgawgl9olxgqwg"><div class="data_display">
# <p class="work_title title">paramedic / occupational medicine</p>
# <div class="work_company">
# <span class="bold">gaylord opryland</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>nashville, tn</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">may 1992 to september 1996</p>
# <p class="work_description">operated the onsite medical clinic at the hotel, the grand ol' opry and aboard the general jackson showboat. rendered routine and emergency medical care to the hotel guests and employees. maintained all emergency advanced life support equipment in proper working order and a state of readiness to respond. maintained inventory of drugs, medicines, and supplies and followed state protocol for utilization of narcotics used in treatment. worked alone in a fast paced, often stressful and busy atmosphere. obtained medical histories. conducted patient assessments for nature and severity of illness/injury and determined appropriate medical treatment or procedure. performed invasive procedures as needed or required such as iv access, blood collection and endotracheal intubations.  maintained patient care information, response logs and entered data into the computer. filed workman's compensation claims for on the job staff injuries and referred patients to doctors for follow up according to tennessee worker's compensation law. utilized various emergency medical equipment to aid in diagnosis and treatment of patients. <br/> <br/>paramedic/ hbo technician <br/> <br/>regional medical center @ memphis <br/>877 jefferson ave memphis, tn 38103 <br/> <br/>worked in triage in the emergency room in order to streamline patient check in so that the sickest patients were sure to be seen first. assisted rn's and md's as needed with all aspects of patient care including venipuncture for iv access and blood collection. obtained patient histories, started iv's, administered medications and charted treatments. also worked in patient care in the burn unit, the wound care center, and the hyperbaric unit in this hospital and was involved with all aspects of patient care as it related to each department. maintained and utilized a variety of medical equipment in the diagnosis and treatment of patients including 12 lead ekg. measured and recorded patient's vital signs, prepared patients for treatments, conducted patient education with regards to their treatment, provided wound care, wound debridement, dressing changes, and suture removal. conducted patient testing to determine hbo candidacy. maintained inventory of supplies used in wound care. transported patients via ambulance to other facilities for tests, for transfer of care, and to their residence upon discharge.</p>
# </div></div>
# <div class="work-experience-section last" id="workexperience-eel6jrf6jgewgl9olxgqwg"><div class="data_display">
# <p class="work_title title">paramedic /patient care technician</p>
# <div class="work_company">
# <span class="bold">baptist memorial hospital tipton</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>covington, tn</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">august 1989 to april 1992</p>
# <p class="work_description">maintained a state of readiness to respond, via ambulance, to medical emergencies throughout the county. responded as needed or required to emergency calls for medical assistance, hazardous material incidents, vehicle accidents, explosions, fires, etc. operated ambulance on emergency calls on both daylight and night time responses. conducted patient assessments for nature and severity of illness / injury in order to determine appropriate medical treatment or procedure. administered basic and advanced life support on scene and enroute to the hospital. performed invasive and non invasive procedures on patients with life threatening and non life threatening conditions and administered medications as needed or required according to medical protocol. maintained patient care information. worked in the emergency room between ambulance calls assisting md's and rn's with all aspects of patient care including venipuncture for the purpose of iv access and blood collection, triage, charting, suturing, suture removal, x rays, ekg's, hospital admissions, splinting, bandaging, maintaining inventory of supplies,</p>
# </div></div>
# </div>
# </div>
#
# <div class="section-item awards-content">
# <div><div class="section_title"><h2>awards</h2></div></div>
# <div class="items-container" id="award-items"><div class="award-section last" id="award-eewonvibs0gghgiymcl89g"><div class="data_display">
# <p class="award_title">academic excellence award from southwest tn community college</p>
# <p class="award_date">june 1987</p>
# <p class="award_description">awarded the emt award for academic excellence during studies for maintaining the highest gpa throughout the program.</p>
# </div></div></div>
# </div>
# <div class="section-item certification-content">
# <div><div class="section_title"><h2>certifications/licenses</h2></div></div>
# <div class="items-container" id="certification-items">
# <div class="certification-section " id="certification-eewonxrgwe6xqitele7s5a"><div class="data_display">
# <p class="certification_title">bls/cpr</p>
# <p class="certification_date">february 2015 to february 2017</p>
# <p class="certification_description">basic cpr certification</p>
# </div></div>
# <div class="certification-section last" id="certification-eewonzi7keoxqitele7s5a"><div class="data_display">
# <p class="certification_title">acls provider</p>
# <p class="certification_date">march 2015 to march 2017</p>
# <p class="certification_description">advanced cardiac life support</p>
# </div></div>
# </div>
# </div>
# <div class="section-item publications-content">
# <div><div class="section_title"><h2>publications</h2></div></div>
# <div class="items-container" id="publication-items"><div class="publication-section last" id="publication-eewon3zvvmcxqitele7s5a"><div class="data_display">
# <p class="publication_title">almost a whisper  a holistic approach to working with your horse</p>
# <p class="publication_date">september 1999</p>
# <p class="publication_description">i wrote this book about my husband's technique for working with horses using the horse's natural instincts to gentle them.</p>
# </div></div></div>
# </div>
# </div>
#
#
# paramedic/ cardiac monitor technician
# paramedic/ cardiac monitor technician
#
# fayetteville, tn
# -
#
# • have been a paramedic since 1988 with extensive medical experience in the field and in a clinical setting. • able to work well with no supervision. • currently bls and acls certified
#
#
# work experience
#
#
# paramedic/ cardiac monitor technician
#
# cardiolabs, inc - franklin, tn
#
# -
# august 2007 to november 2011
# take calls from patients for ekg event monitoring transmission. locate the patient's file and receive the cardiac rhythm via telephone and computer. using computer gems program, take measurements using computer calipers and interpret the rhythm. fill out the patient report and send it to the patient's cardiologist via fax. follow protocols for priority notification for life threatening abnormal rhythms such as sinus arrest of greater than 2 seconds in duration, new and symptomatic onset of atrial fibrillation, runs of v-tach, etc.  maintain quality control on the reports that are being submitted to the cardiologists. assist other technicians with questionable interpretations. had to maintain a calm demeanor despite multiple transmissions coming in simultaneously, dealing with a wide range in patient ages and ability to comprehend how to operate the monitors, and numerous other variables. required to maintain acls certification paramedic licensure and have an understanding of current hippa laws.
#
#
# paramedic/ operations supervisor
#
# cardiolabs, inc - nashville, tn
#
# -
# august 2007 to march 2009
# as operations supervisor, my priorities were in coordinating the daily and weekly schedule to coincide with customer demand and unit deployment. solved day to day issues as they occurred. provided leadership and day to day management of the operations department. conducted employee education and training, tracked attendance and made certain that ambulance calls were completed in an efficient and safe manner. maintained log of employee certifications. maintained medications and fluids and made sure the ambulances were cleaned, stocked, and in working order. staffed ambulance and functioned as a paramedic as needed. when functioning in the role of a paramedic i was required to render medical care to patients as needed or required according to state protocol.  sept. 2002-aug 2006
#
#
# paramedic / occupational medicine
#
# gaylord opryland - nashville, tn
#
# -
# may 1992 to september 1996
# operated the onsite medical clinic at the hotel, the grand ol' opry and aboard the general jackson showboat. rendered routine and emergency medical care to the hotel guests and employees. maintained all emergency advanced life support equipment in proper working order and a state of readiness to respond. maintained inventory of drugs, medicines, and supplies and followed state protocol for utilization of narcotics used in treatment. worked alone in a fast paced, often stressful and busy atmosphere. obtained medical histories. conducted patient assessments for nature and severity of illness/injury and determined appropriate medical treatment or procedure. performed invasive procedures as needed or required such as iv access, blood collection and endotracheal intubations.  maintained patient care information, response logs and entered data into the computer. filed workman's compensation claims for on the job staff injuries and referred patients to doctors for follow up according to tennessee worker's compensation law. utilized various emergency medical equipment to aid in diagnosis and treatment of patients.  paramedic/ hbo technician  regional medical center @ memphis 877 jefferson ave memphis, tn 38103  worked in triage in the emergency room in order to streamline patient check in so that the sickest patients were sure to be seen first. assisted rn's and md's as needed with all aspects of patient care including venipuncture for iv access and blood collection. obtained patient histories, started iv's, administered medications and charted treatments. also worked in patient care in the burn unit, the wound care center, and the hyperbaric unit in this hospital and was involved with all aspects of patient care as it related to each department. maintained and utilized a variety of medical equipment in the diagnosis and treatment of patients including 12 lead ekg. measured and recorded patient's vital signs, prepared patients for treatments, conducted patient education with regards to their treatment, provided wound care, wound debridement, dressing changes, and suture removal. conducted patient testing to determine hbo candidacy. maintained inventory of supplies used in wound care. transported patients via ambulance to other facilities for tests, for transfer of care, and to their residence upon discharge.
#
#
# paramedic /patient care technician
#
# baptist memorial hospital tipton - covington, tn
#
# -
# august 1989 to april 1992
# maintained a state of readiness to respond, via ambulance, to medical emergencies throughout the county. responded as needed or required to emergency calls for medical assistance, hazardous material incidents, vehicle accidents, explosions, fires, etc. operated ambulance on emergency calls on both daylight and night time responses. conducted patient assessments for nature and severity of illness / injury in order to determine appropriate medical treatment or procedure. administered basic and advanced life support on scene and enroute to the hospital. performed invasive and non invasive procedures on patients with life threatening and non life threatening conditions and administered medications as needed or required according to medical protocol. maintained patient care information. worked in the emergency room between ambulance calls assisting md's and rn's with all aspects of patient care including venipuncture for the purpose of iv access and blood collection, triage, charting, suturing, suture removal, x rays, ekg's, hospital admissions, splinting, bandaging, maintaining inventory of supplies,
#
#
#
#
#
# awards
#
# academic excellence award from southwest tn community college
# june 1987
# awarded the emt award for academic excellence during studies for maintaining the highest gpa throughout the program.
#
#
#
# certifications/licenses
#
#
# bls/cpr
# february 2015 to february 2017
# basic cpr certification
#
#
# acls provider
# march 2015 to march 2017
# advanced cardiac life support
#
#
#
#
# publications
#
# almost a whisper  a holistic approach to working with your horse
# september 1999
# i wrote this book about my husband's technique for working with horses using the horse's natural instincts to gentle them.
#
#
#
# <div class="vcard single_form-content" id="resume_body">
# <div class="last basicinfo-content" id="basic_info_row"><div class="data_display" id="basic_info_cell">
# <h1 class="fn " id="resume-contact" itemprop="name">native hawaiian student services (nhss)</h1>
# <div id="contact_info_container">
# <div class="adr" itemprop="address" itemscope="" itemtype="http://schema.org/postaladdress"><p class="locality" id="headline_location" itemprop="addresslocality">honolulu, hi</p></div>
# <div class="separator-hyphen">-</div>
# </div>
# <p class="summary" id="res_summary">i am seeking part-full time employment with an institution that has an understanding of the needs of graduate <br/>students seeking employment while completing their degrees. <br/> <br/>current status <br/>i am currently a full time graduate student at the university of hawaii at mānoa (uhm) <br/>in my second year of a masters in pacific island studies and a graduate certificate in <br/>conflict resolution. <br/> <br/>about me <br/>i am very passionate about the preservation and perpetuation of hawaiian culture and <br/>the environment (ʻāina) which nourishes it.  my years as the foreman of a landscaping <br/>company and my more recent years as an office manager, student assistant, and <br/>program coordinator have given me leadership skills and a strong work ethic that i <br/>believe has helped me to excel in projects and tasks which are assigned to me. the <br/>research and development of programs (grant writing, community networking, defining <br/>of social and educational objectives and goals and the assessment of outcomes) has <br/>given me a sense of what it takes to navigate the logistics and structures of upper <br/>academia that i feel will aid in my duties and responsibilities in any position. <br/> <br/>abilities <br/>i am proficient in mac/microsoft word/excel/powerpoint, adobe <br/>illustrator/dreamweaver, filezilla, and gmail/docs/groups/forms/spreadsheets. i am <br/>an independent worker that is not afraid to take on tasks alone if needs be and am a <br/>seasoned team player in multiple aspects throughout my personal, academic, and career <br/>endeavors.</p>
# <p id="employment_eligibility">authorized to work in the us for any employer</p>
# </div></div>
# <div class="section-item workexperience-content">
# <div><div class="section_title"><h2>work experience</h2></div></div>
# <div class="items-container" id="work-experience-items">
# <div class="work-experience-section " id="workexperience-eeaj0giphwyg1dessc6fxa"><div class="data_display">
# <p class="work_title title">native hawaiian student services (nhss)</p>
# <div class="work_company"><span class="bold">university of hawaii</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">september 2015 to august 2016</p>
# <p class="work_description">at mānoa <br/>september 2015 to august 2016 <br/> <br/>this is a pilot position that was designed to follow a cohort of 150+native hawaiian <br/>students through specific coursework and civic engagement in the college of social <br/>sciences. <br/>my duties include: coordinating and implementing programs ­ including orientations, <br/>activities, and initiatives with community partners and uhm departments, mentoring <br/>students, helping to develop future programs and initiatives, and serving as a bridge between native hawaiian student services (nhss), the college of social sciences (css), and the program for civic engagement (pce).</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eeaj0giprh2g1dessc6fxa"><div class="data_display">
# <p class="work_title title">nhi assistant coordinator</p>
# <div class="work_company"><span class="bold">css civic engagement</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">june 2012 to august 2015</p>
# <p class="work_description">program for civic engagement, university of hawaii at mānoa college of social <br/>sciences. june 2012 to august 2015 <br/> <br/>i assisted in the coordination of several civic­ engagement and service­learning <br/>programs, projects, and initiatives under the program for civic engagement (pce), <br/>university of hawaii at mānoa (uhm) college of social sciences (css) as a student, <br/>student leader, and program coordinator working to help preserve and perpetuate <br/>hawaiian culture and education on institutional and community levels working with individuals from grass roots efforts to renowned academics and people from all walks of <br/>life on both local, national, and international levels. my duties included: coordinating and implementing programs ­ including orientations, activities, and initiatives with community partners, uhm departments, other institutions of higher education (ihe), and public and private k­12 schools. the work also included maintaining community <br/>partner relationships, coordinating service­learning students (registration, progress, <br/>transportation, and special needs), collecting and correlating data for community <br/>partners and pce, production of reports, developing new projects, reporting to instructors on student progress, coordinating with other ihe (particularly kcc, hpu, <br/>cuh), and maintaining the css/pce service­learning website and event calendar, <br/>responding to pce service­learning email, creating and updating program <br/>brochures/fliers/posters, promoting programs and initiatives at service­learning fairs, <br/>attending/leading program activities, presenting at local/regional and national <br/>conferences, and performing general office duties. i also worked on several grant writing <br/>initiatives for various programs (including those listed below). it was a challenging job <br/>that i enjoyed very much. <br/> <br/>specific projects that i continue to be involved with, include, but are not limited to: <br/>● the mālama i nā ahupuaʻa service­learning program (mina), which focuses on <br/>native rights, kuleana, cultural access, sustainability, food sovereignty, cultural and environmental preservation, and documentation. <br/>● the native hawaiian initiative (nhi), creating a sense of belonging for students at the uhm college of social sciences and focusing on supporting academic <br/>excellence and the development of student leaders of native hawaiian ancestry <br/>who are encouraged to become community advocates. <br/>● the ka holo waʻa program which fosters connections between students and the <br/>waʻa (voyaging) communities in the pacific islands on academic and community <br/>levels. it is a <br/>● the pālolo ʻohana program (pop), which focuses on community needs through education (lectures, films, talk story sessions, and dinner) and is designed around <br/>specific areas of concern in the community. pop is a project under the larger pālolo <br/>pipeline program run out of css. <br/>● the exploring my backyard and beyond summer science program (ebb), which engages student leaders with the mixed pacific islander youth of the pālolo <br/>community in a two week stem focused program every june. <br/>● oceanic connections forum ­ connecting pacific islander immigrant groups with <br/>local communities arranged by the department of ethnic studies and center for <br/>pacific islands studies at uhm for the general public and uhm folks about ethnic <br/>relations in hawaii with a focus on pacific islanders, health and education. yearly during the spring semester. <br/>● the development of curricula based on sustainability and science, technology, <br/>engineering, and math (stem) taught through hawaiian epistemology and practice (civic engagement) ­ for college students and in turn for k­12 students</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eeaj0gip1s6g1dessc6fxa"><div class="data_display">
# <p class="work_title title">teaching assistant</p>
# <div class="work_company">
# <span class="bold">uhm, roderick n. labrador, ph.d</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>honolulu, hi</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">march 2015 to may 2015</p>
# <p class="work_description">i held this position for the last two semesters of my undergrad ba and enjoyed it very <br/>much. being able to work with both professors allowed me to experience different <br/>methodologies and approaches to the course (lectures and labs) and gave me insights <br/>that deepened my understanding of both the top down and bottom up dynamics of the course and generally working with students from an instructor's perspective. i prepared <br/>lesson plans, administered quizzes and exams, held study groups, tutored students, and worked directly with support faculty, staff, and additional student leaders in various <br/>capacities.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eeaj0gip1s-g1dessc6fxa"><div class="data_display">
# <p class="work_title title">teaching assistant</p>
# <div class="work_company"><span class="bold">ethnic studies</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">september 2014 to november 2014</p>
# <p class="work_description">monisha das gupta, ph.d.</p>
# </div></div>
# <div class="work-experience-section last" id="workexperience-eeaj0gip_ecg1dessc6fxa"><div class="data_display">
# <p class="work_title title">osa peer mentor/student assistant ii</p>
# <div class="work_company"><span class="bold">kapiʻolani community college</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">august 2010 to january 2014</p>
# <p class="work_description">i held this position for a little more than three  years. my duties included assisting <br/>students with tutoring, academic planning, and solving day­to­day problems related to college life. in addition, i assisted in the production (coordination and promotion) of <br/>several events on campus such as concerts, debate forums, and commencement. my <br/>office duties also included overseeing the sales and tracking (balances, deposits etc,) of student buspasses, movie tickets, and specialty ids, as well as locker rentals. i issued <br/>regular student and faculty ids, did semester validations for returning students, and oversaw the formation and regular operations of the registered independent student</p>
# </div></div>
# </div>
# </div>
#
# <div class="section-item skills-content">
# <div><div class="section_title"><h2>skills</h2></div></div>
# <div class="items-container" id="skills-items"><div class="data_display"><div class="skill-container resume-element">
# <span class="skill-text">microsoft office (6 years)</span>, <span class="skill-text">google+ (6 years)</span>, <span class="skill-text">adobe + (6 years)</span>, <span class="skill-text">dreamweaver (4 years)</span>
# </div></div></div>
# </div>
# <div class="section-item certification-content">
# <div><div class="section_title"><h2>certifications</h2></div></div>
# <div class="items-container" id="certification-items"><div class="certification-section last" id="certification-eeaj0u5vlvw3e3tcoxaklq"><div class="data_display"><p class="certification_title">grad. cert. in conflict resolution</p></div></div></div>
# </div>
# </div>
#
#
# native hawaiian student services (nhss)
#
# honolulu, hi
# -
#
# i am seeking part-full time employment with an institution that has an understanding of the needs of graduate students seeking employment while completing their degrees.  current status i am currently a full time graduate student at the university of hawaii at mānoa (uhm) in my second year of a masters in pacific island studies and a graduate certificate in conflict resolution.  about me i am very passionate about the preservation and perpetuation of hawaiian culture and the environment (ʻāina) which nourishes it.  my years as the foreman of a landscaping company and my more recent years as an office manager, student assistant, and program coordinator have given me leadership skills and a strong work ethic that i believe has helped me to excel in projects and tasks which are assigned to me. the research and development of programs (grant writing, community networking, defining of social and educational objectives and goals and the assessment of outcomes) has given me a sense of what it takes to navigate the logistics and structures of upper academia that i feel will aid in my duties and responsibilities in any position.  abilities i am proficient in mac/microsoft word/excel/powerpoint, adobe illustrator/dreamweaver, filezilla, and gmail/docs/groups/forms/spreadsheets. i am an independent worker that is not afraid to take on tasks alone if needs be and am a seasoned team player in multiple aspects throughout my personal, academic, and career endeavors.
# authorized to work in the us for any employer
#
#
# work experience
#
#
# native hawaiian student services (nhss)
# university of hawaii
# -
# september 2015 to august 2016
# at mānoa september 2015 to august 2016  this is a pilot position that was designed to follow a cohort of 150+native hawaiian students through specific coursework and civic engagement in the college of social sciences. my duties include: coordinating and implementing programs ­ including orientations, activities, and initiatives with community partners and uhm departments, mentoring students, helping to develop future programs and initiatives, and serving as a bridge between native hawaiian student services (nhss), the college of social sciences (css), and the program for civic engagement (pce).
#
#
# nhi assistant coordinator
# css civic engagement
# -
# june 2012 to august 2015
# ...
#
#
# general coordinator &amp; site manager
#
# inex factory - riyadh
#
# -
# april 1999 to november 2003
# responsibilities: general coordinator: for all the factory projects involving preparation of the contracts, developing the project schedule, coordination between the factory departments in order to obtain the required product as per the client requirements. the following project are the main: - all king area projects at riyadh. (saudi oger). - private villa, mr saad al-hareri. (saudi oger). - main hall at al faisaliah tower. (saudi bin ladin grope). -   al      mamlakah        tower      market.     (al-saif contracting co). -   private villas inside and outside riyadh area.  • site manager: for certain projects that required exclusive attention, following the shop drawings with the client &amp; the fabrication with the factory, supervising the installation at the site. - swimming pool at al janadriyah farm/ king area/. (saudi oger). - private villa #111 at al janadriyah farm/king area/(saudi oger). - private villas inside and outside riyadh area.
#
#
# geotechnical designer &amp; site engineer
#
# saudi labs ltd - riyadh
#
# -
# march 1998 to october 1999
# responsibilities: prepared the scope of works for soil investigations programs, supervised filed investigations works and this following inclusive the preparation of the inspection location, , correct and finalized the geotechnical reports. study the stability of the old buildings and make the necessary actions to strengthen it as injecting the soil under these buildings. following projects are the main:  -   qassim- maddinah express way: site engineer of geotechnical investigations for the under construction bridges. preparation the geotechnical report and the foundation design. (saudi bin ladin grope) -   technical college, riyadh, (al rashed co.). -   different schools projects for ministry of education in qassim. -   different projects in several regions of the kingdom
#
#
#
#
#
# <div class="vcard single_form-content" id="resume_body">
# <div class="last basicinfo-content" id="basic_info_row"><div class="data_display" id="basic_info_cell">
# <h1 class="fn " id="resume-contact" itemprop="name">robin bloomfield</h1>
# <h2 id="headline" itemprop="jobtitle">general practice legal secretary - the kizer law firm</h2>
# <div id="contact_info_container">
# <div class="adr" itemprop="address" itemscope="" itemtype="http://schema.org/postaladdress"><p class="locality" id="headline_location" itemprop="addresslocality">linden, mi</p></div>
# <div class="separator-hyphen">-</div>
# </div>
# </div></div>
# <div class="section-item workexperience-content">
# <div><div class="section_title"><h2>work experience</h2></div></div>
# <div class="items-container" id="work-experience-items">
# <div class="work-experience-section " id="workexperience-eexnrikl4dgf0lli6yveoa"><div class="data_display">
# <p class="work_title title">general practice legal secretary</p>
# <div class="work_company" itemprop="worksfor" itemscope="" itemtype="http://schema.org/organization">
# <span class="bold" itemprop="name">the kizer law firm</span> <div class="separator-hyphen">-</div> <div class="inline-block" itemprop="address" itemscope="" itemtype="http://schema.org/postaladdress"><span itemprop="addresslocality">howell, mi</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">october 2012 to present</p>
# <p class="work_description">specializing in family law, criminal law and providing a <br/>full range of administrative support to two partners/attorneys.  responsibilities include <br/>typing various legal documents, drafting correspondence and pleadings, telephone <br/>communications, scheduling, assisting clients, tracking discovery, organizing and maintaining files.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eexnrikmb0of0lli6yveoa"><div class="data_display">
# <p class="work_title title">para professional, and recess</p>
# <div class="work_company"><span class="bold">the thurswell law firm and kevin cox</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">january 2012 to october 2012</p>
# <p class="work_description">pesg) <br/> <br/>substitute for linden community schools as a secretarial, para professional, and recess <br/>aide substitute.  worked in all of the linden school buildings.  worked in the capacity of office­secretarial, ci rooms, ei rooms, one­on­one aide and recess aide.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eexnrikmb0kf0lli6yveoa"><div class="data_display">
# <p class="work_title title">independent contractor</p>
# <div class="work_company"><span class="bold">the thurswell law firm and kevin cox</span></div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">april 1999 to october 2012</p>
# <p class="work_description">typing medical malpractice expert doctor reviews regarding medical malpractice cases for gerald thurswell, the thurswell law firm and kevin cox, weiner &amp; cox.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eexnrikmb0sf0lli6yveoa"><div class="data_display">
# <p class="work_title title">receptionist, dispatcher and scheduler for a non­emergency transportation company</p>
# <div class="work_company">
# <span class="bold">the thurswell law firm and kevin cox</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>davison, mi</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">july 2009 to december 2011</p>
# <p class="work_description">p.o. box 741, davison, mi  48423 ­ 810­658­6000 <br/> <br/>receptionist, dispatcher and scheduler for a non­emergency transportation company.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eexnrikmb0wf0lli6yveoa"><div class="data_display">
# <p class="work_title title">substitute for linden community schools as a substitute aide, office administration</p>
# <div class="work_company">
# <span class="bold">the thurswell law firm and kevin cox</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>linden, mi</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">september 2004 to may 2005</p>
# <p class="work_description">library aide, special education aide, one­on­one aide, and recess aide.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eexnrikmb0af0lli6yveoa"><div class="data_display">
# <p class="work_title title">medical malpractice legal secretary</p>
# <div class="work_company">
# <span class="bold">thurswell, chayet &amp; weiner, p.c</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>southfield, mi</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">march 1992 to january 1997</p>
# <p class="work_description">1000 town center, ste. 500, southfield, mi  48075 - (810) 948­0000 <br/> <br/>medical malpractice legal secretary specializing in birth trauma and providing a full <br/>range of administrative support to partner/attorney.  responsibilities include typing <br/>various legal documents, drafting correspondence and pleadings, telephone <br/>communications, scheduling, assisting clients, tracking discovery, organizing and maintaining files. <br/>14419 oak leaf trail <br/>linden, mi  48451 <br/>(810) 625­1591 <br/>rbloomfield01@yahoo.com</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eexnrikmb0ef0lli6yveoa"><div class="data_display">
# <p class="work_title title">medical malpractice/personal injury legal secretary</p>
# <div class="work_company">
# <span class="bold">matz &amp; rubin, p.c</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>farmington hills, mi</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">january 1991 to february 1992</p>
# <p class="work_description">30300 northwestern hwy., ste. 250, farmington hills, mi  48334 ­ (313) 932­2800 <br/> <br/>medical malpractice/personal injury legal secretary providing a full range of administrative support to associate attorney.  responsibilities included typing various <br/>legal documents, drafting correspondence and pleadings, telephone communications, <br/>scheduling, assisting clients, tracking discovery, organizing and maintaining files. <br/>personal injury files included medical malpractice/birth trauma, first­party auto <br/>negligence, third­party auto negligence and premise liability.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eexnrikmb0if0lli6yveoa"><div class="data_display">
# <p class="work_title title">litigation secretary</p>
# <div class="work_company">
# <span class="bold">babcock &amp; kaufman</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>farmington hills, mi</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">april 1989 to january 1991</p>
# <p class="work_description">to both partners, as well as litigation secretary to inkster city <br/>attorney.  general practice law firm specializing in divorce, litigation, probate, corporate, <br/>bankruptcy, real estate and collection.  responsibilities included typing various legal <br/>documents, preparation of billing statements, disbursements, drafting correspondence, <br/>telephone communications, scheduling, filing, organizing and maintaining files.</p>
# </div></div>
# <div class="work-experience-section " id="workexperience-eexnrikmb0mf0lli6yveoa"><div class="data_display">
# <p class="work_title title">legal secretary</p>
# <div class="work_company">
# <span class="bold">tolley, fisher &amp; verwys, p.c</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>grand rapids, mi</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">february 1988 to march 1989</p>
# <p class="work_description">to three paralegals.  job responsibilities included typing, dictation, <br/>telephone communications, filing, office billing, summarizing and organizing exhibits, <br/>organizing and maintaining files.  files worked on included general litigation and collection.</p>
# </div></div>
# <div class="work-experience-section last" id="workexperience-eexnrikmb0qf0lli6yveoa"><div class="data_display">
# <p class="work_title title">legal secretary</p>
# <div class="work_company">
# <span class="bold">seigel, hudson, gee, shaw &amp; fisher</span> <div class="separator-hyphen">-</div> <div class="inline-block"><span>hastings, mi</span></div>
# </div>
# <div class="separator-hyphen">-</div>
# <p class="work_dates">june 1984 to august 1985</p>
# </div></div>
# </div>
# </div>
#
# </div>
#
#
# robin bloomfield
# general practice legal secretary - the kizer law firm
#
# linden, mi
# -
#
#
#
# work experience
#
#
# general practice legal secretary
#
# the kizer law firm - howell, mi
#
# -
# october 2012 to present
# specializing in family law, criminal law and providing a full range of administrative support to two partners/attorneys.  responsibilities include typing various legal documents, drafting correspondence and pleadings, telephone communications, scheduling, assisting clients, tracking discovery, organizing and maintaining files.
#
#
# para professional, and recess
# the thurswell law firm and kevin cox
# -
# january 2012 to october 2012
# pesg)  substitute for linden community schools as a secretarial, para professional, and recess aide substitute.  worked in all of the linden school buildings.  worked in the capacity of office­secretarial, ci rooms, ei rooms, one­on­one aide and recess aide.
#
#
# independent contractor
# the thurswell law firm and kevin cox
# -
# april 1999 to october 2012
# typing medical malpractice expert doctor reviews regarding medical malpractice cases for gerald thurswell, the thurswell law firm and kevin cox, weiner &amp; cox.
#
#
# receptionist, dispatcher and scheduler for a non­emergency transportation company
#
# the thurswell law firm and kevin cox - davison, mi
#
# -
# july 2009 to december 2011
# p.o. box 741, davison, mi  48423 ­ 810­658­6000  receptionist, dispatcher and scheduler for a non­emergency transportation company.
#
#
# substitute for linden community schools as a substitute aide, office administration
#
# the thurswell law firm and kevin cox - linden, mi
#
# -
# september 2004 to may 2005
# library aide, special education aide, one­on­one aide, and recess aide.
#
#
# medical malpractice legal secretary
#
# thurswell, chayet &amp; weiner, p.c - southfield, mi
#
# -
# march 1992 to january 1997
# 1000 town center, ste. 500, southfield, mi  48075 - (810) 948­0000  medical malpractice legal secretary specializing in birth trauma and providing a full range of administrative support to partner/attorney.  responsibilities include typing various legal documents, drafting correspondence and pleadings, telephone communications, scheduling, assisting clients, tracking discovery, organizing and maintaining files. 14419 oak leaf trail linden, mi  48451 (810) 625­1591 rbloomfield01@yahoo.com
#
#
# medical malpractice/personal injury legal secretary
#
# matz &amp; rubin, p.c - farmington hills, mi
#
# -
# january 1991 to february 1992
# 30300 northwestern hwy., ste. 250, farmington hills, mi  48334 ­ (313) 932­2800  medical malpractice/personal injury legal secretary providing a full range of administrative support to associate attorney.  responsibilities included typing various legal documents, drafting correspondence and pleadings, telephone communications, scheduling, assisting clients, tracking discovery, organizing and maintaining files. personal injury files included medical malpractice/birth trauma, first­party auto negligence, third­party auto negligence and premise liability.
#
#
# litigation secretary
#
# babcock &amp; kaufman - farmington hills, mi
#
# -
# april 1989 to january 1991
# to both partners, as well as litigation secretary to inkster city attorney.  general practice law firm specializing in divorce, litigation, probate, corporate, bankruptcy, real estate and collection.  responsibilities included typing various legal documents, preparation of billing statements, disbursements, drafting correspondence, telephone communications, scheduling, filing, organizing and maintaining files.
#
#
# legal secretary
#
# tolley, fisher &amp; verwys, p.c - grand rapids, mi
#
# -
# february 1988 to march 1989
# to three paralegals.  job responsibilities included typing, dictation, telephone communications, filing, office billing, summarizing and organizing exhibits, organizing and maintaining files.  files worked on included general litigation and collection.
#
#
# legal secretary
#
# seigel, hudson, gee, shaw &amp; fisher - hastings, mi
#
# -
# june 1984 to august 1985

# %%
multinomial = MultinomialNB()
multinomial.fit(train_transformed, predictors_train_['bachelor'].astype(int))
f1score_multi = multinomial.score(dev_transformed, predictors_test['bachelor'].astype(int)) 

pred_multi = multinomial.predict_proba(dev_transformed)

accuracy = round(f1score_multi, 6)
log_loss_ = round(log_loss(predictors_test['bachelor'].astype(int), pred_multi), 6)

print("Accuracy: " + str(accuracy))
print("Log Loss: " + str(log_loss_))
model_results.append({"accuracy" : accuracy, "name" : "TFIDF HTML NB - Predict Bachelor", "log_loss": log_loss_})
# Out:
# Accuracy: 0.675449
# Log Loss: 0.979609

# %%
multinomial_plain = MultinomialNB()
multinomial_plain.fit(train_transformed_plain, predictors_train_['bachelor'].astype(int))
f1score_multi = multinomial_plain.score(dev_transformed_plain, predictors_test['bachelor'].astype(int)) 

pred_plain_multi = multinomial_plain.predict_proba(dev_transformed_plain)

accuracy = round(f1score_multi, 6)
log_loss_ = round(log_loss(predictors_test['bachelor'].astype(int), pred_plain_multi), 6)

print("Accuracy: " + str(accuracy))
print("Log Loss: " + str(log_loss_))
model_results.append({"accuracy" : accuracy, "name" : "TFIDF Plain NB - Predict Bachelor", "log_loss": log_loss_})
# Out:
# Accuracy: 0.706906
# Log Loss: 0.774902

# %%
showValues = construct_columns_for_top_vocab(vectorizer_train, multinomial)
df = pd.DataFrame.from_dict(showValues, orient='index')
display(df)
# Out:
#                     0
# div            -5.970
# class          -6.045
# id             -6.323
# br             -6.385
# span           -6.397
# and            -6.448
# to             -6.531
# work           -6.589
# separator      -6.610
# hyphen         -6.610
# section        -6.618
# itemprop       -6.625
# experience     -6.629
# data_display   -6.649
# h2             -6.700
# workexperience -6.744
# content        -6.754
# of             -6.780
# items          -6.797
# the            -6.804
# in             -6.832
# work_dates     -6.870
# for            -6.870
# bold           -6.876
# work_company   -6.879

# %%
showValues = construct_columns_for_top_vocab(vectorizer_train_plain, multinomial_plain)
df = pd.DataFrame.from_dict(showValues, orient='index')
display(df)
# Out:
#                  0
# and         -5.936
# to          -5.998
# of          -6.273
# the         -6.286
# in          -6.312
# for         -6.354
# with        -6.445
# work        -6.578
# skills      -6.652
# customer    -6.715
# as          -6.732
# service     -6.735
# on          -6.813
# years       -6.837
# experience  -6.841
# 2015        -6.886
# 2014        -6.904
# all         -6.935
# sales       -6.943
# management  -6.946
# 2013        -6.958
# office      -6.979
# present     -6.991
# information -7.006
# august      -7.013

# %%
from sklearn.base import TransformerMixin
from sklearn.pipeline import FeatureUnion

# %%
# Loading list of stopwords from nltk corpus
stop_words = stopwords.words('english')

# Helper function for finding the percent of stop words in the message
def contains_stop_words(x):
    count = 0
    
    tokens = x.lower().split()
    for value in tokens:
        if value in stop_words:
            count = count + 1
    
    return count / float(len(tokens))

# The word length function for counting how long individual words are
def word_length(x):
    total_chars = len(x)
    num_words = len(x.split())
    return total_chars / float(num_words)

# Helper function for finding the number of unique words
def unique_words(x):
    num_words = len(set(x.lower().split()))
    return num_words

def capitalized_percent(x):
    total_chars = len(x)
    num_capi = len(re.findall(r'[A-Z]', x))
    return num_capi / float(total_chars)

# Helper function for calculating the percent of non-alpha numeric characters
def non_alphanumeric_percent(x):
    total_chars = len(x)
    num_special = len(re.findall(r'[^0-9a-zA-Z ]', x))
    return num_special / float(total_chars)

# Helper function for calculating the percent of non-alpha numeric non-period, comma, dash characters
def non_alphanumeric_noperiodscommas_percent(x):
    total_chars = len(x)
    num_special = len(re.findall(r'[^0-9a-zA-Z.,-/ ]', x))
    return num_special / float(total_chars)

# Helper function for calculating the percent of non-alpha-numeric specific punctuation characters
def non_alphanumeric_specificpunc_percent(x):
    total_chars = len(x)
    num_special = len(re.findall(r'[!@$%&*]', x))
    return num_special / float(total_chars)

# Helper function for calculating the percent of just ! characters
def non_alphanumeric_just_exclamation_percent(x):
    total_chars = len(x)
    num_special = len(re.findall(r'[!]', x))
    return num_special / float(total_chars)

# Class transformer for TextLengthTransformer
class TextLengthTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: len(x) > 150 )).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self

# Class transformer for TokenLengthTransformer
class TokenLengthTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: len([word for word in x.split() if word]))).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self

# Class transformer for AverageWordLengthTransformer
class AverageWordLengthTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: word_length(x))).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self

# Class transformer for AverageWordLengthNormalTransformer
class AverageWordLengthNormalTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: word_length(x) > 100)).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self
    
# Class transformer for CapitalizedPercentTransformer
class CapitalizedPercentTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: capitalized_percent(x))).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self

# Class transformer for SpecificPunctuationTransformer
class SpecificPunctuationTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: non_alphanumeric_specificpunc_percent(x))).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self

# Class transformer for SpecificPunctuationExclamaTransformer
class SpecificPunctuationExclamaTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: non_alphanumeric_just_exclamation_percent(x))).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self

# Class transformer for UniqueWordsTransformer
class UniqueWordsTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: unique_words(x))).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self
    
# Class transformer for ContainsStopWordsTransformer
class ContainsStopWordsTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: contains_stop_words(x))).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self

class SpecificPunctuationTransformer(TransformerMixin):
    def transform(self, X, **transform_params):
        feature = np.array(X.apply(lambda x: non_alphanumeric_specificpunc_percent(x))).reshape(-1,1)
        return feature

    def fit(self, X, y=None, **fit_params):
        return self

# %%
pipe_all = Pipeline([
    ('features', FeatureUnion([
        ('TextLength', TextLengthTransformer()),
        ('TokenLength', TokenLengthTransformer()),
        ('AverageWordLength', AverageWordLengthTransformer()),
        ('AverageWordLengthNormal', AverageWordLengthNormalTransformer()),
        ('CapitalizedPercent', CapitalizedPercentTransformer()),
        ('SpecificPunctuation', SpecificPunctuationTransformer()),
        ('SpecificPunctuationExclama', SpecificPunctuationExclamaTransformer()),
        ('UniqueWords', UniqueWordsTransformer()),
        ('ContainsStopWords', ContainsStopWordsTransformer()),
        ('tfdif_features', Pipeline([
            ('cv', CountVectorizer()),
            ('tfidf', TfidfTransformer(sublinear_tf = True)),
        ])),
    ])),
    ('logit', LogisticRegression()),

])

pipe_all.fit(train_data_['plain_data'], predictors_train_['bachelor'].astype(int))
f1score_logis = pipe_all.score(test_data_['plain_data'], predictors_test['bachelor'].astype(int))
pred_pipe = pipe_all.predict_proba(test_data_['plain_data'])

accuracy = round(f1score_logis, 6)
log_loss_ = round(log_loss(predictors_test['bachelor'].astype(int), pred_pipe), 6)

print("Accuracy: " + str(accuracy))
print("Log Loss: " + str(log_loss_))
model_results.append({"accuracy" : accuracy, "name" : "TFIDF Plain Log Pipeline [*all] - Predict Bachelor", "log_loss": log_loss_})
# Out:
# Accuracy: 0.73501
# Log Loss: 0.520727

# %%
pipe_all = Pipeline([
    ('features', FeatureUnion([
        ('TextLength', TextLengthTransformer()),
        ('TokenLength', TokenLengthTransformer()),
        ('AverageWordLength', AverageWordLengthTransformer()),
        ('AverageWordLengthNormal', AverageWordLengthNormalTransformer()),
        ('CapitalizedPercent', CapitalizedPercentTransformer()),
        ('SpecificPunctuation', SpecificPunctuationTransformer()),
        ('SpecificPunctuationExclama', SpecificPunctuationExclamaTransformer()),
        ('UniqueWords', UniqueWordsTransformer()),
        ('ContainsStopWords', ContainsStopWordsTransformer()),
        ('tfdif_features', Pipeline([
            ('cv', CountVectorizer()),
            ('tfidf', TfidfTransformer(sublinear_tf = True)),
        ])),
    ])),
    ('logit', LogisticRegression()),

])

pipe_all.fit(train_data_['data'], predictors_train_['bachelor'].astype(int))
f1score_logis = pipe_all.score(test_data_['data'], predictors_test['bachelor'].astype(int))
pred_pipe = pipe_all.predict_proba(test_data_['data'])

accuracy = round(f1score_logis, 6)
log_loss_ = round(log_loss(predictors_test['bachelor'].astype(int), pred_pipe), 6)

print("Accuracy: " + str(accuracy))
print("Log Loss: " + str(log_loss_))
model_results.append({"accuracy" : accuracy, "name" : "TFIDF HTML Log Pipeline [*all] - Predict bachelor", "log_loss": log_loss_})
# Out:
# Accuracy: 0.735409
# Log Loss: 0.522804

# %%
model_results
# Out:
# [{'accuracy': 0.735729,
#   'name': 'TFIDF HTML - Predict Bachelor',
#   'log_loss': 0.521058},
#  {'accuracy': 0.734371,
#   'name': 'TFIDF Plain Text - Predict Bachelor',
#   'log_loss': 0.521902},
#  {'accuracy': 0.675449,
#   'name': 'TFIDF HTML NB - Predict Bachelor',
#   'log_loss': 0.979609},
#  {'accuracy': 0.706906,
#   'name': 'TFIDF Plain NB - Predict Bachelor',
#   'log_loss': 0.774902},
#  {'accuracy': 0.73501,
#   'name': 'TFIDF Plain Log Pipeline [*all] - Predict Bachelor',
#   'log_loss': 0.520727},
#  {'accuracy': 0.735409,
#   'name': 'TFIDF HTML Log Pipeline [*all] - Predict bachelor',
#   'log_loss': 0.522804}]

# %%
import gensim.models.keyedvectors as word2vec
import keras
import gc

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation
from keras.layers import Bidirectional, GlobalMaxPool1D,Bidirectional
from keras.models import Model
from keras import initializers, regularizers, constraints, optimizers, layers

# load word2vec, slimmed down version for performance reasons
word2vecDict = word2vec.KeyedVectors.load_word2vec_format("data/GoogleNews-vectors-negative300-SLIM.bin", binary = True)
embedding_dictionary = dict()

# create the embeddings index from word2vec vocabulary
for word in word2vecDict.wv.vocab:
    embedding_dictionary[word] = word2vecDict.word_vec(word)

### TUNABLE PARAMETERS WE DID NOT TUNE DUE TO RUN TIME DURATION
max_length_cutoff = 200
batch_size = 32
epochs = 3
vocab_size = 16000
embedding_layer = 300

# Initialize tokenizer with a default vocab size, fit on training data
# tokenizer = Tokenizer(num_words = vocab_size)
# tokenizer.fit_on_texts(list(train_data_['data']))

# # for training and test data
# list_tokenized_train = tokenizer.texts_to_sequences(train_data_['data'])
# tokenized_padded_train = pad_sequences(list_tokenized_train, maxlen = max_length_cutoff)

# list_tokenized_test = tokenizer.texts_to_sequences(test_data_['data'])
# tokenized_padded_test = pad_sequences(list_tokenized_test, maxlen = max_length_cutoff)
# Out:
# /Users/sxc2/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /Users/sxc2/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
# https://www.kaggle.com/amberhahn/using-f-score-to-evaluate-the-lstm-model
def model_F_score(newp,newy_test):
    TP=0
    FN=0
    FP=0
    for i in range(len(newp)-1):
        test_prof=newy_test[i+1]-newy_test[i]
        p_prof=newp[i+1] - newp[i]

        if((test_prof>=0) and (p_prof>=0)):
            TP=TP+1
        if ((test_prof>= 0) and (p_prof<0)):
            FN=FN+1
        if ((test_prof<0) and (p_prof>=0)):
            FP=FP+1

    Precision=float(TP)/float(TP+FP)
    Recall=float(TP)/float(TP+FN)

    Fscore= 2.0*Precision*Recall/(Precision+Recall)
    print('classification F score: %.5f' % (Fscore))
    return Fscore

# model_F_score(predictors_test['bachelor'].astype(int), lstm_nn_pred)

# %%
model_predictions = {}

# %%
from keras import backend as K

# https://stackoverflow.com/questions/43547402/how-to-calculate-f1-macro-in-keras
def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
def train_lstm_rnn(_epochs, _embedding_layer, data_name, _max_length_cutoff, _optimizer, _dropout):

    global model_results
    global embedding_dictionary
    
    tokenizer_ = Tokenizer(num_words = vocab_size)
    tokenizer_.fit_on_texts(list(train_data_[data_name]))

    # for training and test data
    list_tokenized_train_ = tokenizer_.texts_to_sequences(train_data_[data_name])
    tokenized_padded_train_ = pad_sequences(list_tokenized_train_, maxlen = _max_length_cutoff)

    list_tokenized_test_ = tokenizer_.texts_to_sequences(test_data_[data_name])
    tokenized_padded_test_ = pad_sequences(list_tokenized_test_, maxlen = _max_length_cutoff)

    number_words_ = len(tokenizer_.word_index)
    embedding_values_ = np.stack(list(embedding_dictionary.values()))
    
    _mean, _std = embedding_values_.mean(), embedding_values_.std()
    embedding_matrix_ = np.random.normal(_mean, _std, (number_words_, _embedding_layer))

    for word, index in tokenizer_.word_index.items():
        index = index - 1
        embedding_vector = embedding_dictionary.get(word)
        if embedding_vector is not None: 
            embedding_matrix_[index] = embedding_vector

    sequence_input_ = Input(shape = (_max_length_cutoff, ))
    x_ = Embedding(len(tokenizer_.word_index), 
                  embedding_matrix_.shape[1], weights = [embedding_matrix_], trainable = False)(sequence_input_)

    x_ = Bidirectional(
        LSTM(60, return_sequences = True, name='lstm_layer', dropout = _dropout, recurrent_dropout = _dropout))(x_)

    x_ = GlobalMaxPool1D()(x_)
    x_ = Dropout(_dropout)(x_)
    x_ = Dense(50, activation = "relu")(x_)
    x_ = Dropout(_dropout)(x_)

    # one output node
    x_ = Dense(1, activation = "sigmoid")(x_)
    model_ = Model(inputs = sequence_input_, outputs = x_)
    model_.compile(loss = 'binary_crossentropy',
                      optimizer = _optimizer,
                      metrics = ['accuracy', 'cosine_proximity', f1])

    # a look at the RNN we're building and its structure
    model_.summary()

    lstm_nn_plain = model_.fit(tokenized_padded_train_, 
                        predictors_train_['bachelor'], 
                        batch_size = batch_size, epochs = _epochs, validation_split = 0.1)
    lstm_nn_pred_plain = model_.predict(tokenized_padded_test_)
    accuracy = model_F_score(predictors_test['bachelor'].astype(int), lstm_nn_pred_plain)
    
    model_details_ = "CO:" + str(_max_length_cutoff) + ", E:" + str(_epochs) + ", " + data_name + ", " + _optimizer
    model_predictions[model_details_] = lstm_nn_pred_plain
    model_results.append({"F1 accuracy" : accuracy, "name" : "LSTM: " + model_details_ + " - Predict Bachelor"})

# %%
train_lstm_rnn(5, 300, 'data', 400, "adam", 0.1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 400)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 400, 300)          105469200
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 400, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                6050
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 105,648,581
# Trainable params: 179,381
# Non-trainable params: 105,469,200
# _________________________________________________________________
# Train on 33818 samples, validate on 3758 samples
# Epoch 1/5
# 33818/33818 [==============================] - 541s 16ms/step - loss: 0.6047 - acc: 0.6783 - cosine_proximity: -0.5673 - f1: 0.7319 - val_loss: 0.5911 - val_acc: 0.6873 - val_cosine_proximity: -0.5596 - val_f1: 0.6765
# Epoch 2/5
# 33818/33818 [==============================] - 512s 15ms/step - loss: 0.5565 - acc: 0.7182 - cosine_proximity: -0.5673 - f1: 0.7512 - val_loss: 0.5479 - val_acc: 0.7227 - val_cosine_proximity: -0.5596 - val_f1: 0.7622
# Epoch 3/5
# 33818/33818 [==============================] - 512s 15ms/step - loss: 0.5375 - acc: 0.7304 - cosine_proximity: -0.5673 - f1: 0.7596 - val_loss: 0.5382 - val_acc: 0.7286 - val_cosine_proximity: -0.5596 - val_f1: 0.7592
# Epoch 4/5
# 33818/33818 [==============================] - 513s 15ms/step - loss: 0.5282 - acc: 0.7356 - cosine_proximity: -0.5673 - f1: 0.7634 - val_loss: 0.5351 - val_acc: 0.7294 - val_cosine_proximity: -0.5596 - val_f1: 0.7611
# Epoch 5/5
# 33818/33818 [==============================] - 513s 15ms/step - loss: 0.5173 - acc: 0.7446 - cosine_proximity: -0.5673 - f1: 0.7713 - val_loss: 0.5349 - val_acc: 0.7360 - val_cosine_proximity: -0.5596 - val_f1: 0.7695
# classification F score: 0.71538

# %%
train_lstm_rnn(5, 300, 'plain_data', 400, "adam", 0.1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 400)               0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 400, 300)          88642800
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 400, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                6050
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 88,822,181
# Trainable params: 179,381
# Non-trainable params: 88,642,800
# _________________________________________________________________
# Train on 33818 samples, validate on 3758 samples
# Epoch 1/5
# 33818/33818 [==============================] - 584s 17ms/step - loss: 0.6066 - acc: 0.6761 - cosine_proximity: -0.5673 - f1: 0.7258 - val_loss: 0.5629 - val_acc: 0.7147 - val_cosine_proximity: -0.5596 - val_f1: 0.7375
# Epoch 2/5
# 33818/33818 [==============================] - 570s 17ms/step - loss: 0.5543 - acc: 0.7178 - cosine_proximity: -0.5673 - f1: 0.7507 - val_loss: 0.5399 - val_acc: 0.7320 - val_cosine_proximity: -0.5596 - val_f1: 0.7632
# Epoch 3/5
# 33818/33818 [==============================] - 563s 17ms/step - loss: 0.5359 - acc: 0.7333 - cosine_proximity: -0.5673 - f1: 0.7618 - val_loss: 0.5403 - val_acc: 0.7291 - val_cosine_proximity: -0.5596 - val_f1: 0.7407
# Epoch 4/5
# 33818/33818 [==============================] - 518s 15ms/step - loss: 0.5255 - acc: 0.7400 - cosine_proximity: -0.5673 - f1: 0.7690 - val_loss: 0.5373 - val_acc: 0.7278 - val_cosine_proximity: -0.5596 - val_f1: 0.7696
# Epoch 5/5
# 33818/33818 [==============================] - 518s 15ms/step - loss: 0.5166 - acc: 0.7446 - cosine_proximity: -0.5673 - f1: 0.7718 - val_loss: 0.5341 - val_acc: 0.7384 - val_cosine_proximity: -0.5596 - val_f1: 0.7550
# classification F score: 0.71589

# %%
train_lstm_rnn(5, 300, 'data', 800, "adam", 0.1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 800)               0
# _________________________________________________________________
# embedding_3 (Embedding)      (None, 800, 300)          105469200
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 800, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_3 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                6050
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 105,648,581
# Trainable params: 179,381
# Non-trainable params: 105,469,200
# _________________________________________________________________
# Train on 33818 samples, validate on 3758 samples
# Epoch 1/5
# 33818/33818 [==============================] - 1045s 31ms/step - loss: 0.6012 - acc: 0.6824 - cosine_proximity: -0.5673 - f1: 0.7320 - val_loss: 0.5616 - val_acc: 0.7073 - val_cosine_proximity: -0.5596 - val_f1: 0.7519
# Epoch 2/5
# 33818/33818 [==============================] - 1047s 31ms/step - loss: 0.5521 - acc: 0.7190 - cosine_proximity: -0.5673 - f1: 0.7513 - val_loss: 0.5410 - val_acc: 0.7310 - val_cosine_proximity: -0.5596 - val_f1: 0.7707
# Epoch 3/5
# 33818/33818 [==============================] - 1048s 31ms/step - loss: 0.5325 - acc: 0.7332 - cosine_proximity: -0.5673 - f1: 0.7609 - val_loss: 0.5303 - val_acc: 0.7344 - val_cosine_proximity: -0.5596 - val_f1: 0.7560
# Epoch 4/5
# 33818/33818 [==============================] - 1044s 31ms/step - loss: 0.5215 - acc: 0.7403 - cosine_proximity: -0.5673 - f1: 0.7671 - val_loss: 0.5260 - val_acc: 0.7400 - val_cosine_proximity: -0.5596 - val_f1: 0.7580
# Epoch 5/5
# 33818/33818 [==============================] - 1040s 31ms/step - loss: 0.5134 - acc: 0.7461 - cosine_proximity: -0.5673 - f1: 0.7714 - val_loss: 0.5241 - val_acc: 0.7376 - val_cosine_proximity: -0.5596 - val_f1: 0.7762
# classification F score: 0.71658

# %%
train_lstm_rnn(5, 300, 'plain_data', 800, "adam", 0.1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 800)               0
# _________________________________________________________________
# embedding_4 (Embedding)      (None, 800, 300)          88642800
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 800, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_4 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                6050
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 88,822,181
# Trainable params: 179,381
# Non-trainable params: 88,642,800
# _________________________________________________________________
# Train on 33818 samples, validate on 3758 samples
# Epoch 1/5
# 33818/33818 [==============================] - 1035s 31ms/step - loss: 0.5942 - acc: 0.6863 - cosine_proximity: -0.5673 - f1: 0.7356 - val_loss: 0.5561 - val_acc: 0.7179 - val_cosine_proximity: -0.5596 - val_f1: 0.7273
# Epoch 2/5
# 33818/33818 [==============================] - 1034s 31ms/step - loss: 0.5425 - acc: 0.7295 - cosine_proximity: -0.5673 - f1: 0.7588 - val_loss: 0.5342 - val_acc: 0.7360 - val_cosine_proximity: -0.5596 - val_f1: 0.7653
# Epoch 3/5
# 33818/33818 [==============================] - 1031s 30ms/step - loss: 0.5254 - acc: 0.7385 - cosine_proximity: -0.5673 - f1: 0.7669 - val_loss: 0.5302 - val_acc: 0.7331 - val_cosine_proximity: -0.5596 - val_f1: 0.7486
# Epoch 4/5
# 33818/33818 [==============================] - 1031s 30ms/step - loss: 0.5150 - acc: 0.7456 - cosine_proximity: -0.5673 - f1: 0.7734 - val_loss: 0.5287 - val_acc: 0.7352 - val_cosine_proximity: -0.5596 - val_f1: 0.7707
# Epoch 5/5
# 33818/33818 [==============================] - 1033s 31ms/step - loss: 0.5039 - acc: 0.7543 - cosine_proximity: -0.5673 - f1: 0.7813 - val_loss: 0.5231 - val_acc: 0.7384 - val_cosine_proximity: -0.5596 - val_f1: 0.7599
# classification F score: 0.71426

# %%
train_lstm_rnn(10, 300, 'data', 800, "adam", 0.1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 800)               0
# _________________________________________________________________
# embedding_5 (Embedding)      (None, 800, 300)          105469200
# _________________________________________________________________
# bidirectional_5 (Bidirection (None, 800, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_5 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 50)                6050
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 105,648,581
# Trainable params: 179,381
# Non-trainable params: 105,469,200
# _________________________________________________________________
# Train on 33818 samples, validate on 3758 samples
# Epoch 1/10
# 33818/33818 [==============================] - 1088s 32ms/step - loss: 0.5964 - acc: 0.6848 - cosine_proximity: -0.5673 - f1: 0.7313 - val_loss: 0.5484 - val_acc: 0.7203 - val_cosine_proximity: -0.5596 - val_f1: 0.7506
# Epoch 2/10
# 33818/33818 [==============================] - 1090s 32ms/step - loss: 0.5454 - acc: 0.7229 - cosine_proximity: -0.5673 - f1: 0.7537 - val_loss: 0.5361 - val_acc: 0.7328 - val_cosine_proximity: -0.5596 - val_f1: 0.7690
# Epoch 3/10
# 33818/33818 [==============================] - 1095s 32ms/step - loss: 0.5324 - acc: 0.7334 - cosine_proximity: -0.5673 - f1: 0.7616 - val_loss: 0.5342 - val_acc: 0.7315 - val_cosine_proximity: -0.5596 - val_f1: 0.7431
# Epoch 4/10
# 33818/33818 [==============================] - 1093s 32ms/step - loss: 0.5219 - acc: 0.7396 - cosine_proximity: -0.5673 - f1: 0.7669 - val_loss: 0.5335 - val_acc: 0.7323 - val_cosine_proximity: -0.5596 - val_f1: 0.7727
# Epoch 5/10
# 33818/33818 [==============================] - 1093s 32ms/step - loss: 0.5118 - acc: 0.7472 - cosine_proximity: -0.5673 - f1: 0.7737 - val_loss: 0.5228 - val_acc: 0.7419 - val_cosine_proximity: -0.5596 - val_f1: 0.7727
# Epoch 6/10
# 33818/33818 [==============================] - 1094s 32ms/step - loss: 0.5048 - acc: 0.7520 - cosine_proximity: -0.5673 - f1: 0.7785 - val_loss: 0.5253 - val_acc: 0.7406 - val_cosine_proximity: -0.5596 - val_f1: 0.7642
# Epoch 7/10
# 33818/33818 [==============================] - 1092s 32ms/step - loss: 0.4945 - acc: 0.7569 - cosine_proximity: -0.5673 - f1: 0.7824 - val_loss: 0.5252 - val_acc: 0.7382 - val_cosine_proximity: -0.5596 - val_f1: 0.7540
# Epoch 8/10
# 33818/33818 [==============================] - 1094s 32ms/step - loss: 0.4882 - acc: 0.7609 - cosine_proximity: -0.5673 - f1: 0.7856 - val_loss: 0.5326 - val_acc: 0.7374 - val_cosine_proximity: -0.5596 - val_f1: 0.7538
# Epoch 9/10
# 33818/33818 [==============================] - 1093s 32ms/step - loss: 0.4770 - acc: 0.7699 - cosine_proximity: -0.5673 - f1: 0.7927 - val_loss: 0.5231 - val_acc: 0.7371 - val_cosine_proximity: -0.5596 - val_f1: 0.7575
# Epoch 10/10
# 33818/33818 [==============================] - 1093s 32ms/step - loss: 0.4672 - acc: 0.7767 - cosine_proximity: -0.5673 - f1: 0.7988 - val_loss: 0.5469 - val_acc: 0.7342 - val_cosine_proximity: -0.5596 - val_f1: 0.7735
# classification F score: 0.71668

# %%
train_lstm_rnn(10, 300, 'plain_data', 800, "adam", 0.1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 800)               0
# _________________________________________________________________
# embedding_6 (Embedding)      (None, 800, 300)          88642800
# _________________________________________________________________
# bidirectional_6 (Bidirection (None, 800, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_6 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 120)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 50)                6050
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 88,822,181
# Trainable params: 179,381
# Non-trainable params: 88,642,800
# _________________________________________________________________
# Train on 33818 samples, validate on 3758 samples
# Epoch 1/10
# 33818/33818 [==============================] - 1088s 32ms/step - loss: 0.6008 - acc: 0.6798 - cosine_proximity: -0.5673 - f1: 0.7286 - val_loss: 0.5569 - val_acc: 0.7227 - val_cosine_proximity: -0.5596 - val_f1: 0.7601
# Epoch 2/10
# 33818/33818 [==============================] - 1088s 32ms/step - loss: 0.5526 - acc: 0.7198 - cosine_proximity: -0.5673 - f1: 0.7501 - val_loss: 0.5451 - val_acc: 0.7217 - val_cosine_proximity: -0.5596 - val_f1: 0.7310
# Epoch 3/10
# 33818/33818 [==============================] - 1089s 32ms/step - loss: 0.5323 - acc: 0.7334 - cosine_proximity: -0.5673 - f1: 0.7615 - val_loss: 0.5352 - val_acc: 0.7331 - val_cosine_proximity: -0.5596 - val_f1: 0.7710
# Epoch 4/10
# 33818/33818 [==============================] - 1088s 32ms/step - loss: 0.5194 - acc: 0.7411 - cosine_proximity: -0.5673 - f1: 0.7690 - val_loss: 0.5268 - val_acc: 0.7312 - val_cosine_proximity: -0.5596 - val_f1: 0.7625
# Epoch 5/10
# 33818/33818 [==============================] - 1090s 32ms/step - loss: 0.5095 - acc: 0.7494 - cosine_proximity: -0.5673 - f1: 0.7758 - val_loss: 0.5262 - val_acc: 0.7358 - val_cosine_proximity: -0.5596 - val_f1: 0.7523
# Epoch 6/10
# 33818/33818 [==============================] - 1087s 32ms/step - loss: 0.5000 - acc: 0.7574 - cosine_proximity: -0.5673 - f1: 0.7828 - val_loss: 0.5303 - val_acc: 0.7310 - val_cosine_proximity: -0.5596 - val_f1: 0.7632
# Epoch 7/10
# 33818/33818 [==============================] - 1086s 32ms/step - loss: 0.4911 - acc: 0.7620 - cosine_proximity: -0.5673 - f1: 0.7875 - val_loss: 0.5265 - val_acc: 0.7318 - val_cosine_proximity: -0.5596 - val_f1: 0.7502
# Epoch 8/10
# 33818/33818 [==============================] - 1089s 32ms/step - loss: 0.4799 - acc: 0.7715 - cosine_proximity: -0.5673 - f1: 0.7955 - val_loss: 0.5256 - val_acc: 0.7299 - val_cosine_proximity: -0.5596 - val_f1: 0.7460
# Epoch 9/10
# 33818/33818 [==============================] - 1086s 32ms/step - loss: 0.4696 - acc: 0.7763 - cosine_proximity: -0.5673 - f1: 0.7995 - val_loss: 0.5312 - val_acc: 0.7291 - val_cosine_proximity: -0.5596 - val_f1: 0.7473
# Epoch 10/10
# 33818/33818 [==============================] - 1084s 32ms/step - loss: 0.4614 - acc: 0.7800 - cosine_proximity: -0.5673 - f1: 0.8036 - val_loss: 0.5330 - val_acc: 0.7286 - val_cosine_proximity: -0.5596 - val_f1: 0.7421
# classification F score: 0.71720

# %%
train_lstm_rnn(15, 300, 'data', 400, "adam", 0.05)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 400)               0
# _________________________________________________________________
# embedding_7 (Embedding)      (None, 400, 300)          105469200
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, 400, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_7 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 120)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 50)                6050
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 105,648,581
# Trainable params: 179,381
# Non-trainable params: 105,469,200
# _________________________________________________________________
# Train on 33818 samples, validate on 3758 samples
# Epoch 1/15
# 33818/33818 [==============================] - 534s 16ms/step - loss: 0.5972 - acc: 0.6868 - cosine_proximity: -0.5673 - f1: 0.7378 - val_loss: 0.5630 - val_acc: 0.7097 - val_cosine_proximity: -0.5596 - val_f1: 0.7398
# Epoch 2/15
# 33818/33818 [==============================] - 539s 16ms/step - loss: 0.5502 - acc: 0.7196 - cosine_proximity: -0.5673 - f1: 0.7531 - val_loss: 0.5458 - val_acc: 0.7219 - val_cosine_proximity: -0.5596 - val_f1: 0.7456
# Epoch 3/15
# 33818/33818 [==============================] - 539s 16ms/step - loss: 0.5324 - acc: 0.7326 - cosine_proximity: -0.5673 - f1: 0.7635 - val_loss: 0.5365 - val_acc: 0.7270 - val_cosine_proximity: -0.5596 - val_f1: 0.7507
# Epoch 4/15
# 33818/33818 [==============================] - 539s 16ms/step - loss: 0.5174 - acc: 0.7432 - cosine_proximity: -0.5673 - f1: 0.7714 - val_loss: 0.5498 - val_acc: 0.7142 - val_cosine_proximity: -0.5596 - val_f1: 0.7143
# Epoch 5/15
# 33818/33818 [==============================] - 539s 16ms/step - loss: 0.5058 - acc: 0.7517 - cosine_proximity: -0.5673 - f1: 0.7780 - val_loss: 0.5334 - val_acc: 0.7288 - val_cosine_proximity: -0.5596 - val_f1: 0.7478
# Epoch 6/15
# 33818/33818 [==============================] - 540s 16ms/step - loss: 0.4902 - acc: 0.7631 - cosine_proximity: -0.5673 - f1: 0.7881 - val_loss: 0.5373 - val_acc: 0.7294 - val_cosine_proximity: -0.5596 - val_f1: 0.7438
# Epoch 7/15
# 33818/33818 [==============================] - 541s 16ms/step - loss: 0.4763 - acc: 0.7727 - cosine_proximity: -0.5673 - f1: 0.7951 - val_loss: 0.5438 - val_acc: 0.7344 - val_cosine_proximity: -0.5596 - val_f1: 0.7669
# Epoch 8/15
# 33818/33818 [==============================] - 540s 16ms/step - loss: 0.4595 - acc: 0.7822 - cosine_proximity: -0.5673 - f1: 0.8036 - val_loss: 0.5507 - val_acc: 0.7246 - val_cosine_proximity: -0.5596 - val_f1: 0.7553
# Epoch 9/15
# 33818/33818 [==============================] - 540s 16ms/step - loss: 0.4425 - acc: 0.7960 - cosine_proximity: -0.5673 - f1: 0.8157 - val_loss: 0.5524 - val_acc: 0.7267 - val_cosine_proximity: -0.5596 - val_f1: 0.7648
# Epoch 10/15
# 33818/33818 [==============================] - 540s 16ms/step - loss: 0.4250 - acc: 0.8051 - cosine_proximity: -0.5673 - f1: 0.8235 - val_loss: 0.5641 - val_acc: 0.7214 - val_cosine_proximity: -0.5596 - val_f1: 0.7445
# Epoch 11/15
# 33818/33818 [==============================] - 542s 16ms/step - loss: 0.4075 - acc: 0.8144 - cosine_proximity: -0.5673 - f1: 0.8324 - val_loss: 0.5772 - val_acc: 0.7147 - val_cosine_proximity: -0.5596 - val_f1: 0.7250
# Epoch 12/15
# 33818/33818 [==============================] - 541s 16ms/step - loss: 0.3932 - acc: 0.8223 - cosine_proximity: -0.5673 - f1: 0.8394 - val_loss: 0.5889 - val_acc: 0.7084 - val_cosine_proximity: -0.5596 - val_f1: 0.7124
# Epoch 13/15
# 33818/33818 [==============================] - 540s 16ms/step - loss: 0.3752 - acc: 0.8320 - cosine_proximity: -0.5673 - f1: 0.8478 - val_loss: 0.6445 - val_acc: 0.7068 - val_cosine_proximity: -0.5596 - val_f1: 0.7525
# Epoch 14/15
# 33818/33818 [==============================] - 542s 16ms/step - loss: 0.3586 - acc: 0.8406 - cosine_proximity: -0.5673 - f1: 0.8549 - val_loss: 0.6114 - val_acc: 0.7243 - val_cosine_proximity: -0.5596 - val_f1: 0.7627
# Epoch 15/15
# 33818/33818 [==============================] - 540s 16ms/step - loss: 0.3407 - acc: 0.8517 - cosine_proximity: -0.5673 - f1: 0.8654 - val_loss: 0.6374 - val_acc: 0.7044 - val_cosine_proximity: -0.5596 - val_f1: 0.7184
# classification F score: 0.70498

# %%
train_lstm_rnn(15, 300, 'plain_data', 400, "adam", 0.05)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 400)               0
# _________________________________________________________________
# embedding_8 (Embedding)      (None, 400, 300)          88642800
# _________________________________________________________________
# bidirectional_8 (Bidirection (None, 400, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_8 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 120)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 50)                6050
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 88,822,181
# Trainable params: 179,381
# Non-trainable params: 88,642,800
# _________________________________________________________________
# Train on 33818 samples, validate on 3758 samples
# Epoch 1/15
# 33818/33818 [==============================] - 529s 16ms/step - loss: 0.5888 - acc: 0.6905 - cosine_proximity: -0.5673 - f1: 0.7349 - val_loss: 0.5454 - val_acc: 0.7238 - val_cosine_proximity: -0.5596 - val_f1: 0.7438
# Epoch 2/15
# 33818/33818 [==============================] - 549s 16ms/step - loss: 0.5367 - acc: 0.7312 - cosine_proximity: -0.5673 - f1: 0.7608 - val_loss: 0.5333 - val_acc: 0.7358 - val_cosine_proximity: -0.5596 - val_f1: 0.7699
# Epoch 3/15
# 33818/33818 [==============================] - 587s 17ms/step - loss: 0.5192 - acc: 0.7409 - cosine_proximity: -0.5673 - f1: 0.7687 - val_loss: 0.5277 - val_acc: 0.7368 - val_cosine_proximity: -0.5596 - val_f1: 0.7666
# Epoch 4/15
# 33818/33818 [==============================] - 555s 16ms/step - loss: 0.5028 - acc: 0.7546 - cosine_proximity: -0.5673 - f1: 0.7802 - val_loss: 0.5274 - val_acc: 0.7352 - val_cosine_proximity: -0.5596 - val_f1: 0.7554
# Epoch 5/15
# 33818/33818 [==============================] - 527s 16ms/step - loss: 0.4893 - acc: 0.7621 - cosine_proximity: -0.5673 - f1: 0.7866 - val_loss: 0.5282 - val_acc: 0.7360 - val_cosine_proximity: -0.5596 - val_f1: 0.7649
# Epoch 6/15
# 33818/33818 [==============================] - 542s 16ms/step - loss: 0.4703 - acc: 0.7757 - cosine_proximity: -0.5673 - f1: 0.7986 - val_loss: 0.5530 - val_acc: 0.7262 - val_cosine_proximity: -0.5596 - val_f1: 0.7752
# Epoch 7/15
# 33818/33818 [==============================] - 548s 16ms/step - loss: 0.4538 - acc: 0.7845 - cosine_proximity: -0.5673 - f1: 0.8063 - val_loss: 0.5395 - val_acc: 0.7336 - val_cosine_proximity: -0.5596 - val_f1: 0.7710
# Epoch 8/15
# 33818/33818 [==============================] - 544s 16ms/step - loss: 0.4348 - acc: 0.7993 - cosine_proximity: -0.5673 - f1: 0.8196 - val_loss: 0.5431 - val_acc: 0.7280 - val_cosine_proximity: -0.5596 - val_f1: 0.7557
# Epoch 9/15
# 33818/33818 [==============================] - 573s 17ms/step - loss: 0.4150 - acc: 0.8103 - cosine_proximity: -0.5673 - f1: 0.8287 - val_loss: 0.5495 - val_acc: 0.7280 - val_cosine_proximity: -0.5596 - val_f1: 0.7650
# Epoch 10/15
# 33818/33818 [==============================] - 621s 18ms/step - loss: 0.3937 - acc: 0.8241 - cosine_proximity: -0.5673 - f1: 0.8416 - val_loss: 0.6035 - val_acc: 0.7155 - val_cosine_proximity: -0.5596 - val_f1: 0.7612
# Epoch 11/15
# 33818/33818 [==============================] - 645s 19ms/step - loss: 0.3716 - acc: 0.8357 - cosine_proximity: -0.5673 - f1: 0.8517 - val_loss: 0.6022 - val_acc: 0.7139 - val_cosine_proximity: -0.5596 - val_f1: 0.7184
# Epoch 12/15
# 33818/33818 [==============================] - 566s 17ms/step - loss: 0.3551 - acc: 0.8440 - cosine_proximity: -0.5673 - f1: 0.8590 - val_loss: 0.6094 - val_acc: 0.7211 - val_cosine_proximity: -0.5596 - val_f1: 0.7511
# Epoch 13/15
# 33818/33818 [==============================] - 577s 17ms/step - loss: 0.3371 - acc: 0.8530 - cosine_proximity: -0.5673 - f1: 0.8669 - val_loss: 0.6209 - val_acc: 0.7137 - val_cosine_proximity: -0.5596 - val_f1: 0.7462
# Epoch 14/15
# 33818/33818 [==============================] - 572s 17ms/step - loss: 0.3175 - acc: 0.8629 - cosine_proximity: -0.5673 - f1: 0.8760 - val_loss: 0.6501 - val_acc: 0.7105 - val_cosine_proximity: -0.5596 - val_f1: 0.7218
# Epoch 15/15
# 33818/33818 [==============================] - 599s 18ms/step - loss: 0.3070 - acc: 0.8675 - cosine_proximity: -0.5673 - f1: 0.8803 - val_loss: 0.6810 - val_acc: 0.7105 - val_cosine_proximity: -0.5596 - val_f1: 0.7252
# classification F score: 0.70238

# %%
model_results
# Out:
# [{'accuracy': 0.735729,
#   'name': 'TFIDF HTML - Predict Bachelor',
#   'log_loss': 0.521058},
#  {'accuracy': 0.734371,
#   'name': 'TFIDF Plain Text - Predict Bachelor',
#   'log_loss': 0.521902},
#  {'accuracy': 0.675449,
#   'name': 'TFIDF HTML NB - Predict Bachelor',
#   'log_loss': 0.979609},
#  {'accuracy': 0.706906,
#   'name': 'TFIDF Plain NB - Predict Bachelor',
#   'log_loss': 0.774902},
#  {'accuracy': 0.73501,
#   'name': 'TFIDF Plain Log Pipeline [*all] - Predict Bachelor',
#   'log_loss': 0.520727},
#  {'accuracy': 0.735409,
#   'name': 'TFIDF HTML Log Pipeline [*all] - Predict bachelor',
#   'log_loss': 0.522804},
#  {'F1 accuracy': 0.7153826465318659,
#   'name': 'LSTM: CO:400, E:5, data, adam - Predict Bachelor'},
#  {'F1 accuracy': 0.7158888038765621,
#   'name': 'LSTM: CO:400, E:5, plain_data, adam - Predict Bachelor'},
#  {'F1 accuracy': 0.7165836844121027,
#   'name': 'LSTM: CO:800, E:5, data, adam - Predict Bachelor'},
#  {'F1 accuracy': 0.7142583732057416,
#   'name': 'LSTM: CO:800, E:5, plain_data, adam - Predict Bachelor'},
#  {'F1 accuracy': 0.7166751787538306,
#   'name': 'LSTM: CO:800, E:10, data, adam - Predict Bachelor'},
#  {'F1 accuracy': 0.7172026544155181,
#   'name': 'LSTM: CO:800, E:10, plain_data, adam - Predict Bachelor'},
#  {'F1 accuracy': 0.7049808429118775,
#   'name': 'LSTM: CO:400, E:15, data, adam - Predict Bachelor'},
#  {'F1 accuracy': 0.7023786748294114,
#   'name': 'LSTM: CO:400, E:15, plain_data, adam - Predict Bachelor'}]

# %%
model_predictions
# Out:
# {'CO:400, E:5, data, adam': array([[0.3 ],
#         [0.78],
#         [0.48],
#         ...,
#         [0.26],
#         [0.38],
#         [0.16]], dtype=float32),
#  'CO:400, E:5, plain_data, adam': array([[0.34],
#         [0.77],
#         [0.24],
#         ...,
#         [0.19],
#         [0.22],
#         [0.18]], dtype=float32),
#  'CO:800, E:5, data, adam': array([[0.42],
#         [0.65],
#         [0.45],
#         ...,
#         [0.35],
#         [0.35],
#         [0.34]], dtype=float32),
#  'CO:800, E:5, plain_data, adam': array([[0.43],
#         [0.5 ],
#         [0.27],
#         ...,
#         [0.25],
#         [0.24],
#         [0.35]], dtype=float32),
#  'CO:800, E:10, data, adam': array([[0.29],
#         [0.65],
#         [0.27],
#         ...,
#         [0.5 ],
#         [0.68],
#         [0.3 ]], dtype=float32),
#  'CO:800, E:10, plain_data, adam': array([[0.26],
#         [0.6 ],
#         [0.44],
#         ...,
#         [0.19],
#         [0.18],
#         [0.28]], dtype=float32),
#  'CO:400, E:15, data, adam': array([[0.1 ],
#         [0.35],
#         [0.2 ],
#         ...,
#         [0.31],
#         [0.3 ],
#         [0.05]], dtype=float32),
#  'CO:400, E:15, plain_data, adam': array([[0.68],
#         [0.97],
#         [0.3 ],
#         ...,
#         [0.31],
#         [0.66],
#         [0.91]], dtype=float32)}

# %%
def score_accuracy(pred, actual):
    total = 0.0
    correct = 0.0
    for index, value in enumerate(pred):
        if (actual[index] == round(value[0])):
            correct += 1
        total += 1
    return correct / total

# %%
for index in model_predictions:
    score = score_accuracy(model_predictions[index], predictors_test['bachelor'].astype(int))
    print(str(index) + " score: " + str(score))
# Out:
# CO:400, E:5, data, adam score: 0.7251097804391218
# CO:400, E:5, plain_data, adam score: 0.7239121756487026
# CO:800, E:5, data, adam score: 0.7274251497005988
# CO:800, E:5, plain_data, adam score: 0.725189620758483
# CO:800, E:10, data, adam score: 0.7255089820359282
# CO:800, E:10, plain_data, adam score: 0.7220758483033932
# CO:400, E:15, data, adam score: 0.7014770459081836
# CO:400, E:15, plain_data, adam score: 0.6977245508982036

# %%
train_lstm_rnn(3, 300, 'plain_data', 800, "adam", 0.05)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 800)               0
# _________________________________________________________________
# embedding_9 (Embedding)      (None, 800, 300)          88642800
# _________________________________________________________________
# bidirectional_9 (Bidirection (None, 800, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_9 (Glob (None, 120)               0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 120)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 50)                6050
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 88,822,181
# Trainable params: 179,381
# Non-trainable params: 88,642,800
# _________________________________________________________________
# Train on 33818 samples, validate on 3758 samples
# Epoch 1/3
# 33818/33818 [==============================] - 1211s 36ms/step - loss: 0.5941 - acc: 0.6879 - cosine_proximity: -0.5673 - f1: 0.7336 - val_loss: 0.5594 - val_acc: 0.7163 - val_cosine_proximity: -0.5596 - val_f1: 0.7626
# Epoch 2/3
# 33818/33818 [==============================] - 1254s 37ms/step - loss: 0.5404 - acc: 0.7278 - cosine_proximity: -0.5673 - f1: 0.7560 - val_loss: 0.5396 - val_acc: 0.7331 - val_cosine_proximity: -0.5596 - val_f1: 0.7743
# Epoch 3/3
# 33818/33818 [==============================] - 1271s 38ms/step - loss: 0.5199 - acc: 0.7423 - cosine_proximity: -0.5673 - f1: 0.7687 - val_loss: 0.5274 - val_acc: 0.7355 - val_cosine_proximity: -0.5596 - val_f1: 0.7612
# classification F score: 0.71553

# %%
train_lstm_rnn(3, 300, 'data', 800, "adam", 0.05)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        (None, 800)               0
# _________________________________________________________________
# embedding_10 (Embedding)     (None, 800, 300)          105469200
# _________________________________________________________________
# bidirectional_10 (Bidirectio (None, 800, 120)          173280
# _________________________________________________________________
# global_max_pooling1d_10 (Glo (None, 120)               0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 120)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 50)                6050
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 105,648,581
# Trainable params: 179,381
# Non-trainable params: 105,469,200
# _________________________________________________________________
# Train on 33818 samples, validate on 3758 samples
# Epoch 1/3
# 33818/33818 [==============================] - 1237s 37ms/step - loss: 0.5913 - acc: 0.6884 - cosine_proximity: -0.5673 - f1: 0.7331 - val_loss: 0.5527 - val_acc: 0.7171 - val_cosine_proximity: -0.5596 - val_f1: 0.7553
# Epoch 2/3
# 33818/33818 [==============================] - 1147s 34ms/step - loss: 0.5411 - acc: 0.7272 - cosine_proximity: -0.5673 - f1: 0.7564 - val_loss: 0.5447 - val_acc: 0.7235 - val_cosine_proximity: -0.5596 - val_f1: 0.7325
# Epoch 3/3
# 33818/33818 [==============================] - 1275s 38ms/step - loss: 0.5228 - acc: 0.7384 - cosine_proximity: -0.5673 - f1: 0.7660 - val_loss: 0.5281 - val_acc: 0.7331 - val_cosine_proximity: -0.5596 - val_f1: 0.7498
# classification F score: 0.71606

# %%
for index in model_predictions:
    score = score_accuracy(model_predictions[index], predictors_test['bachelor'].astype(int))
    print(str(index) + " score: " + str(score))
# Out:
# CO:400, E:5, data, adam score: 0.7251097804391218
# CO:400, E:5, plain_data, adam score: 0.7239121756487026
# CO:800, E:5, data, adam score: 0.7274251497005988
# CO:800, E:5, plain_data, adam score: 0.725189620758483
# CO:800, E:10, data, adam score: 0.7255089820359282
# CO:800, E:10, plain_data, adam score: 0.7220758483033932
# CO:400, E:15, data, adam score: 0.7014770459081836
# CO:400, E:15, plain_data, adam score: 0.6977245508982036
# CO:800, E:3, plain_data, adam score: 0.7304590818363274
# CO:800, E:3, data, adam score: 0.7244710578842315

# %%
model_predictions
# Out:
# {'CO:400, E:5, data, adam': array([[0.3 ],
#         [0.78],
#         [0.48],
#         ...,
#         [0.26],
#         [0.38],
#         [0.16]], dtype=float32),
#  'CO:400, E:5, plain_data, adam': array([[0.34],
#         [0.77],
#         [0.24],
#         ...,
#         [0.19],
#         [0.22],
#         [0.18]], dtype=float32),
#  'CO:800, E:5, data, adam': array([[0.42],
#         [0.65],
#         [0.45],
#         ...,
#         [0.35],
#         [0.35],
#         [0.34]], dtype=float32),
#  'CO:800, E:5, plain_data, adam': array([[0.43],
#         [0.5 ],
#         [0.27],
#         ...,
#         [0.25],
#         [0.24],
#         [0.35]], dtype=float32),
#  'CO:800, E:10, data, adam': array([[0.29],
#         [0.65],
#         [0.27],
#         ...,
#         [0.5 ],
#         [0.68],
#         [0.3 ]], dtype=float32),
#  'CO:800, E:10, plain_data, adam': array([[0.26],
#         [0.6 ],
#         [0.44],
#         ...,
#         [0.19],
#         [0.18],
#         [0.28]], dtype=float32),
#  'CO:400, E:15, data, adam': array([[0.1 ],
#         [0.35],
#         [0.2 ],
#         ...,
#         [0.31],
#         [0.3 ],
#         [0.05]], dtype=float32),
#  'CO:400, E:15, plain_data, adam': array([[0.68],
#         [0.97],
#         [0.3 ],
#         ...,
#         [0.31],
#         [0.66],
#         [0.91]], dtype=float32),
#  'CO:800, E:3, plain_data, adam': array([[0.52],
#         [0.64],
#         [0.27],
#         ...,
#         [0.29],
#         [0.27],
#         [0.23]], dtype=float32),
#  'CO:800, E:3, data, adam': array([[0.33],
#         [0.66],
#         [0.27],
#         ...,
#         [0.3 ],
#         [0.27],
#         [0.24]], dtype=float32)}

# %%
def print_wrong_examples(pred, actual, details = True):
    count = 0
    for index, value in enumerate(pred):
        if (actual[index] != round(value[0])) and (abs(actual[index] - value[0]) > 0.8):
            print("index:" + str(index) + " actual:" + str(actual[index].astype(int)) + " predicted:" + str(round(value[0])) + " " + str(value[0]))
            if (details):
                print('====================================================================')
                print(test_data_['plain_data'][index])
            count += 1
        if (count > 10):
            break

# %%
print_wrong_examples(model_predictions['CO:800, E:5, data, adam'], predictors_test['bachelor'].astype(int), True)
# Out:
# index:0 actual:1 predicted:0.0 0.42440167
# ====================================================================
#
#
# foreman
#
# riverdale, il
# -
#
# to join an interactive organization that offers me a constructive workplace for communication and interaction. able to work within a team but also maintain self-motivation that allows production and no supervision.
# willing to relocate: anywhere
# authorized to work in the us for any employer
#
#
# work experience
#
#
# foreman
#
# suburban landscaping - chicago heights, il
#
# -
# may 2016 to present
# team leader of crew members on projects.  ensures that all projects are completed and met in a timely matter and that the work of field crew meets quality expectations.  primary role is to perform herbicide spot treatments on noxious weeds using backpack sprayers.  responsible for managing multiple projects at once. responsible for weed removal on both residential and commercial properties
#
#
# assistant manager/cashier
#
# 19paul smokehouse - chicago, il
#
# -
# july 2014 to april 2016
# responsible for up keeping and filing of store records, time sheets, and employee records.  responsible for maintaining quality customer service, which included greeting and advising customers. ordering supplies problem solving recruiting, training, and supervising staff ensuring compliance with licensing, and health and safety guidelines. cash handling   accomplishments i began as a cashier in july of 2014 and within a year i was promoted as an assistant manager.
#
#
# laborer
#
# cook county forest preserve district - river forest, il
#
# -
# may 2012 to august 2013
# responsible for maintenance and up keeping of forest preserve grounds, which include cutting, trimming, and picking. • maintained picnic groves and bathrooms • some clerical duties performed. • built customer confidence by actively listening to their concerns and gave appropriate feedback. • planned work and determined appropriate tools and equipment. • kept supervisor informed on job progress and material requirements • preserved perfect attendance record for six months.
#
#
# cashier/customer service
#
# crisp-n-clean cleaners - evergreen park, il
#
# -
# november 2008 to may 2012
# answered customer telephone calls promptly and in an appropriate manner. • operated a cash register for cash, check, and credit card transactions • cleaned and organized the store, including the checkout desk and displays • handled all customer relations issues in a gracious manner and in accordance with company policies. • verified that all customers received receipts for their purchases. • mentored new sales associate to contribute to the store's positive culture.
#
#
#
#
#
# additional information
# skills &amp; abilities • customer-oriented • active listening skills  • computer literate • stocking • motivated team player • personable
#
#
# index:1 actual:0 predicted:1.0 0.6514158
# ====================================================================
#
#
# export control specialist
#
# eagleville, pa
# -
#
#
#
# work experience
#
#
# export control specialist
# greene, tweed &amp; co., llc
# -
# january 2009 to september 2016
# role summary: works closely with all levels of management to provide guidance on all issues having an impact on import/export operations and procedures to assure the company meets or exceeds all export compliance requirements.  export control specialist responsibilities • communicate with directorate of defense trade controls (ddtc), bureau of industry and security (bis), department of defense (dod) on trade regulations and licensing issues. • prepare licensing application for submittal to ddtc or bis. • support from engineering, sales or program development to review and approve export classifications (export control classification number (eccn), united states munitions lists (usml), harmonized tariff schedule (hts), and schedule b codes) of greene, tweed products. • review restricted/denied party screening hits and consult with staff on screening issues. • communicate with human resources: provide authorizations for foreign employment on both commercial and defense services. • empowered official, managed the company's import-export activities. • worked with export processing/shipper to coordinate necessary documentation in compliance with u.s. import and export laws and regulations. • evaluated current policies, procedures, and documentation for compliance with government laws and regulations. • processed and applied for all export licenses, exemptions, technical assistance, warehouse and distribution agreements, and kept track of all documents in the export license database. • established, administered and monitored a part number classifications/license determinations matrix that listed all applicable eccns, usmls, schedule b and hts codes. • ensured u.s regulatory recordkeeping requirements were maintained and available via an internal database that also enabled prompt retrieval. • screened all customers, vendors, shippers, and any other parties involved in the transactions against the u.s. government prohibited/denied party lists. • complied with all requests for manufacturer's affidavits/certifications, marking of country of origins, and commodities classifications. • reviewed request for quotes (rfq) and sales orders, for anti-boycotting issues, red flags, and other export issues and reported, if any, to the appropriate government agencies. 65 washington blvd., eagleville, pa 19403 c: (610) 930-6751 maironan86@gmail.com
#
#
# customer service representative
# greene, tweed &amp; co
# -
# 2000 to 2009
# received and processes and expedite all customers' rfqs and sales orders.
#
#
# industrial warehouse, packaging/shipping department supervisor
# greene, tweed &amp; co
# -
# 1996 to 2000
# responsible for direct supervision of hourly, union warehouse, packaging, and shipping personnel
#
#
# production control/ planner
# greene, tweed &amp; co
# -
# 1994 to 1996
# responsible for the planning and scheduling major account products and releasing timely shipments. coordinates all products requirements including external sources and monitor shipments. maintain accurate lead times and requirements of assigned accounts.
#
#
# quality control inspector
# greene, tweed &amp; co
# -
# 1992 to 1994
# for aerospace and industrial products responsible for inspecting of incoming products, perform first article, in-process, and final inspection and product audits as directed.
#
#
# warehouse/ packaging operator
# greene, tweed &amp; co
# -
# 1990 to 1992
# responsible for store, retrieves, count, label and record all parts assemblies, and perform any other warehouse tasks. responsible for assembling and package components as specified and performs quality control.
#
#
# electronic assembler
# brookes instrument
# -
# 1986 to 1990
# assembling, inspecting, and repairing of circuit boards
#
#
#
#
#
# additional information
# computer skills • d-trade, department of state                    • snap-r, department of commerce • dtas-online: mary                               • aes (automated export system), u.s. • ds-4076 commodity jurisdiction (cj) request       customs form • microsoft office (e.g., visio, word, excel, • visual compliance - restricted/ denied party powerpoint)                                       screening • sap
#
#
# index:2 actual:1 predicted:0.0 0.44526967
# ====================================================================
#
#
# housekeeper
#
# memphis, tn
# -
#
# willing to relocate: anywhere
# authorized to work in the us for any employer
#
#
# work experience
#
#
# housekeeper
#
# abm industries, inc. - memphis, tn
#
# -
# october 2014 to december 2015 (1 year, 2 months)
# performed a variety of cleaning activities such as sweeping, mopping, dusting and polishing •ensured all rooms are cared for and inspected according to standards •protect equipment and make sure there are no inadequacies •notify superiors on any damages, deficits and disturbances •deal with reasonable complaints/requests with professionalism and patience •check stocking levels of all consumables and replace when appropriate •adhere strictly to rules regarding health and safety and be aware of any company-related practices
#
#
# server
#
# tgi friday's restaurants - memphis, tn
#
# -
# november 2013 to january 2015 (1 year, 2 months)
# •prepared room for dining by clothing tables and setting decorations, condiments, candles, napkins, service plates, and utensils. •protect establishment and patrons by adhering to sanitation, safety, and alcohol beverage control policies. •help patrons select food and beverages by presenting menu; offering cocktails and aperitifs; suggesting courses; explaining the chef's specialties; identifying appropriate wines; answering food preparation questions. •transmitted orders to bar and kitchen by recording patrons' choices; identifying patrons' special dietary needs and special requests. •kept kitchen staff informed by noting timing of meal progression. •served orders by picking up and delivering patrons' choices from bar and kitchen; delivering accompaniments and condiments from service bars. •responded to additional patron requirements by inquiring of needs; observing dining process. •maintained table setting by removing courses as completed; replenishing utensils; refilling water glasses; being alert to patron spills or other special needs. •concluded dining experience by acknowledging choice of restaurant; inviting patrons to return. •obtained revenues by totaling charges; issuing bill; accepting payment; delivering bill and payment to hostperson; returning change or credit card and signature slip to patrons. •contributed to team effort by accomplishing related results as needed.
#
#
# receiving associate/ cashier
#
# academy sports + outdoors - collierville, tn
#
# -
# february 2013 to december 2013 (10 months)
# process and package orders due to production. make sure items are maintained and kept in original packaging. oversee production chart and mark guidelines according to company polices.  accomplishments i learned labeling ..shipping and packing   skills used the right way to ship out a package
#
#
#
#
#
# index:4 actual:0 predicted:1.0 0.73547286
# ====================================================================
#
#
# paul costa
#
# henrico, va
# -
#
# authorized to work in the us for any employer
#
#
# work experience
#
# technical support analyst / system admin
#
# pembrooke/escreen/alere - richmond, va
#
# -
# may 2005 to august 2015
# responsibilities daily responsibilities included monitoring a service desk ticketing system to ensure meeting of service level agreements.    accomplishments •    performed company-wide desktop deployments, os upgrades, and hardware replacements to serve over 100 clients in the business user community. •    implemented numerous dedicated client telephone service numbers and supported telephony configuration. •    supported migration of an in-house server room to a co-location data center. •    mentored new associates to develop understanding of company software and hardware. •       provided weekend and after hours support.   skills used •    systems installation, configuration, and upgrade support •    server administration •    telephony configuration and administration •    desktop image creation and deployment •    mobile device deployments •    technical support and troubleshooting
#
#
#
#
# certifications
#
# microsoft windows vista mcsa
# march 2010
#
#
#
# additional information
# additional education:  learning tree courses - 2009 active directory users and computers exchange 2003
#
#
# index:8 actual:1 predicted:0.0 0.35276544
# ====================================================================
#
#
# job seeker
#
# dillsburg, pa
# -
#
#
#
# work experience
# 6/1/05-present  7/1/12-present  10/1/11-present  12/1/1999 - 8/12/2006  1/1/1997 - 10/31/1999
#
#
#
# additional information
# skills: leadership - life coaching - management - team player - conflict resolution -                       floor specialist - stone and hardscape specialist - finish carpenter
#
#
# index:9 actual:1 predicted:0.0 0.25055635
# ====================================================================
#
#
# cna - certified nursing assistant
#
# eagan, mn
# -
#
#
#
#
# work experience
#
#
# cna - certified nursing assistant
# st therese of woodbury
# -
# july 2016 to present
#
#
# cna - certified nursing assistant
# havenwood care center
# -
# september 2014 to april 2015
#
#
# cna - certified nursing assistant
# cornerstone nursing and rehab center
# -
# january 2014 to september 2014
#
#
#
#
#
# skills
# patient care (3 years)
#
#
# certifications
#
#
# bls/cpr
# january 2015 to present
#
#
# certified dementia specialist
# october 2016 to present
#
#
#
#
# additional information
# i am a enthusiastic with a great work ethic. i am trying to find a job in a hospital where i can set a base for years to come. i am dedicated and have an outstanding attendance.
#
#
# index:16 actual:0 predicted:1.0 0.7702865
# ====================================================================
#
#
# james rubilotta
#
# cambridge springs, pa
# -
#
# dynamic manager with over a 15 year record of achievement and success driving sales growth, while providing leadership in highly competitive markets. adept at driving growth of company revenues and improving sales-team performance. exceptional mentor and coach. a strong belief in providing exceptional customer service to increase business and create customer loyalty.
#
#
# work experience
#
#
# water treatment consultant
#
# nch corporation - irving, tx
#
# -
# 2013 to present
# responsible for the growth of assigned territory including the sales and service of new and existing customers and the negotiation of contracts with both private and public entities.  selected achievements: ♦ increased assigned territory sales volume by 45%. ♦ successfully completed phase i &amp; ii nch national sales training program ♦ successfully completed pa &amp; ny requirements to be a licensed pesticide applicator.
#
#
# salesman
#
# adirondack combustion technologies - duanesburg, ny
#
# -
# 2007 to 2013
# coordinate design of hvac systems with project engineers. responsible for sales of equipment to private companies and public entities via open bid or negotiated contracts.  selected achievements: ♦ part of sales team ranked #1 with patterson kelly in 2009 o doubled new sales for territory over expiring company representative.
#
#
# general manager
#
# ruby &amp; quiri inc - gloversville, ny
#
# -
# 1998 to 2007
# oversee all sales, operational and business development functions, including merchandising, training, customer relations, advertising, purchasing, inventory and all warehouse functions for a multi-unit home furnishing company.  provide cross-functional training, coaching, and mentoring for management team of 8, 40-45 employees and sub-contractor force of 12.  selected achievements: ♦ instrumental in the turnaround of under-performing management team; set higher expectations and instituted individual team-member accountability resulting in yearly sales increases for 7 years. ♦ increased profit margin ♦ instituted a structured advertising budget reducing spending while maintaining yearly growth. ♦ developed and implemented sales tracking/ follow up program increasing the closing rate of sales staff. ♦ trained buyers on inventory control increasing our turns and reducing overall inventory by 22%. ♦ created ad campaigns and coordinated all advertising with, print, radio, tv and direct mail. ♦ increased net profit from 2.4% of sales to 3.1% of sales.
#
#
# sales manager
#
# hack's furniture - albany, ny
#
# -
# 1995 to 1998
# responsible for all day to day functions of the sales team.  worked closely with store management in many areas, including advertising, merchandising, and training.
#
#
#
#
# index:25 actual:0 predicted:1.0 0.73430705
# ====================================================================
#
#
# process driver checks weekly
# process driver checks weekly - account payable
#
# carrollton, ga
# -
#
# to obtain a challenging position with a progressive organization which offers an opportunity for career advancement
#
#
# work experience
#
#
# process driver checks weekly
#
# account payable - carrollton, ga
#
# -
# march 2014 to present
# carrollton, ga *  post invoices -enter invoices  into dealer track *  prepare monthly account receives reports to mail out *  process driver checks weekly *  follow-up collections of past due *   clean schedules
#
#
# account manager
#
# united beverage group - atlanta, ga
#
# -
# march 2009 to june 2013
# *  manage all income and outcome accounts *  process all account receives and payable in quick book *  prepare monthly reports *  record and deposit all checks and deductions *  process reports and corresponding billing *  follow-up collections of past due *   manage edi-outbound; purchase orders, invoices and production
#
#
# market scheduling coordinator
#
# cbs outdoor - atlanta, ga
#
# -
# march 2001 to march 2009
# *  input contracts in data system for advertiser. *  maintained posting cards and contracts *  handle all evaluations and reporting of all assigned contracts forms *  compile data for monthly statistics for monthly reports *  maintained and recorded all contracts evaluation for auditing purposes *  claims troubleshooting and problem solving
#
#
# planning/receiving clerk
#
# tie down engineering inc - atlanta, ga
#
# -
# october 1999 to february 2001
# *  count, sort or weigh incoming material to verify receipts of items on packing slip or invoice *  sorted incoming receipts and route to destination *  processed receiver tickets for all material purchased via purchase order *  perform data entry transactions; aided in return to supplier processes.
#
#
# edi coordinator
#
# intercoastal data corporation - carrollton, ga
#
# -
# october 1996 to october 1999
# under general supervision perform payroll, ap/ar accounting and fiscal control functions * data processor *  process all billing by the deadlines set forth *  assisted director with all meetings, clients, and administrative work
#
#
#
#
#
# additional information
# computer skills: microsoft office, powerpoint, as/400, microsoft outlook, chartpro, excel, clarita mapping, goldmine, quickbooks
#
#
# index:26 actual:0 predicted:1.0 0.51564014
# ====================================================================
#
#
# kimberly chitthaphong
#
# fresno, ca
# -
#
#
#
# work experience
#
#
# maui hawaiian bbq cashier
# -
# june 2015 to present
# handle cash, take orders, pack up orders, learn menu, clean tables, restock, make smoothies/slushies, sweep/mop, take out trash, answer any questions from customers  activities:
#
#
# alorica customer service representative
# verizon wireless
# -
# december 2014 to june 2015
# call center includes many computer skills and high expectations by answering verizon wireless customer's calls, adapting to many changes, learning many techniques or tools everyday, communication skills by positioning professional phrases including sympathy and educating customer's, making sure to provide excellent customer service, and includes patient, positive attitudes.
#
#
# applebee's hostess
# -
# march 2014 to december 2014
# includes no work experience, 18+, fast pace, multitasking, good   communication, open door, greet and seat customers, learn applebee's menu, clean tables, make sure restrooms are neat (clean toilets, sink, mop, and restock), windows are spotless, make sure tables are set to perfection, answer customer's questions, clean anything the manager requests, sweep restaurant, and run food.
#
#
# babysitting
# -
# 2009 to 2014
# child care provide child care for my family on some weekends, change diapers, supervise, entertain, feed, take a bath and etc.  chemistry teacher's aid help the teacher with experiments and tutor underclassmen students, prep chemicals, grade papers, organize chemicals, and clean tools.
#
#
# basketball, volleyball, softball
# -
# 2010 to 2013
# awards:
#
#
# 1st place science fair
# -
# 2009 to 2009
# 2009    1st place science fair, citric acid prevents fruits from browning  special interest: mathematics, sports, arts and crafts, fashion, culinary art
#
#
#
#
#
# index:27 actual:1 predicted:0.0 0.28336024
# ====================================================================
#
#
# walmart pharmacy
#
# owensboro, ky
# -
#
#
#
# work experience
#
# walmart pharmacy
# walmart
# -
# june 2015 to present
#
#
#
#
# skills
#
# customer service (1 year), pharmacology (1 year)
#
#
#
# certifications
#
# certified pharmacy technician (cpht)
# october 2016 to october 2018
#
#
#
# index:29 actual:0 predicted:1.0 0.86596376
# ====================================================================
#
#
# christina lawry
# administrative assistant to special education department - medicaid in public schools
#
# tucson, az
# -
#
#
#
# work experience
#
#
# educational assistant and clerk ii
# amphitheater public schools
# -
# october 2011 to june 2013
# educational assistant - under general supervision of principal, i implemented directives in performing routine administrative tasks necessary for day to day effective operation of the school. -met with principal to secure direction for specific tasks to be accomplished. -monitored work of employees responsible for cleanliness, maintenance and safety of physical plant. -performed routine supervision of students, as directed by principal. -worked directly with students in handling routine discipline problems where consequences are specifically mandated in student handbook, or in state rules of school and district. -communicated with parents, as appropriate. -developed routine reports and communicate information, as requested. -exhibited patience, courtesy and tact when dealing with students, parents and community. -promoted and support district-wide educational advancement in 21st century skills. -integrated knowledge and skills relevant to 21st century. -maintained school website. • clerk ii - clerical work required the initiative to perform routine tasks independently and in accordance with established procedures. -completed forms, copies data, and compiled records and reports in accordance with established procedures. -answered phones, responded to requests for general information, and referred inquiries to appropriate person. -performed routine administrative duties, including scheduling appointments, explaining office procedures to employees and maintaining office supplies and equipment. -sorted and distributed mail or other materials and prepared correspondence for mailing. -operated a variety of standard office machines and telephone switchboard. -typed and proofread a variety of materials of moderate complexity. -researched files and records for information, assembled data, and handled materials of a confidential nature. -maintained limited financial records, logs, schedules, record cards and forms; tabulated and posted data. -initiated work orders, scheduled transportation and provided other backup assistance, as needed. -coordinated box tops for education program.
#
#
# health outreach assistant/certified parent educator
#
# amphitheater public schools - tucson, az
#
# -
# september 2008 to may 2010
# -provided training, support, and information to parents enabling them to enhance their child's intellectual, language, physical and social development from birth to age five. -taught the importance of early literacy to parents in program. -worked with family resource and wellness center staff, family advocates, parents and community groups and provided written reports. -served as referral source to other community agencies. -provided families with monthly home visits, or more often if needed. -provided developmental screenings at 12, 24, 36, 48, and 60 months of age, including vision and hearing screenings. -attended staff meetings and in-services as liaison between parents, school, and outside agencies. -worked with district personnel (board members, principals, nurses) in recruitment of families and dissemination of information. -maintained monthly records and assisted in program evaluation. -promoted parent/community participation in advisory committees, volunteer programs, and school functions. -interacted with community and state agencies; exhibited patience, courtesy and tact dealing with others.
#
#
# special education teaching assistant
#
# amphitheater public schools - tucson, az
#
# -
# august 2007 to may 2008
# -assisted special education teacher, providing individualized instruction and classroom assistance for special education students who were mentally, physically or emotionally disabled, or who may have multiple disabilities. -contributed to planning, implementation and evaluation in training and instruction of students. -provided individualized training of students in eating habits, toileting and bathing; assisted with usage of proper sanitary measures. -provided assistance for handling, lifting, and caring for disabled students; assisted in exercise programs. -provided direct instruction and assistance to students in accordance with guidance plans made in conference with teacher, through demonstration, corrective feedback, and innovative methods. -attended in-services, school and special education faculty meetings and assisted by contributing pertinent data and taking notes, as assigned. -maintained confidential files of special education students, answered phones and provided clerical services. -assisted with student behavior plans and instruction by following i.e.p. objectives and recording data.  parent educator certification and education certificate - three years to kindergarten parents as teachers program tucson, az certificate - prenatal to three years parents as teachers national center st. louis, mo
#
#
#
#
# additional information
# office skills microsoft office, outlook, excel, 10-key internet data bases, mail distribution data entry (45 wpm) fax machines spreadsheets, printers, multi-line telephone, student file organization, confidentiality, etc.
